# %% [markdown]
# Our aim is to reproduce an example from the paper:
#
# [Inferring single-trial neural population dynamics using sequential auto-encoders](https://www.nature.com/articles/s41592-018-0109-9)
#
# We will generate trajectories from a latent Lorentz attractor and apply LFADS to recover the latent dynamic. Instead of using the original code (https://lfads.github.io/lfads-run-manager/) we will use tensorflow 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import scipy.io
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
import funs

# %% [markdown]
# # Sample from latent Lorenz attractor:

# %%
Time = 15  # 50 worse
neuron_num = 30
all_time =1500
datax = scipy.io.loadmat("spike30_sim_1500.mat")
y_data = datax["spike30_sim_1500"] 
traj = scipy.io.loadmat("trj30_sim_1500.mat")
traj = traj["trj30_sim_1500"]
print(traj.shape)
# Out:
# (1500, 2)

# %%
factor_dim = 10

NRep=int(all_time/Time)
output = np.zeros((NRep,Time,neuron_num))

for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    
output = output.astype('float32')

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
# Out:
# (15, 30)

# %%
for i in range(neuron_num):
    fig, ax = plt.subplots()
    mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
    fig.colorbar(mappable)
    plt.show()

# %%
plt.figure()
plt.imshow(output[0,:,:].T,aspect='auto')
plt.xlabel('time')
plt.ylabel('neuron')
plt.colorbar()
plt.show()

# %%
dataset = tf.data.Dataset.from_tensor_slices((output))
#print(dataset)
#dataset = dataset.shuffle(20, reshuffle_each_iteration=True)

# %% [markdown]
# # Autoencoder Model

# %%
tf.keras.backend.clear_session()

# %%
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
class Encoder(tf.keras.layers.Layer):
    """Maps Trajectory to a triplet (z_mean, z_log_var, z)."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)        
        self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(num_gru_unit,return_sequences=False), 
                                                       input_shape=(sequence_length, num_input_neuron))
        self.dense_mean = tf.keras.layers.Dense(latent_dim)
        self.dense_log_var = tf.keras.layers.Dense(latent_dim)
        self.sampling = Sampling()
        
    def call(self, inputs):
        x = self.bidir_gru(inputs)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

# %%
class Decoder(tf.keras.layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""
    def __init__(self,
                 latent_dim=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='decoder',
                 **kwargs):
        self.sequence_length = sequence_length
        super(Decoder, self).__init__(name=name, **kwargs)
        self.recurrent_decoder = tf.keras.layers.GRU(latent_dim,return_sequences=True)#,use_bias=False)
        self.linear_bottleneck = tf.keras.layers.Dense(num_factor, activation=None)
        self.dense_output = tf.keras.layers.Dense(256, activation='relu')
        self.dense_output2 = tf.keras.layers.Dense(num_input_neuron, activation=None)
        self.latent_dim=latent_dim
        
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        null_input = tf.zeros([batch_size,self.sequence_length,self.latent_dim])
        decoder_output = self.recurrent_decoder(null_input, initial_state=inputs)
        x = self.linear_bottleneck(decoder_output)
        x2 = self.dense_output(x)
        xo = self.dense_output2(x2)
        #xo = tf.exp(x2)
        return xo, x

# %%
class VariationalAutoEncoder(tf.keras.Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.encoder = Encoder(latent_dim=latent_dim,num_gru_unit=num_gru_unit,sequence_length=sequence_length,
                               num_input_neuron=num_input_neuron)
        self.decoder = Decoder(latent_dim=latent_dim, sequence_length=sequence_length,
                              num_input_neuron=num_input_neuron,num_factor=num_factor)
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)[0]
        # Add KL divergence regularization loss.
        kl_loss = - 0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        self.add_loss(kl_loss)
        return reconstructed
    def latent(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        latent = self.decoder(z)[1]
        return latent

# %%
BATCH_SIZE = 5 # 1 good , 5 not so good
batched_dataset = dataset.batch(BATCH_SIZE)
batched_dataset_test = dataset.batch(1)

# %%
vae = VariationalAutoEncoder(latent_dim=64,
                             num_gru_unit=32,
                             sequence_length=Time,
                             num_input_neuron=neuron_num,
                             num_factor=factor_dim)

# %% [markdown]
# # Train Model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=8e-4,clipvalue=200)
mse_loss_fn = tf.keras.losses.MeanSquaredError()
loss_metric = tf.keras.metrics.Mean()

# %% [markdown]
# #### Linearly scheduling on the Kullback–Leibler divergence penalty:
#
# We use a linearly increasing schedule on the Kullback–Leibler divergence penalty (as suggested [here](https://arxiv.org/pdf/1511.06349.pdf)) so that the optimization does not quickly (and pathologically) set the Kullback–Leibler divergence to 0

# %%
KL_penalty = np.linspace(0,1,10)

# %%
epochs = 1500

for i,kl_ in enumerate(KL_penalty):
    print(kl_,i)
    if i > 0:
        break
    # Iterate over epochs.
    for epoch in range(epochs):
        print('Start of epoch %d' % (epoch,),'i',i)

        # Iterate over the batches of the dataset.
        for step, x_batch_train in enumerate(batched_dataset):
            with tf.GradientTape() as tape:
                reconstructed = vae(x_batch_train)
                # Compute reconstruction loss
                loss = mse_loss_fn(x_batch_train, reconstructed)
                #print("loss",loss,"kl",sum(vae.losses))
                loss += kl_*sum(vae.losses)  # Add KLD regularization loss

            grads = tape.gradient(loss, vae.trainable_weights)
            optimizer.apply_gradients(zip(grads, vae.trainable_weights))
            loss_metric(loss)

            if step % 100 == 0:
                print('step %s: mean loss = %s' % (step, loss_metric.result().numpy()))
# Out:
# 0.0 0
# Start of epoch 0 i 0
# step 0: mean loss = 1.0004662
# Start of epoch 1 i 0
# step 0: mean loss = 1.0031312
# Start of epoch 2 i 0
# step 0: mean loss = 1.0001845
# Start of epoch 3 i 0
# step 0: mean loss = 0.99802935
# Start of epoch 4 i 0
# step 0: mean loss = 0.9944346
# Start of epoch 5 i 0
# step 0: mean loss = 0.9874428
# Start of epoch 6 i 0
# step 0: mean loss = 0.97828907
# Start of epoch 7 i 0
# step 0: mean loss = 0.96669656
# Start of epoch 8 i 0
# step 0: mean loss = 0.9552599
# Start of epoch 9 i 0
# step 0: mean loss = 0.9424624
# Start of epoch 10 i 0
# step 0: mean loss = 0.92894006
# Start of epoch 11 i 0
# step 0: mean loss = 0.91584253
# Start of epoch 12 i 0
# step 0: mean loss = 0.901865
# Start of epoch 13 i 0
# step 0: mean loss = 0.8883583
# Start of epoch 14 i 0
# step 0: mean loss = 0.8752712
# Start of epoch 15 i 0
# step 0: mean loss = 0.86305344
# Start of epoch 16 i 0
# step 0: mean loss = 0.85232383
# Start of epoch 17 i 0
# step 0: mean loss = 0.84159344
# Start of epoch 18 i 0
# step 0: mean loss = 0.8317251
# Start of epoch 19 i 0
# step 0: mean loss = 0.82184464
# Start of epoch 20 i 0
# step 0: mean loss = 0.81300306
# Start of epoch 21 i 0
# step 0: mean loss = 0.8045118
# Start of epoch 22 i 0
# step 0: mean loss = 0.79657155
# Start of epoch 23 i 0
# step 0: mean loss = 0.7887907
# Start of epoch 24 i 0
# step 0: mean loss = 0.7811833
# Start of epoch 25 i 0
# step 0: mean loss = 0.7736951
# Start of epoch 26 i 0
# step 0: mean loss = 0.76617277
# Start of epoch 27 i 0
# step 0: mean loss = 0.7590753
# Start of epoch 28 i 0
# step 0: mean loss = 0.7521958
# Start of epoch 29 i 0
# step 0: mean loss = 0.74546504
# Start of epoch 30 i 0
# step 0: mean loss = 0.7389985
# Start of epoch 31 i 0
# step 0: mean loss = 0.732775
# Start of epoch 32 i 0
# step 0: mean loss = 0.72706586
# Start of epoch 33 i 0
# step 0: mean loss = 0.7216824
# Start of epoch 34 i 0
# step 0: mean loss = 0.7164723
# Start of epoch 35 i 0
# step 0: mean loss = 0.71121097
# Start of epoch 36 i 0
# step 0: mean loss = 0.70602834
# Start of epoch 37 i 0
# step 0: mean loss = 0.7013276
# Start of epoch 38 i 0
# step 0: mean loss = 0.6967664
# Start of epoch 39 i 0
# step 0: mean loss = 0.6923999
# Start of epoch 40 i 0
# step 0: mean loss = 0.6882408
# Start of epoch 41 i 0
# step 0: mean loss = 0.6838009
# Start of epoch 42 i 0
# step 0: mean loss = 0.6792704
# Start of epoch 43 i 0
# step 0: mean loss = 0.6750375
# Start of epoch 44 i 0
# step 0: mean loss = 0.67065483
# Start of epoch 45 i 0
# step 0: mean loss = 0.666466
# Start of epoch 46 i 0
# step 0: mean loss = 0.66248226
# Start of epoch 47 i 0
# step 0: mean loss = 0.65864706
# Start of epoch 48 i 0
# step 0: mean loss = 0.65475297
# Start of epoch 49 i 0
# step 0: mean loss = 0.6508393
# Start of epoch 50 i 0
# step 0: mean loss = 0.64733094
# Start of epoch 51 i 0
# step 0: mean loss = 0.6440141
# Start of epoch 52 i 0
# step 0: mean loss = 0.64058435
# Start of epoch 53 i 0
# step 0: mean loss = 0.63716084
# Start of epoch 54 i 0
# step 0: mean loss = 0.6337453
# Start of epoch 55 i 0
# step 0: mean loss = 0.63035965
# Start of epoch 56 i 0
# step 0: mean loss = 0.6272174
# Start of epoch 57 i 0
# step 0: mean loss = 0.6241321
# Start of epoch 58 i 0
# step 0: mean loss = 0.62122947
# Start of epoch 59 i 0
# step 0: mean loss = 0.6182974
# Start of epoch 60 i 0
# step 0: mean loss = 0.6154667
# Start of epoch 61 i 0
# step 0: mean loss = 0.61280954
# Start of epoch 62 i 0
# step 0: mean loss = 0.6103477
# Start of epoch 63 i 0
# step 0: mean loss = 0.6079326
# Start of epoch 64 i 0
# step 0: mean loss = 0.6051543
# Start of epoch 65 i 0
# step 0: mean loss = 0.60247344
# Start of epoch 66 i 0
# step 0: mean loss = 0.60007995
# Start of epoch 67 i 0
# step 0: mean loss = 0.5976406
# Start of epoch 68 i 0
# step 0: mean loss = 0.5949098
# Start of epoch 69 i 0
# step 0: mean loss = 0.5922914
# Start of epoch 70 i 0
# step 0: mean loss = 0.58985424
# Start of epoch 71 i 0
# step 0: mean loss = 0.5873612
# Start of epoch 72 i 0
# step 0: mean loss = 0.5853158
# Start of epoch 73 i 0
# step 0: mean loss = 0.5834034
# Start of epoch 74 i 0
# step 0: mean loss = 0.5816277
# Start of epoch 75 i 0
# step 0: mean loss = 0.57936203
# Start of epoch 76 i 0
# step 0: mean loss = 0.57707447
# Start of epoch 77 i 0
# step 0: mean loss = 0.5749454
# Start of epoch 78 i 0
# step 0: mean loss = 0.57298887
# Start of epoch 79 i 0
# step 0: mean loss = 0.5707513
# Start of epoch 80 i 0
# step 0: mean loss = 0.5685434
# Start of epoch 81 i 0
# step 0: mean loss = 0.5663322
# Start of epoch 82 i 0
# step 0: mean loss = 0.5641591
# Start of epoch 83 i 0
# step 0: mean loss = 0.5622133
# Start of epoch 84 i 0
# step 0: mean loss = 0.5604286
# Start of epoch 85 i 0
# step 0: mean loss = 0.55873156
# Start of epoch 86 i 0
# step 0: mean loss = 0.55681914
# Start of epoch 87 i 0
# step 0: mean loss = 0.55476755
# Start of epoch 88 i 0
# step 0: mean loss = 0.55276674
# Start of epoch 89 i 0
# step 0: mean loss = 0.5507782
# Start of epoch 90 i 0
# step 0: mean loss = 0.5487956
# Start of epoch 91 i 0
# step 0: mean loss = 0.54702914
# Start of epoch 92 i 0
# step 0: mean loss = 0.54525703
# Start of epoch 93 i 0
# step 0: mean loss = 0.5435399
# Start of epoch 94 i 0
# step 0: mean loss = 0.5417154
# Start of epoch 95 i 0
# step 0: mean loss = 0.54014003
# Start of epoch 96 i 0
# step 0: mean loss = 0.5384809
# Start of epoch 97 i 0
# step 0: mean loss = 0.53673625
# Start of epoch 98 i 0
# step 0: mean loss = 0.5350695
# Start of epoch 99 i 0
# step 0: mean loss = 0.5334876
# Start of epoch 100 i 0
# step 0: mean loss = 0.53189325
# Start of epoch 101 i 0
# step 0: mean loss = 0.5302727
# Start of epoch 102 i 0
# step 0: mean loss = 0.52864057
# Start of epoch 103 i 0
# step 0: mean loss = 0.5270037
# Start of epoch 104 i 0
# step 0: mean loss = 0.5253269
# Start of epoch 105 i 0
# step 0: mean loss = 0.5237048
# Start of epoch 106 i 0
# step 0: mean loss = 0.5221925
# Start of epoch 107 i 0
# step 0: mean loss = 0.520768
# Start of epoch 108 i 0
# step 0: mean loss = 0.51926315
# Start of epoch 109 i 0
# step 0: mean loss = 0.51774216
# Start of epoch 110 i 0
# step 0: mean loss = 0.5163381
# Start of epoch 111 i 0
# step 0: mean loss = 0.51488155
# Start of epoch 112 i 0
# step 0: mean loss = 0.51346874
# Start of epoch 113 i 0
# step 0: mean loss = 0.5120446
# Start of epoch 114 i 0
# step 0: mean loss = 0.51056933
# Start of epoch 115 i 0
# step 0: mean loss = 0.5091059
# Start of epoch 116 i 0
# step 0: mean loss = 0.50779414
# Start of epoch 117 i 0
# step 0: mean loss = 0.5064909
# Start of epoch 118 i 0
# step 0: mean loss = 0.5051866
# Start of epoch 119 i 0
# step 0: mean loss = 0.50386924
# Start of epoch 120 i 0
# step 0: mean loss = 0.50250226
# Start of epoch 121 i 0
# step 0: mean loss = 0.5012261
# Start of epoch 122 i 0
# step 0: mean loss = 0.5000504
# Start of epoch 123 i 0
# step 0: mean loss = 0.49891153
# Start of epoch 124 i 0
# step 0: mean loss = 0.49770552
# Start of epoch 125 i 0
# step 0: mean loss = 0.4964533
# Start of epoch 126 i 0
# step 0: mean loss = 0.49514928
# Start of epoch 127 i 0
# step 0: mean loss = 0.49387723
# Start of epoch 128 i 0
# step 0: mean loss = 0.49260604
# Start of epoch 129 i 0
# step 0: mean loss = 0.4913674
# Start of epoch 130 i 0
# step 0: mean loss = 0.49011835
# Start of epoch 131 i 0
# step 0: mean loss = 0.48913783
# Start of epoch 132 i 0
# step 0: mean loss = 0.4882298
# Start of epoch 133 i 0
# step 0: mean loss = 0.48707798
# Start of epoch 134 i 0
# step 0: mean loss = 0.4858519
# Start of epoch 135 i 0
# step 0: mean loss = 0.4846462
# Start of epoch 136 i 0
# step 0: mean loss = 0.4834757
# Start of epoch 137 i 0
# step 0: mean loss = 0.48237592
# Start of epoch 138 i 0
# step 0: mean loss = 0.481335
# Start of epoch 139 i 0
# step 0: mean loss = 0.48024282
# Start of epoch 140 i 0
# step 0: mean loss = 0.4791394
# Start of epoch 141 i 0
# step 0: mean loss = 0.47802752
# Start of epoch 142 i 0
# step 0: mean loss = 0.47703898
# Start of epoch 143 i 0
# step 0: mean loss = 0.4761179
# Start of epoch 144 i 0
# step 0: mean loss = 0.47496867
# Start of epoch 145 i 0
# step 0: mean loss = 0.47387004
# Start of epoch 146 i 0
# step 0: mean loss = 0.47278
# Start of epoch 147 i 0
# step 0: mean loss = 0.47180495
# Start of epoch 148 i 0
# step 0: mean loss = 0.47086507
# Start of epoch 149 i 0
# step 0: mean loss = 0.46985528
# Start of epoch 150 i 0
# step 0: mean loss = 0.4687688
# Start of epoch 151 i 0
# step 0: mean loss = 0.46771625
# Start of epoch 152 i 0
# step 0: mean loss = 0.46675703
# Start of epoch 153 i 0
# step 0: mean loss = 0.46573195
# Start of epoch 154 i 0
# step 0: mean loss = 0.4647224
# Start of epoch 155 i 0
# step 0: mean loss = 0.4637223
# Start of epoch 156 i 0
# step 0: mean loss = 0.462735
# Start of epoch 157 i 0
# step 0: mean loss = 0.4617794
# Start of epoch 158 i 0
# step 0: mean loss = 0.4607697
# Start of epoch 159 i 0
# step 0: mean loss = 0.4597802
# Start of epoch 160 i 0
# step 0: mean loss = 0.4588509
# Start of epoch 161 i 0
# step 0: mean loss = 0.45798957
# Start of epoch 162 i 0
# step 0: mean loss = 0.45716414
# Start of epoch 163 i 0
# step 0: mean loss = 0.45632163
# Start of epoch 164 i 0
# step 0: mean loss = 0.45548803
# Start of epoch 165 i 0
# step 0: mean loss = 0.45463493
# Start of epoch 166 i 0
# step 0: mean loss = 0.4536942
# Start of epoch 167 i 0
# step 0: mean loss = 0.4528296
# Start of epoch 168 i 0
# step 0: mean loss = 0.452026
# Start of epoch 169 i 0
# step 0: mean loss = 0.45117295
# Start of epoch 170 i 0
# step 0: mean loss = 0.45032778
# Start of epoch 171 i 0
# step 0: mean loss = 0.44945
# Start of epoch 172 i 0
# step 0: mean loss = 0.44856232
# Start of epoch 173 i 0
# step 0: mean loss = 0.4476558
# Start of epoch 174 i 0
# step 0: mean loss = 0.44674337
# Start of epoch 175 i 0
# step 0: mean loss = 0.44587734
# Start of epoch 176 i 0
# step 0: mean loss = 0.44503716
# Start of epoch 177 i 0
# step 0: mean loss = 0.44424298
# Start of epoch 178 i 0
# step 0: mean loss = 0.4434686
# Start of epoch 179 i 0
# step 0: mean loss = 0.44267324
# Start of epoch 180 i 0
# step 0: mean loss = 0.44183582
# Start of epoch 181 i 0
# step 0: mean loss = 0.44100866
# Start of epoch 182 i 0
# step 0: mean loss = 0.4401512
# Start of epoch 183 i 0
# step 0: mean loss = 0.4393276
# Start of epoch 184 i 0
# step 0: mean loss = 0.43856102
# Start of epoch 185 i 0
# step 0: mean loss = 0.43782732
# Start of epoch 186 i 0
# step 0: mean loss = 0.4370524
# Start of epoch 187 i 0
# step 0: mean loss = 0.43628693
# Start of epoch 188 i 0
# step 0: mean loss = 0.43549997
# Start of epoch 189 i 0
# step 0: mean loss = 0.4346878
# Start of epoch 190 i 0
# step 0: mean loss = 0.43386647
# Start of epoch 191 i 0
# step 0: mean loss = 0.43308058
# Start of epoch 192 i 0
# step 0: mean loss = 0.43226564
# Start of epoch 193 i 0
# step 0: mean loss = 0.43147174
# Start of epoch 194 i 0
# step 0: mean loss = 0.43074915
# Start of epoch 195 i 0
# step 0: mean loss = 0.43003133
# Start of epoch 196 i 0
# step 0: mean loss = 0.4292933
# Start of epoch 197 i 0
# step 0: mean loss = 0.4285417
# Start of epoch 198 i 0
# step 0: mean loss = 0.42777568
# Start of epoch 199 i 0
# step 0: mean loss = 0.4270548
# Start of epoch 200 i 0
# step 0: mean loss = 0.4263422
# Start of epoch 201 i 0
# step 0: mean loss = 0.42565832
# Start of epoch 202 i 0
# step 0: mean loss = 0.42493567
# Start of epoch 203 i 0
# step 0: mean loss = 0.4242636
# Start of epoch 204 i 0
# step 0: mean loss = 0.4236356
# Start of epoch 205 i 0
# step 0: mean loss = 0.42293024
# Start of epoch 206 i 0
# step 0: mean loss = 0.4222226
# Start of epoch 207 i 0
# step 0: mean loss = 0.42150015
# Start of epoch 208 i 0
# step 0: mean loss = 0.42075533
# Start of epoch 209 i 0
# step 0: mean loss = 0.42001867
# Start of epoch 210 i 0
# step 0: mean loss = 0.4192985
# Start of epoch 211 i 0
# step 0: mean loss = 0.41859972
# Start of epoch 212 i 0
# step 0: mean loss = 0.4179466
# Start of epoch 213 i 0
# step 0: mean loss = 0.41731423
# Start of epoch 214 i 0
# step 0: mean loss = 0.41666317
# Start of epoch 215 i 0
# step 0: mean loss = 0.41603276
# Start of epoch 216 i 0
# step 0: mean loss = 0.41538346
# Start of epoch 217 i 0
# step 0: mean loss = 0.4147165
# Start of epoch 218 i 0
# step 0: mean loss = 0.41404513
# Start of epoch 219 i 0
# step 0: mean loss = 0.4133929
# Start of epoch 220 i 0
# step 0: mean loss = 0.41277695
# Start of epoch 221 i 0
# step 0: mean loss = 0.41215697
# Start of epoch 222 i 0
# step 0: mean loss = 0.41154206
# Start of epoch 223 i 0
# step 0: mean loss = 0.41094175
# Start of epoch 224 i 0
# step 0: mean loss = 0.41035512
# Start of epoch 225 i 0
# step 0: mean loss = 0.4097684
# Start of epoch 226 i 0
# step 0: mean loss = 0.40914565
# Start of epoch 227 i 0
# step 0: mean loss = 0.40849587
# Start of epoch 228 i 0
# step 0: mean loss = 0.40782812
# Start of epoch 229 i 0
# step 0: mean loss = 0.4071771
# Start of epoch 230 i 0
# step 0: mean loss = 0.40656433
# Start of epoch 231 i 0
# step 0: mean loss = 0.4059592
# Start of epoch 232 i 0
# step 0: mean loss = 0.40533614
# Start of epoch 233 i 0
# step 0: mean loss = 0.40474555
# Start of epoch 234 i 0
# step 0: mean loss = 0.40420473
# Start of epoch 235 i 0
# step 0: mean loss = 0.4037081
# Start of epoch 236 i 0
# step 0: mean loss = 0.40322423
# Start of epoch 237 i 0
# step 0: mean loss = 0.40265176
# Start of epoch 238 i 0
# step 0: mean loss = 0.40205985
# Start of epoch 239 i 0
# step 0: mean loss = 0.4015013
# Start of epoch 240 i 0
# step 0: mean loss = 0.40090686
# Start of epoch 241 i 0
# step 0: mean loss = 0.40032446
# Start of epoch 242 i 0
# step 0: mean loss = 0.3997377
# Start of epoch 243 i 0
# step 0: mean loss = 0.39915723
# Start of epoch 244 i 0
# step 0: mean loss = 0.39854923
# Start of epoch 245 i 0
# step 0: mean loss = 0.3979602
# Start of epoch 246 i 0
# step 0: mean loss = 0.39737827
# Start of epoch 247 i 0
# step 0: mean loss = 0.39683804
# Start of epoch 248 i 0
# step 0: mean loss = 0.39631766
# Start of epoch 249 i 0
# step 0: mean loss = 0.39577147
# Start of epoch 250 i 0
# step 0: mean loss = 0.3951788
# Start of epoch 251 i 0
# step 0: mean loss = 0.39459634
# Start of epoch 252 i 0
# step 0: mean loss = 0.39406097
# Start of epoch 253 i 0
# step 0: mean loss = 0.39358127
# Start of epoch 254 i 0
# step 0: mean loss = 0.3930795
# Start of epoch 255 i 0
# step 0: mean loss = 0.3925629
# Start of epoch 256 i 0
# step 0: mean loss = 0.39200705
# Start of epoch 257 i 0
# step 0: mean loss = 0.39147252
# Start of epoch 258 i 0
# step 0: mean loss = 0.39093664
# Start of epoch 259 i 0
# step 0: mean loss = 0.39042294
# Start of epoch 260 i 0
# step 0: mean loss = 0.3899206
# Start of epoch 261 i 0
# step 0: mean loss = 0.38941413
# Start of epoch 262 i 0
# step 0: mean loss = 0.38887322
# Start of epoch 263 i 0
# step 0: mean loss = 0.38834092
# Start of epoch 264 i 0
# step 0: mean loss = 0.38779697
# Start of epoch 265 i 0
# step 0: mean loss = 0.3873017
# Start of epoch 266 i 0
# step 0: mean loss = 0.38682583
# Start of epoch 267 i 0
# step 0: mean loss = 0.3863351
# Start of epoch 268 i 0
# step 0: mean loss = 0.38581792
# Start of epoch 269 i 0
# step 0: mean loss = 0.38529325
# Start of epoch 270 i 0
# step 0: mean loss = 0.38475725
# Start of epoch 271 i 0
# step 0: mean loss = 0.3842208
# Start of epoch 272 i 0
# step 0: mean loss = 0.3836958
# Start of epoch 273 i 0
# step 0: mean loss = 0.3831692
# Start of epoch 274 i 0
# step 0: mean loss = 0.38263732
# Start of epoch 275 i 0
# step 0: mean loss = 0.3821091
# Start of epoch 276 i 0
# step 0: mean loss = 0.38157672
# Start of epoch 277 i 0
# step 0: mean loss = 0.38104644
# Start of epoch 278 i 0
# step 0: mean loss = 0.38052598
# Start of epoch 279 i 0
# step 0: mean loss = 0.3800775
# Start of epoch 280 i 0
# step 0: mean loss = 0.3796966
# Start of epoch 281 i 0
# step 0: mean loss = 0.3792674
# Start of epoch 282 i 0
# step 0: mean loss = 0.37878403
# Start of epoch 283 i 0
# step 0: mean loss = 0.37828815
# Start of epoch 284 i 0
# step 0: mean loss = 0.37779826
# Start of epoch 285 i 0
# step 0: mean loss = 0.37735888
# Start of epoch 286 i 0
# step 0: mean loss = 0.3769395
# Start of epoch 287 i 0
# step 0: mean loss = 0.37648454
# Start of epoch 288 i 0
# step 0: mean loss = 0.3760019
# Start of epoch 289 i 0
# step 0: mean loss = 0.375529
# Start of epoch 290 i 0
# step 0: mean loss = 0.3750477
# Start of epoch 291 i 0
# step 0: mean loss = 0.3746462
# Start of epoch 292 i 0
# step 0: mean loss = 0.37426102
# Start of epoch 293 i 0
# step 0: mean loss = 0.37381226
# Start of epoch 294 i 0
# step 0: mean loss = 0.37333173
# Start of epoch 295 i 0
# step 0: mean loss = 0.37286583
# Start of epoch 296 i 0
# step 0: mean loss = 0.3723898
# Start of epoch 297 i 0
# step 0: mean loss = 0.37190798
# Start of epoch 298 i 0
# step 0: mean loss = 0.37144434
# Start of epoch 299 i 0
# step 0: mean loss = 0.37100187
# Start of epoch 300 i 0
# step 0: mean loss = 0.3705564
# Start of epoch 301 i 0
# step 0: mean loss = 0.3701111
# Start of epoch 302 i 0
# step 0: mean loss = 0.36965743
# Start of epoch 303 i 0
# step 0: mean loss = 0.3692017
# Start of epoch 304 i 0
# step 0: mean loss = 0.36873975
# Start of epoch 305 i 0
# step 0: mean loss = 0.36827514
# Start of epoch 306 i 0
# step 0: mean loss = 0.3677925
# Start of epoch 307 i 0
# step 0: mean loss = 0.367321
# Start of epoch 308 i 0
# step 0: mean loss = 0.3668462
# Start of epoch 309 i 0
# step 0: mean loss = 0.36638477
# Start of epoch 310 i 0
# step 0: mean loss = 0.36593887
# Start of epoch 311 i 0
# step 0: mean loss = 0.3655261
# Start of epoch 312 i 0
# step 0: mean loss = 0.36512724
# Start of epoch 313 i 0
# step 0: mean loss = 0.36475086
# Start of epoch 314 i 0
# step 0: mean loss = 0.36433303
# Start of epoch 315 i 0
# step 0: mean loss = 0.3639058
# Start of epoch 316 i 0
# step 0: mean loss = 0.36346266
# Start of epoch 317 i 0
# step 0: mean loss = 0.3630416
# Start of epoch 318 i 0
# step 0: mean loss = 0.36263028
# Start of epoch 319 i 0
# step 0: mean loss = 0.36224595
# Start of epoch 320 i 0
# step 0: mean loss = 0.36187512
# Start of epoch 321 i 0
# step 0: mean loss = 0.36150342
# Start of epoch 322 i 0
# step 0: mean loss = 0.3610911
# Start of epoch 323 i 0
# step 0: mean loss = 0.36065933
# Start of epoch 324 i 0
# step 0: mean loss = 0.36022457
# Start of epoch 325 i 0
# step 0: mean loss = 0.35980332
# Start of epoch 326 i 0
# step 0: mean loss = 0.35938358
# Start of epoch 327 i 0
# step 0: mean loss = 0.35900468
# Start of epoch 328 i 0
# step 0: mean loss = 0.3586418
# Start of epoch 329 i 0
# step 0: mean loss = 0.3582633
# Start of epoch 330 i 0
# step 0: mean loss = 0.35785827
# Start of epoch 331 i 0
# step 0: mean loss = 0.3574516
# Start of epoch 332 i 0
# step 0: mean loss = 0.3570545
# Start of epoch 333 i 0
# step 0: mean loss = 0.35666782
# Start of epoch 334 i 0
# step 0: mean loss = 0.356285
# Start of epoch 335 i 0
# step 0: mean loss = 0.35590747
# Start of epoch 336 i 0
# step 0: mean loss = 0.3555535
# Start of epoch 337 i 0
# step 0: mean loss = 0.3551946
# Start of epoch 338 i 0
# step 0: mean loss = 0.35480392
# Start of epoch 339 i 0
# step 0: mean loss = 0.35440052
# Start of epoch 340 i 0
# step 0: mean loss = 0.3539929
# Start of epoch 341 i 0
# step 0: mean loss = 0.35358652
# Start of epoch 342 i 0
# step 0: mean loss = 0.35318872
# Start of epoch 343 i 0
# step 0: mean loss = 0.35281163
# Start of epoch 344 i 0
# step 0: mean loss = 0.3524282
# Start of epoch 345 i 0
# step 0: mean loss = 0.3520599
# Start of epoch 346 i 0
# step 0: mean loss = 0.3517089
# Start of epoch 347 i 0
# step 0: mean loss = 0.3513788
# Start of epoch 348 i 0
# step 0: mean loss = 0.3510411
# Start of epoch 349 i 0
# step 0: mean loss = 0.35067484
# Start of epoch 350 i 0
# step 0: mean loss = 0.35027534
# Start of epoch 351 i 0
# step 0: mean loss = 0.3498628
# Start of epoch 352 i 0
# step 0: mean loss = 0.3494491
# Start of epoch 353 i 0
# step 0: mean loss = 0.34904027
# Start of epoch 354 i 0
# step 0: mean loss = 0.34863296
# Start of epoch 355 i 0
# step 0: mean loss = 0.34823933
# Start of epoch 356 i 0
# step 0: mean loss = 0.34786665
# Start of epoch 357 i 0
# step 0: mean loss = 0.34751076
# Start of epoch 358 i 0
# step 0: mean loss = 0.3471357
# Start of epoch 359 i 0
# step 0: mean loss = 0.34676853
# Start of epoch 360 i 0
# step 0: mean loss = 0.34638873
# Start of epoch 361 i 0
# step 0: mean loss = 0.3460077
# Start of epoch 362 i 0
# step 0: mean loss = 0.34562197
# Start of epoch 363 i 0
# step 0: mean loss = 0.3452339
# Start of epoch 364 i 0
# step 0: mean loss = 0.34484798
# Start of epoch 365 i 0
# step 0: mean loss = 0.34448272
# Start of epoch 366 i 0
# step 0: mean loss = 0.3441402
# Start of epoch 367 i 0
# step 0: mean loss = 0.34381533
# Start of epoch 368 i 0
# step 0: mean loss = 0.3434738
# Start of epoch 369 i 0
# step 0: mean loss = 0.34314185
# Start of epoch 370 i 0
# step 0: mean loss = 0.34280068
# Start of epoch 371 i 0
# step 0: mean loss = 0.3424786
# Start of epoch 372 i 0
# step 0: mean loss = 0.3421568
# Start of epoch 373 i 0
# step 0: mean loss = 0.34182078
# Start of epoch 374 i 0
# step 0: mean loss = 0.3414599
# Start of epoch 375 i 0
# step 0: mean loss = 0.341103
# Start of epoch 376 i 0
# step 0: mean loss = 0.34076327
# Start of epoch 377 i 0
# step 0: mean loss = 0.34045255
# Start of epoch 378 i 0
# step 0: mean loss = 0.3401406
# Start of epoch 379 i 0
# step 0: mean loss = 0.33983427
# Start of epoch 380 i 0
# step 0: mean loss = 0.33950317
# Start of epoch 381 i 0
# step 0: mean loss = 0.33916605
# Start of epoch 382 i 0
# step 0: mean loss = 0.3388118
# Start of epoch 383 i 0
# step 0: mean loss = 0.3384708
# Start of epoch 384 i 0
# step 0: mean loss = 0.33814016
# Start of epoch 385 i 0
# step 0: mean loss = 0.33783424
# Start of epoch 386 i 0
# step 0: mean loss = 0.33752665
# Start of epoch 387 i 0
# step 0: mean loss = 0.33720213
# Start of epoch 388 i 0
# step 0: mean loss = 0.33686137
# Start of epoch 389 i 0
# step 0: mean loss = 0.33651143
# Start of epoch 390 i 0
# step 0: mean loss = 0.33614984
# Start of epoch 391 i 0
# step 0: mean loss = 0.3357885
# Start of epoch 392 i 0
# step 0: mean loss = 0.33544022
# Start of epoch 393 i 0
# step 0: mean loss = 0.33513066
# Start of epoch 394 i 0
# step 0: mean loss = 0.33482403
# Start of epoch 395 i 0
# step 0: mean loss = 0.33448467
# Start of epoch 396 i 0
# step 0: mean loss = 0.33413485
# Start of epoch 397 i 0
# step 0: mean loss = 0.33378312
# Start of epoch 398 i 0
# step 0: mean loss = 0.33342952
# Start of epoch 399 i 0
# step 0: mean loss = 0.33309805
# Start of epoch 400 i 0
# step 0: mean loss = 0.33278686
# Start of epoch 401 i 0
# step 0: mean loss = 0.33249095
# Start of epoch 402 i 0
# step 0: mean loss = 0.33218193
# Start of epoch 403 i 0
# step 0: mean loss = 0.33187714
# Start of epoch 404 i 0
# step 0: mean loss = 0.33155447
# Start of epoch 405 i 0
# step 0: mean loss = 0.33123007
# Start of epoch 406 i 0
# step 0: mean loss = 0.33091894
# Start of epoch 407 i 0
# step 0: mean loss = 0.3306387
# Start of epoch 408 i 0
# step 0: mean loss = 0.3303554
# Start of epoch 409 i 0
# step 0: mean loss = 0.3300476
# Start of epoch 410 i 0
# step 0: mean loss = 0.32972294
# Start of epoch 411 i 0
# step 0: mean loss = 0.32939726
# Start of epoch 412 i 0
# step 0: mean loss = 0.32907975
# Start of epoch 413 i 0
# step 0: mean loss = 0.32876146
# Start of epoch 414 i 0
# step 0: mean loss = 0.32843614
# Start of epoch 415 i 0
# step 0: mean loss = 0.3281166
# Start of epoch 416 i 0
# step 0: mean loss = 0.32779965
# Start of epoch 417 i 0
# step 0: mean loss = 0.32748702
# Start of epoch 418 i 0
# step 0: mean loss = 0.32716343
# Start of epoch 419 i 0
# step 0: mean loss = 0.32683647
# Start of epoch 420 i 0
# step 0: mean loss = 0.32651237
# Start of epoch 421 i 0
# step 0: mean loss = 0.3262168
# Start of epoch 422 i 0
# step 0: mean loss = 0.32592088
# Start of epoch 423 i 0
# step 0: mean loss = 0.3256425
# Start of epoch 424 i 0
# step 0: mean loss = 0.3253464
# Start of epoch 425 i 0
# step 0: mean loss = 0.32505187
# Start of epoch 426 i 0
# step 0: mean loss = 0.32475567
# Start of epoch 427 i 0
# step 0: mean loss = 0.324468
# Start of epoch 428 i 0
# step 0: mean loss = 0.32416016
# Start of epoch 429 i 0
# step 0: mean loss = 0.32383892
# Start of epoch 430 i 0
# step 0: mean loss = 0.3235158
# Start of epoch 431 i 0
# step 0: mean loss = 0.32318932
# Start of epoch 432 i 0
# step 0: mean loss = 0.3228604
# Start of epoch 433 i 0
# step 0: mean loss = 0.32253456
# Start of epoch 434 i 0
# step 0: mean loss = 0.3222122
# Start of epoch 435 i 0
# step 0: mean loss = 0.3219
# Start of epoch 436 i 0
# step 0: mean loss = 0.32160613
# Start of epoch 437 i 0
# step 0: mean loss = 0.32132867
# Start of epoch 438 i 0
# step 0: mean loss = 0.32103288
# Start of epoch 439 i 0
# step 0: mean loss = 0.32073772
# Start of epoch 440 i 0
# step 0: mean loss = 0.32043582
# Start of epoch 441 i 0
# step 0: mean loss = 0.32013407
# Start of epoch 442 i 0
# step 0: mean loss = 0.31983736
# Start of epoch 443 i 0
# step 0: mean loss = 0.31957996
# Start of epoch 444 i 0
# step 0: mean loss = 0.31935954
# Start of epoch 445 i 0
# step 0: mean loss = 0.31908166
# Start of epoch 446 i 0
# step 0: mean loss = 0.31878126
# Start of epoch 447 i 0
# step 0: mean loss = 0.31848553
# Start of epoch 448 i 0
# step 0: mean loss = 0.31819963
# Start of epoch 449 i 0
# step 0: mean loss = 0.31790373
# Start of epoch 450 i 0
# step 0: mean loss = 0.31758732
# Start of epoch 451 i 0
# step 0: mean loss = 0.3172732
# Start of epoch 452 i 0
# step 0: mean loss = 0.31696662
# Start of epoch 453 i 0
# step 0: mean loss = 0.3166696
# Start of epoch 454 i 0
# step 0: mean loss = 0.31636778
# Start of epoch 455 i 0
# step 0: mean loss = 0.3160795
# Start of epoch 456 i 0
# step 0: mean loss = 0.315784
# Start of epoch 457 i 0
# step 0: mean loss = 0.31551036
# Start of epoch 458 i 0
# step 0: mean loss = 0.31524172
# Start of epoch 459 i 0
# step 0: mean loss = 0.31497952
# Start of epoch 460 i 0
# step 0: mean loss = 0.31469688
# Start of epoch 461 i 0
# step 0: mean loss = 0.31442237
# Start of epoch 462 i 0
# step 0: mean loss = 0.31416497
# Start of epoch 463 i 0
# step 0: mean loss = 0.31390953
# Start of epoch 464 i 0
# step 0: mean loss = 0.3136352
# Start of epoch 465 i 0
# step 0: mean loss = 0.31335136
# Start of epoch 466 i 0
# step 0: mean loss = 0.31306627
# Start of epoch 467 i 0
# step 0: mean loss = 0.31278953
# Start of epoch 468 i 0
# step 0: mean loss = 0.3125256
# Start of epoch 469 i 0
# step 0: mean loss = 0.3122799
# Start of epoch 470 i 0
# step 0: mean loss = 0.31201038
# Start of epoch 471 i 0
# step 0: mean loss = 0.3117584
# Start of epoch 472 i 0
# step 0: mean loss = 0.311507
# Start of epoch 473 i 0
# step 0: mean loss = 0.31124568
# Start of epoch 474 i 0
# step 0: mean loss = 0.31096587
# Start of epoch 475 i 0
# step 0: mean loss = 0.3106799
# Start of epoch 476 i 0
# step 0: mean loss = 0.31041574
# Start of epoch 477 i 0
# step 0: mean loss = 0.3101805
# Start of epoch 478 i 0
# step 0: mean loss = 0.30994242
# Start of epoch 479 i 0
# step 0: mean loss = 0.30974635
# Start of epoch 480 i 0
# step 0: mean loss = 0.30950683
# Start of epoch 481 i 0
# step 0: mean loss = 0.30929044
# Start of epoch 482 i 0
# step 0: mean loss = 0.3090624
# Start of epoch 483 i 0
# step 0: mean loss = 0.308813
# Start of epoch 484 i 0
# step 0: mean loss = 0.30856276
# Start of epoch 485 i 0
# step 0: mean loss = 0.30830425
# Start of epoch 486 i 0
# step 0: mean loss = 0.3080582
# Start of epoch 487 i 0
# step 0: mean loss = 0.30781424
# Start of epoch 488 i 0
# step 0: mean loss = 0.30760282
# Start of epoch 489 i 0
# step 0: mean loss = 0.30736527
# Start of epoch 490 i 0
# step 0: mean loss = 0.3071174
# Start of epoch 491 i 0
# step 0: mean loss = 0.30684742
# Start of epoch 492 i 0
# step 0: mean loss = 0.30657047
# Start of epoch 493 i 0
# step 0: mean loss = 0.30628306
# Start of epoch 494 i 0
# step 0: mean loss = 0.3059939
# Start of epoch 495 i 0
# step 0: mean loss = 0.30570385
# Start of epoch 496 i 0
# step 0: mean loss = 0.3054241
# Start of epoch 497 i 0
# step 0: mean loss = 0.30515194
# Start of epoch 498 i 0
# step 0: mean loss = 0.30487704
# Start of epoch 499 i 0
# step 0: mean loss = 0.30459175
# Start of epoch 500 i 0
# step 0: mean loss = 0.30430514
# Start of epoch 501 i 0
# step 0: mean loss = 0.30402943
# Start of epoch 502 i 0
# step 0: mean loss = 0.30377173
# Start of epoch 503 i 0
# step 0: mean loss = 0.30351418
# Start of epoch 504 i 0
# step 0: mean loss = 0.3032591
# Start of epoch 505 i 0
# step 0: mean loss = 0.3029878
# Start of epoch 506 i 0
# step 0: mean loss = 0.3027187
# Start of epoch 507 i 0
# step 0: mean loss = 0.30245548
# Start of epoch 508 i 0
# step 0: mean loss = 0.30219194
# Start of epoch 509 i 0
# step 0: mean loss = 0.30193672
# Start of epoch 510 i 0
# step 0: mean loss = 0.3016846
# Start of epoch 511 i 0
# step 0: mean loss = 0.30144447
# Start of epoch 512 i 0
# step 0: mean loss = 0.30119875
# Start of epoch 513 i 0
# step 0: mean loss = 0.30096447
# Start of epoch 514 i 0
# step 0: mean loss = 0.30074096
# Start of epoch 515 i 0
# step 0: mean loss = 0.30052626
# Start of epoch 516 i 0
# step 0: mean loss = 0.30031374
# Start of epoch 517 i 0
# step 0: mean loss = 0.30010372
# Start of epoch 518 i 0
# step 0: mean loss = 0.29991025
# Start of epoch 519 i 0
# step 0: mean loss = 0.29968405
# Start of epoch 520 i 0
# step 0: mean loss = 0.29945815
# Start of epoch 521 i 0
# step 0: mean loss = 0.29924062
# Start of epoch 522 i 0
# step 0: mean loss = 0.2990124
# Start of epoch 523 i 0
# step 0: mean loss = 0.29877537
# Start of epoch 524 i 0
# step 0: mean loss = 0.2985371
# Start of epoch 525 i 0
# step 0: mean loss = 0.2982871
# Start of epoch 526 i 0
# step 0: mean loss = 0.29804173
# Start of epoch 527 i 0
# step 0: mean loss = 0.29778284
# Start of epoch 528 i 0
# step 0: mean loss = 0.2975259
# Start of epoch 529 i 0
# step 0: mean loss = 0.29726553
# Start of epoch 530 i 0
# step 0: mean loss = 0.29700878
# Start of epoch 531 i 0
# step 0: mean loss = 0.29676947
# Start of epoch 532 i 0
# step 0: mean loss = 0.29652855
# Start of epoch 533 i 0
# step 0: mean loss = 0.29626867
# Start of epoch 534 i 0
# step 0: mean loss = 0.29600295
# Start of epoch 535 i 0
# step 0: mean loss = 0.2957411
# Start of epoch 536 i 0
# step 0: mean loss = 0.2955002
# Start of epoch 537 i 0
# step 0: mean loss = 0.29526204
# Start of epoch 538 i 0
# step 0: mean loss = 0.29500565
# Start of epoch 539 i 0
# step 0: mean loss = 0.29474816
# Start of epoch 540 i 0
# step 0: mean loss = 0.2945116
# Start of epoch 541 i 0
# step 0: mean loss = 0.2942923
# Start of epoch 542 i 0
# step 0: mean loss = 0.29407927
# Start of epoch 543 i 0
# step 0: mean loss = 0.293864
# Start of epoch 544 i 0
# Start of epoch 740 i 0
# step 0: mean loss = 0.2565962
# Start of epoch 741 i 0
# step 0: mean loss = 0.25646275
# Start of epoch 742 i 0
# step 0: mean loss = 0.25632238
# Start of epoch 743 i 0
# step 0: mean loss = 0.25617906
# Start of epoch 744 i 0
# step 0: mean loss = 0.25602126
# Start of epoch 745 i 0
# step 0: mean loss = 0.25585946
# Start of epoch 746 i 0
# step 0: mean loss = 0.2556934
# Start of epoch 747 i 0
# step 0: mean loss = 0.25553346
# Start of epoch 748 i 0
# step 0: mean loss = 0.25536588
# Start of epoch 749 i 0
# step 0: mean loss = 0.25519788
# Start of epoch 750 i 0
# step 0: mean loss = 0.25502625
# Start of epoch 751 i 0
# step 0: mean loss = 0.25485706
# Start of epoch 752 i 0
# step 0: mean loss = 0.2546919
# Start of epoch 753 i 0
# step 0: mean loss = 0.25453457
# Start of epoch 754 i 0
# step 0: mean loss = 0.2543695
# Start of epoch 755 i 0
# step 0: mean loss = 0.25420257
# Start of epoch 756 i 0
# step 0: mean loss = 0.25403145
# Start of epoch 757 i 0
# step 0: mean loss = 0.25386056
# Start of epoch 758 i 0
# step 0: mean loss = 0.25369337
# Start of epoch 759 i 0
# step 0: mean loss = 0.2535327
# Start of epoch 760 i 0
# step 0: mean loss = 0.25336447
# Start of epoch 761 i 0
# step 0: mean loss = 0.25319397
# Start of epoch 762 i 0
# step 0: mean loss = 0.25302252
# Start of epoch 763 i 0
# step 0: mean loss = 0.25285232
# Start of epoch 764 i 0
# step 0: mean loss = 0.25268617
# Start of epoch 765 i 0
# step 0: mean loss = 0.2525317
# Start of epoch 766 i 0
# step 0: mean loss = 0.252383
# Start of epoch 767 i 0
# step 0: mean loss = 0.25223398
# Start of epoch 768 i 0
# step 0: mean loss = 0.25208947
# Start of epoch 769 i 0
# step 0: mean loss = 0.25192666
# Start of epoch 770 i 0
# step 0: mean loss = 0.2517638
# Start of epoch 771 i 0
# step 0: mean loss = 0.2515984
# Start of epoch 772 i 0
# step 0: mean loss = 0.2514346
# Start of epoch 773 i 0
# step 0: mean loss = 0.25127488
# Start of epoch 774 i 0
# step 0: mean loss = 0.25110963
# Start of epoch 775 i 0
# step 0: mean loss = 0.25094205
# Start of epoch 776 i 0
# step 0: mean loss = 0.25077435
# Start of epoch 777 i 0
# step 0: mean loss = 0.2506135
# Start of epoch 778 i 0
# step 0: mean loss = 0.25045872
# Start of epoch 779 i 0
# step 0: mean loss = 0.25030866
# Start of epoch 780 i 0
# step 0: mean loss = 0.25016186
# Start of epoch 781 i 0
# step 0: mean loss = 0.25001073
# Start of epoch 782 i 0
# step 0: mean loss = 0.24986011
# Start of epoch 783 i 0
# step 0: mean loss = 0.24969865
# Start of epoch 784 i 0
# step 0: mean loss = 0.24953164
# Start of epoch 785 i 0
# step 0: mean loss = 0.24936613
# Start of epoch 786 i 0
# step 0: mean loss = 0.24920109
# Start of epoch 787 i 0
# step 0: mean loss = 0.2490338
# Start of epoch 788 i 0
# step 0: mean loss = 0.24886434
# Start of epoch 1483 i 0
# step 0: mean loss = 0.17920884
# Start of epoch 1484 i 0
# step 0: mean loss = 0.17915317
# Start of epoch 1485 i 0
# step 0: mean loss = 0.17909586
# Start of epoch 1486 i 0
# step 0: mean loss = 0.17903644
# Start of epoch 1487 i 0
# step 0: mean loss = 0.17897342
# Start of epoch 1488 i 0
# step 0: mean loss = 0.17890805
# Start of epoch 1489 i 0
# step 0: mean loss = 0.17884116
# Start of epoch 1490 i 0
# step 0: mean loss = 0.17877223
# Start of epoch 1491 i 0
# step 0: mean loss = 0.17870232
# Start of epoch 1492 i 0
# step 0: mean loss = 0.17863125
# Start of epoch 1493 i 0
# step 0: mean loss = 0.17856121
# Start of epoch 1494 i 0
# step 0: mean loss = 0.17849118
# Start of epoch 1495 i 0
# step 0: mean loss = 0.17842127
# Start of epoch 1496 i 0
# step 0: mean loss = 0.17835136
# Start of epoch 1497 i 0
# step 0: mean loss = 0.1782821
# Start of epoch 1498 i 0
# step 0: mean loss = 0.17821194
# Start of epoch 1499 i 0
# step 0: mean loss = 0.17814344
# 0.1111111111111111 1

# %%
qy_mean_est = np.zeros((1500,neuron_num))
for step, x_batch_train in enumerate(batched_dataset_test):
    qy_mean_est[Time*step:Time*(step+1),:] = vae(x_batch_train)
for i in range(neuron_num):
    plt.figure()
    plt.ylim(-2,20)
    plt.plot(y_data[:,i],"k",linewidth = 2)
    plt.plot(qy_mean_est[:,i],"r",linewidth = 1)
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
qz_mean_est = np.zeros((all_time,factor_dim))
for step, x_batch_train in enumerate(batched_dataset_test):
    qz_mean_est[Time*step:Time*(step+1),:] = vae.latent(x_batch_train)
wgt = np.linalg.lstsq(qz_mean_est-qz_mean_est.mean(), traj-traj.mean())[0] 
qz_mean_est = np.dot(qz_mean_est,wgt)
qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # Evaluate Quality of reconstruction

# %%
#plt.plot(qz_mean_est[:,0],qz_mean_est[:,1])
#qz_est_c = qz_mean_est - qz_mean_est.mean(axis=0)
#qz_est_norm = qz_est_c/np.linalg.norm(qz_est_c)
#qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))

z_true_c = traj - traj.mean(axis=0)
z_true_norm = z_true_c/np.linalg.norm(z_true_c)
R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
fig = plt.figure(figsize=(12,12))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure()
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
