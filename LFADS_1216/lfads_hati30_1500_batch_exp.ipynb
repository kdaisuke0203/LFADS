# %% [markdown]
# Our aim is to reproduce an example from the paper:
#
# [Inferring single-trial neural population dynamics using sequential auto-encoders](https://www.nature.com/articles/s41592-018-0109-9)
#
# We will generate trajectories from a latent Lorentz attractor and apply LFADS to recover the latent dynamic. Instead of using the original code (https://lfads.github.io/lfads-run-manager/) we will use tensorflow 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import scipy.io
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
import funs

# %% [markdown]
# # Sample from latent Lorenz attractor:

# %%
Time = 15
neuron_num = 30
datax = scipy.io.loadmat("spike30_sim_1500.mat")
y_data = datax["spike30_sim_1500"] 
traj = scipy.io.loadmat("trj30_sim_1500.mat")
traj = traj["trj30_sim_1500"]

# %%
factor_dim = 20
all_time =1500
NRep=int(all_time/Time)
output = np.zeros((NRep,Time,neuron_num))

for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    
output = output.astype('float32')

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
# Out:
# (15, 30)

# %%
plt.figure()
plt.imshow(output[0,:,:].T,aspect='auto')
plt.xlabel('time')
plt.ylabel('neuron')
plt.colorbar()
plt.show()

# %%
dataset = tf.data.Dataset.from_tensor_slices((output))
#print(dataset)
#dataset = dataset.shuffle(20, reshuffle_each_iteration=True)

# %% [markdown]
# # Autoencoder Model

# %%
tf.keras.backend.clear_session()

# %%
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
class Encoder(tf.keras.layers.Layer):
    """Maps Trajectory to a triplet (z_mean, z_log_var, z)."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)        
        self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(num_gru_unit,return_sequences=False), 
                                                       input_shape=(sequence_length, num_input_neuron))
        self.dense_mean = tf.keras.layers.Dense(latent_dim)
        self.dense_log_var = tf.keras.layers.Dense(latent_dim)
        self.sampling = Sampling()
        
    def call(self, inputs):
        x = self.bidir_gru(inputs)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

# %%
class Decoder(tf.keras.layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""
    def __init__(self,
                 latent_dim=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='decoder',
                 **kwargs):
        self.sequence_length = sequence_length
        super(Decoder, self).__init__(name=name, **kwargs)
        self.recurrent_decoder = tf.keras.layers.GRU(latent_dim,return_sequences=True)#,use_bias=False)
        self.linear_bottleneck = tf.keras.layers.Dense(num_factor, activation=None)
        self.dense_output = tf.keras.layers.Dense(512, activation='relu') #tanh bad
        self.dense_output2 = tf.keras.layers.Dense(num_input_neuron, activation=None)
        self.latent_dim=latent_dim
        
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        null_input = tf.zeros([batch_size,self.sequence_length,self.latent_dim])
        decoder_output = self.recurrent_decoder(null_input, initial_state=inputs)
        x = self.linear_bottleneck(decoder_output)
        x2 = self.dense_output(x)
        xo = self.dense_output2(x2)
        #xo = tf.exp(xo)
        return xo, x

# %%
class VariationalAutoEncoder(tf.keras.Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.encoder = Encoder(latent_dim=latent_dim,num_gru_unit=num_gru_unit,sequence_length=sequence_length,
                               num_input_neuron=num_input_neuron)
        self.decoder = Decoder(latent_dim=latent_dim, sequence_length=sequence_length,
                              num_input_neuron=num_input_neuron,num_factor=num_factor)
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)[0]
        # Add KL divergence regularization loss.
        kl_loss = - 0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        self.add_loss(kl_loss)
        return reconstructed
    def latent(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        latent = self.decoder(z)[1]
        return latent

# %%
BATCH_SIZE = 1
batched_dataset = dataset.batch(BATCH_SIZE)

# %%
vae = VariationalAutoEncoder(latent_dim=64,
                             num_gru_unit=32,
                             sequence_length=Time,
                             num_input_neuron=neuron_num,
                             num_factor=factor_dim)

# %% [markdown]
# # Train Model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=8e-4,clipvalue=200)
mse_loss_fn = tf.keras.losses.MeanSquaredError()
loss_metric = tf.keras.metrics.Mean()

# %% [markdown]
# #### Linearly scheduling on the Kullback–Leibler divergence penalty:
#
# We use a linearly increasing schedule on the Kullback–Leibler divergence penalty (as suggested [here](https://arxiv.org/pdf/1511.06349.pdf)) so that the optimization does not quickly (and pathologically) set the Kullback–Leibler divergence to 0

# %%
KL_penalty = np.linspace(0,1,10)

# %%
epochs = 2500

for i,kl_ in enumerate(KL_penalty):
    print(kl_,i)
    if i > 0:
        break
    # Iterate over epochs.
    for epoch in range(epochs):
        print('Start of epoch %d' % (epoch,),'i',i)

        # Iterate over the batches of the dataset.
        for step, x_batch_train in enumerate(batched_dataset):
            with tf.GradientTape() as tape:
                reconstructed = vae(x_batch_train)
                # Compute reconstruction loss
                loss = mse_loss_fn(x_batch_train, reconstructed)
                #print("loss",loss,"kl",sum(vae.losses))
                loss += kl_*sum(vae.losses)  # Add KLD regularization loss

            grads = tape.gradient(loss, vae.trainable_weights)
            optimizer.apply_gradients(zip(grads, vae.trainable_weights))
            loss_metric(loss)

            if step % 100 == 0:
                print('step %s: mean loss = %s' % (step, loss_metric.result().numpy()))
# Out:
# 0.0 0
# Start of epoch 0 i 0
# step 0: mean loss = 1.8463072
# Start of epoch 1 i 0
# step 0: mean loss = 1.0164375
# Start of epoch 2 i 0
# step 0: mean loss = 1.00173
# Start of epoch 3 i 0
# step 0: mean loss = 0.9885371
# Start of epoch 4 i 0
# step 0: mean loss = 0.9679728
# Start of epoch 5 i 0
# step 0: mean loss = 0.94589156
# Start of epoch 6 i 0
# step 0: mean loss = 0.92072964
# Start of epoch 7 i 0
# step 0: mean loss = 0.8994622
# Start of epoch 8 i 0
# step 0: mean loss = 0.8771887
# Start of epoch 9 i 0
# step 0: mean loss = 0.860041
# Start of epoch 10 i 0
# step 0: mean loss = 0.84319913
# Start of epoch 11 i 0
# step 0: mean loss = 0.82790434
# Start of epoch 12 i 0
# step 0: mean loss = 0.8140935
# Start of epoch 13 i 0
# step 0: mean loss = 0.8017604
# Start of epoch 14 i 0
# step 0: mean loss = 0.79183406
# Start of epoch 15 i 0
# step 0: mean loss = 0.7841596
# Start of epoch 16 i 0
# step 0: mean loss = 0.7729254
# Start of epoch 17 i 0
# step 0: mean loss = 0.7645122
# Start of epoch 18 i 0
# step 0: mean loss = 0.75449747
# Start of epoch 19 i 0
# step 0: mean loss = 0.7441183
# Start of epoch 20 i 0
# step 0: mean loss = 0.73548925
# Start of epoch 21 i 0
# step 0: mean loss = 0.7270723
# Start of epoch 22 i 0
# step 0: mean loss = 0.7188208
# Start of epoch 23 i 0
# step 0: mean loss = 0.711335
# Start of epoch 24 i 0
# step 0: mean loss = 0.7046654
# Start of epoch 25 i 0
# step 0: mean loss = 0.69768685
# Start of epoch 26 i 0
# step 0: mean loss = 0.6906107
# Start of epoch 27 i 0
# step 0: mean loss = 0.6835832
# Start of epoch 28 i 0
# step 0: mean loss = 0.6775255
# Start of epoch 29 i 0
# step 0: mean loss = 0.6722249
# Start of epoch 30 i 0
# step 0: mean loss = 0.6676021
# Start of epoch 31 i 0
# step 0: mean loss = 0.6623861
# Start of epoch 32 i 0
# step 0: mean loss = 0.6563995
# Start of epoch 33 i 0
# step 0: mean loss = 0.6506207
# Start of epoch 34 i 0
# step 0: mean loss = 0.64492494
# Start of epoch 35 i 0
# step 0: mean loss = 0.6400345
# Start of epoch 36 i 0
# step 0: mean loss = 0.63487625
# Start of epoch 37 i 0
# step 0: mean loss = 0.630651
# Start of epoch 38 i 0
# step 0: mean loss = 0.626832
# Start of epoch 39 i 0
# step 0: mean loss = 0.6231195
# Start of epoch 40 i 0
# step 0: mean loss = 0.6186001
# Start of epoch 41 i 0
# step 0: mean loss = 0.6139874
# Start of epoch 42 i 0
# step 0: mean loss = 0.6095326
# Start of epoch 43 i 0
# step 0: mean loss = 0.6054442
# Start of epoch 44 i 0
# step 0: mean loss = 0.6018161
# Start of epoch 45 i 0
# step 0: mean loss = 0.5983567
# Start of epoch 46 i 0
# step 0: mean loss = 0.59467524
# Start of epoch 47 i 0
# step 0: mean loss = 0.5912969
# Start of epoch 48 i 0
# step 0: mean loss = 0.58769304
# Start of epoch 49 i 0
# step 0: mean loss = 0.5845805
# Start of epoch 50 i 0
# step 0: mean loss = 0.58142334
# Start of epoch 51 i 0
# step 0: mean loss = 0.5781161
# Start of epoch 52 i 0
# step 0: mean loss = 0.57513344
# Start of epoch 53 i 0
# step 0: mean loss = 0.57206273
# Start of epoch 54 i 0
# step 0: mean loss = 0.5697451
# Start of epoch 55 i 0
# step 0: mean loss = 0.56676644
# Start of epoch 56 i 0
# step 0: mean loss = 0.5637329
# Start of epoch 57 i 0
# step 0: mean loss = 0.56094754
# Start of epoch 58 i 0
# step 0: mean loss = 0.5580206
# Start of epoch 59 i 0
# step 0: mean loss = 0.55515057
# Start of epoch 60 i 0
# step 0: mean loss = 0.5525536
# Start of epoch 61 i 0
# step 0: mean loss = 0.54973996
# Start of epoch 62 i 0
# step 0: mean loss = 0.5467611
# Start of epoch 63 i 0
# step 0: mean loss = 0.5440065
# Start of epoch 64 i 0
# step 0: mean loss = 0.54202646
# Start of epoch 65 i 0
# step 0: mean loss = 0.5397388
# Start of epoch 66 i 0
# step 0: mean loss = 0.53757125
# Start of epoch 67 i 0
# step 0: mean loss = 0.5351735
# Start of epoch 68 i 0
# step 0: mean loss = 0.5327296
# Start of epoch 69 i 0
# step 0: mean loss = 0.5301811
# Start of epoch 70 i 0
# step 0: mean loss = 0.5276827
# Start of epoch 71 i 0
# step 0: mean loss = 0.52525395
# Start of epoch 72 i 0
# step 0: mean loss = 0.52321595
# Start of epoch 73 i 0
# step 0: mean loss = 0.52085817
# Start of epoch 74 i 0
# step 0: mean loss = 0.5184397
# Start of epoch 75 i 0
# step 0: mean loss = 0.51670074
# Start of epoch 76 i 0
# step 0: mean loss = 0.515004
# Start of epoch 77 i 0
# step 0: mean loss = 0.5128581
# Start of epoch 78 i 0
# step 0: mean loss = 0.5105773
# Start of epoch 79 i 0
# step 0: mean loss = 0.50852406
# Start of epoch 80 i 0
# step 0: mean loss = 0.5068942
# Start of epoch 81 i 0
# step 0: mean loss = 0.5049503
# Start of epoch 82 i 0
# step 0: mean loss = 0.5030035
# Start of epoch 83 i 0
# step 0: mean loss = 0.5010571
# Start of epoch 84 i 0
# step 0: mean loss = 0.4993947
# Start of epoch 85 i 0
# step 0: mean loss = 0.49767053
# Start of epoch 86 i 0
# step 0: mean loss = 0.4957455
# Start of epoch 87 i 0
# step 0: mean loss = 0.49390724
# Start of epoch 88 i 0
# step 0: mean loss = 0.49229813
# Start of epoch 89 i 0
# step 0: mean loss = 0.49072868
# Start of epoch 90 i 0
# step 0: mean loss = 0.48909485
# Start of epoch 91 i 0
# step 0: mean loss = 0.48759732
# Start of epoch 92 i 0
# step 0: mean loss = 0.48575795
# Start of epoch 93 i 0
# step 0: mean loss = 0.4838694
# Start of epoch 94 i 0
# step 0: mean loss = 0.48198316
# Start of epoch 95 i 0
# step 0: mean loss = 0.48012447
# Start of epoch 96 i 0
# step 0: mean loss = 0.4784116
# Start of epoch 97 i 0
# step 0: mean loss = 0.4769465
# Start of epoch 98 i 0
# step 0: mean loss = 0.4753052
# Start of epoch 99 i 0
# step 0: mean loss = 0.47362235
# Start of epoch 100 i 0
# step 0: mean loss = 0.47219673
# Start of epoch 101 i 0
# step 0: mean loss = 0.47115955
# Start of epoch 102 i 0
# step 0: mean loss = 0.46957716
# Start of epoch 103 i 0
# step 0: mean loss = 0.46791014
# Start of epoch 104 i 0
# step 0: mean loss = 0.4662104
# Start of epoch 105 i 0
# step 0: mean loss = 0.46474922
# Start of epoch 106 i 0
# step 0: mean loss = 0.46320024
# Start of epoch 107 i 0
# step 0: mean loss = 0.4620066
# Start of epoch 108 i 0
# step 0: mean loss = 0.46091196
# Start of epoch 109 i 0
# step 0: mean loss = 0.4595909
# Start of epoch 110 i 0
# step 0: mean loss = 0.45816484
# Start of epoch 111 i 0
# step 0: mean loss = 0.4568815
# Start of epoch 112 i 0
# step 0: mean loss = 0.45566598
# Start of epoch 113 i 0
# step 0: mean loss = 0.45426467
# Start of epoch 114 i 0
# step 0: mean loss = 0.4530219
# Start of epoch 115 i 0
# step 0: mean loss = 0.45171863
# Start of epoch 116 i 0
# step 0: mean loss = 0.45031974
# Start of epoch 117 i 0
# step 0: mean loss = 0.44894797
# Start of epoch 118 i 0
# step 0: mean loss = 0.44750446
# Start of epoch 119 i 0
# step 0: mean loss = 0.4460197
# Start of epoch 120 i 0
# step 0: mean loss = 0.4447401
# Start of epoch 121 i 0
# step 0: mean loss = 0.44336575
# Start of epoch 122 i 0
# step 0: mean loss = 0.44223654
# Start of epoch 123 i 0
# step 0: mean loss = 0.44107106
# Start of epoch 124 i 0
# step 0: mean loss = 0.43984517
# Start of epoch 125 i 0
# step 0: mean loss = 0.4385529
# Start of epoch 126 i 0
# step 0: mean loss = 0.43733713
# Start of epoch 127 i 0
# step 0: mean loss = 0.43640503
# Start of epoch 128 i 0
# step 0: mean loss = 0.43541446
# Start of epoch 129 i 0
# step 0: mean loss = 0.43413997
# Start of epoch 130 i 0
# step 0: mean loss = 0.43287107
# Start of epoch 131 i 0
# step 0: mean loss = 0.43173063
# Start of epoch 132 i 0
# step 0: mean loss = 0.43059346
# Start of epoch 133 i 0
# step 0: mean loss = 0.42961428
# Start of epoch 134 i 0
# step 0: mean loss = 0.428696
# Start of epoch 135 i 0
# step 0: mean loss = 0.42753032
# Start of epoch 136 i 0
# step 0: mean loss = 0.4262904
# Start of epoch 137 i 0
# step 0: mean loss = 0.42506424
# Start of epoch 138 i 0
# step 0: mean loss = 0.4238457
# Start of epoch 139 i 0
# step 0: mean loss = 0.42276374
# Start of epoch 140 i 0
# step 0: mean loss = 0.42171893
# Start of epoch 141 i 0
# step 0: mean loss = 0.42069116
# Start of epoch 142 i 0
# step 0: mean loss = 0.41966474
# Start of epoch 143 i 0
# step 0: mean loss = 0.41858768
# Start of epoch 144 i 0
# step 0: mean loss = 0.41741186
# Start of epoch 145 i 0
# step 0: mean loss = 0.41621643
# Start of epoch 146 i 0
# step 0: mean loss = 0.4151136
# Start of epoch 147 i 0
# step 0: mean loss = 0.4140002
# Start of epoch 148 i 0
# step 0: mean loss = 0.41298798
# Start of epoch 149 i 0
# step 0: mean loss = 0.41214615
# Start of epoch 150 i 0
# step 0: mean loss = 0.41130757
# Start of epoch 151 i 0
# step 0: mean loss = 0.41037425
# Start of epoch 152 i 0
# step 0: mean loss = 0.40937573
# Start of epoch 153 i 0
# step 0: mean loss = 0.4084822
# Start of epoch 154 i 0
# step 0: mean loss = 0.40750048
# Start of epoch 155 i 0
# step 0: mean loss = 0.40655875
# Start of epoch 156 i 0
# step 0: mean loss = 0.40577877
# Start of epoch 157 i 0
# step 0: mean loss = 0.40496185
# Start of epoch 158 i 0
# step 0: mean loss = 0.40403035
# Start of epoch 159 i 0
# step 0: mean loss = 0.40316084
# Start of epoch 160 i 0
# step 0: mean loss = 0.40235913
# Start of epoch 161 i 0
# step 0: mean loss = 0.40141973
# Start of epoch 162 i 0
# step 0: mean loss = 0.40043187
# Start of epoch 163 i 0
# step 0: mean loss = 0.39933515
# Start of epoch 164 i 0
# step 0: mean loss = 0.39822572
# Start of epoch 165 i 0
# step 0: mean loss = 0.39717922
# Start of epoch 166 i 0
# step 0: mean loss = 0.39620736
# Start of epoch 167 i 0
# step 0: mean loss = 0.39526033
# Start of epoch 168 i 0
# step 0: mean loss = 0.39432338
# Start of epoch 169 i 0
# step 0: mean loss = 0.3934415
# Start of epoch 170 i 0
# step 0: mean loss = 0.39259383
# Start of epoch 171 i 0
# step 0: mean loss = 0.39164075
# Start of epoch 172 i 0
# step 0: mean loss = 0.39065328
# Start of epoch 173 i 0
# step 0: mean loss = 0.38981804
# Start of epoch 174 i 0
# step 0: mean loss = 0.38920596
# Start of epoch 175 i 0
# step 0: mean loss = 0.38845658
# Start of epoch 176 i 0
# step 0: mean loss = 0.38766104
# Start of epoch 177 i 0
# step 0: mean loss = 0.38683063
# Start of epoch 178 i 0
# step 0: mean loss = 0.386063
# Start of epoch 179 i 0
# step 0: mean loss = 0.38528845
# Start of epoch 180 i 0
# step 0: mean loss = 0.3844826
# Start of epoch 181 i 0
# step 0: mean loss = 0.38361296
# Start of epoch 182 i 0
# step 0: mean loss = 0.3827619
# Start of epoch 183 i 0
# step 0: mean loss = 0.3818974
# Start of epoch 184 i 0
# step 0: mean loss = 0.3810608
# Start of epoch 185 i 0
# step 0: mean loss = 0.380204
# Start of epoch 186 i 0
# step 0: mean loss = 0.37940696
# Start of epoch 187 i 0
# step 0: mean loss = 0.37860394
# Start of epoch 188 i 0
# step 0: mean loss = 0.37776348
# Start of epoch 189 i 0
# step 0: mean loss = 0.37693343
# Start of epoch 190 i 0
# step 0: mean loss = 0.37602928
# Start of epoch 191 i 0
# step 0: mean loss = 0.37518293
# Start of epoch 192 i 0
# step 0: mean loss = 0.37444782
# Start of epoch 193 i 0
# step 0: mean loss = 0.37368912
# Start of epoch 194 i 0
# step 0: mean loss = 0.37298444
# Start of epoch 195 i 0
# step 0: mean loss = 0.37221014
# Start of epoch 196 i 0
# step 0: mean loss = 0.37139326
# Start of epoch 197 i 0
# step 0: mean loss = 0.37061954
# Start of epoch 198 i 0
# step 0: mean loss = 0.36986428
# Start of epoch 199 i 0
# step 0: mean loss = 0.3691153
# Start of epoch 200 i 0
# step 0: mean loss = 0.3684039
# Start of epoch 201 i 0
# step 0: mean loss = 0.36763394
# Start of epoch 202 i 0
# step 0: mean loss = 0.36685866
# Start of epoch 203 i 0
# step 0: mean loss = 0.36610046
# Start of epoch 204 i 0
# step 0: mean loss = 0.36537465
# Start of epoch 205 i 0
# step 0: mean loss = 0.3647863
# Start of epoch 206 i 0
# step 0: mean loss = 0.3642904
# Start of epoch 207 i 0
# step 0: mean loss = 0.3635879
# Start of epoch 208 i 0
# step 0: mean loss = 0.36293772
# Start of epoch 209 i 0
# step 0: mean loss = 0.3623562
# Start of epoch 210 i 0
# step 0: mean loss = 0.36162755
# Start of epoch 211 i 0
# step 0: mean loss = 0.36086628
# Start of epoch 212 i 0
# step 0: mean loss = 0.36015055
# Start of epoch 213 i 0
# step 0: mean loss = 0.35940838
# Start of epoch 214 i 0
# step 0: mean loss = 0.35868764
# Start of epoch 215 i 0
# step 0: mean loss = 0.3579833
# Start of epoch 216 i 0
# step 0: mean loss = 0.3572486
# Start of epoch 217 i 0
# step 0: mean loss = 0.35653454
# Start of epoch 218 i 0
# step 0: mean loss = 0.3558822
# Start of epoch 219 i 0
# step 0: mean loss = 0.35521877
# Start of epoch 220 i 0
# step 0: mean loss = 0.35459295
# Start of epoch 221 i 0
# step 0: mean loss = 0.35397518
# Start of epoch 222 i 0
# step 0: mean loss = 0.3532854
# Start of epoch 223 i 0
# step 0: mean loss = 0.35259885
# Start of epoch 224 i 0
# step 0: mean loss = 0.3520113
# Start of epoch 225 i 0
# step 0: mean loss = 0.35133138
# Start of epoch 226 i 0
# step 0: mean loss = 0.3506185
# Start of epoch 227 i 0
# step 0: mean loss = 0.34991458
# Start of epoch 228 i 0
# step 0: mean loss = 0.34928375
# Start of epoch 229 i 0
# step 0: mean loss = 0.3487416
# Start of epoch 230 i 0
# step 0: mean loss = 0.34819093
# Start of epoch 231 i 0
# step 0: mean loss = 0.34761778
# Start of epoch 232 i 0
# step 0: mean loss = 0.34697628
# Start of epoch 233 i 0
# step 0: mean loss = 0.34634373
# Start of epoch 234 i 0
# step 0: mean loss = 0.34568945
# Start of epoch 235 i 0
# step 0: mean loss = 0.3449936
# Start of epoch 236 i 0
# step 0: mean loss = 0.3443255
# Start of epoch 237 i 0
# step 0: mean loss = 0.34373042
# Start of epoch 238 i 0
# step 0: mean loss = 0.3431904
# Start of epoch 239 i 0
# step 0: mean loss = 0.34259138
# Start of epoch 240 i 0
# step 0: mean loss = 0.3420435
# Start of epoch 241 i 0
# step 0: mean loss = 0.3415008
# Start of epoch 242 i 0
# step 0: mean loss = 0.34085402
# Start of epoch 243 i 0
# step 0: mean loss = 0.34018755
# Start of epoch 244 i 0
# step 0: mean loss = 0.33956373
# Start of epoch 245 i 0
# step 0: mean loss = 0.33895376
# Start of epoch 246 i 0
# step 0: mean loss = 0.3383493
# Start of epoch 247 i 0
# step 0: mean loss = 0.33773905
# Start of epoch 248 i 0
# step 0: mean loss = 0.33714816
# Start of epoch 249 i 0
# step 0: mean loss = 0.33655655
# Start of epoch 250 i 0
# step 0: mean loss = 0.335983
# Start of epoch 251 i 0
# step 0: mean loss = 0.33545697
# Start of epoch 252 i 0
# step 0: mean loss = 0.33490232
# Start of epoch 253 i 0
# step 0: mean loss = 0.33431417
# Start of epoch 254 i 0
# step 0: mean loss = 0.33372626
# Start of epoch 255 i 0
# step 0: mean loss = 0.33316776
# Start of epoch 256 i 0
# step 0: mean loss = 0.3326309
# Start of epoch 257 i 0
# step 0: mean loss = 0.3320739
# Start of epoch 258 i 0
# step 0: mean loss = 0.33146983
# Start of epoch 259 i 0
# step 0: mean loss = 0.3308907
# Start of epoch 260 i 0
# step 0: mean loss = 0.33034
# Start of epoch 261 i 0
# step 0: mean loss = 0.32981986
# Start of epoch 262 i 0
# step 0: mean loss = 0.3293054
# Start of epoch 263 i 0
# step 0: mean loss = 0.32881597
# Start of epoch 264 i 0
# step 0: mean loss = 0.32840252
# Start of epoch 265 i 0
# step 0: mean loss = 0.32804957
# Start of epoch 266 i 0
# step 0: mean loss = 0.32763758
# Start of epoch 267 i 0
# step 0: mean loss = 0.32715872
# Start of epoch 268 i 0
# step 0: mean loss = 0.32661653
# Start of epoch 269 i 0
# step 0: mean loss = 0.3260414
# Start of epoch 270 i 0
# step 0: mean loss = 0.32543537
# Start of epoch 271 i 0
# step 0: mean loss = 0.32482186
# Start of epoch 272 i 0
# step 0: mean loss = 0.3242168
# Start of epoch 273 i 0
# step 0: mean loss = 0.32365248
# Start of epoch 274 i 0
# step 0: mean loss = 0.3231013
# Start of epoch 275 i 0
# step 0: mean loss = 0.32255298
# Start of epoch 276 i 0
# step 0: mean loss = 0.3220196
# Start of epoch 277 i 0
# step 0: mean loss = 0.32150006
# Start of epoch 278 i 0
# step 0: mean loss = 0.3210059
# Start of epoch 279 i 0
# step 0: mean loss = 0.32050937
# Start of epoch 280 i 0
# step 0: mean loss = 0.3200075
# Start of epoch 281 i 0
# step 0: mean loss = 0.3195218
# Start of epoch 282 i 0
# step 0: mean loss = 0.319016
# Start of epoch 283 i 0
# step 0: mean loss = 0.3185173
# Start of epoch 284 i 0
# step 0: mean loss = 0.31799105
# Start of epoch 285 i 0
# step 0: mean loss = 0.31749377
# Start of epoch 286 i 0
# step 0: mean loss = 0.3170022
# Start of epoch 287 i 0
# step 0: mean loss = 0.3165116
# Start of epoch 288 i 0
# step 0: mean loss = 0.31603277
# Start of epoch 289 i 0
# step 0: mean loss = 0.31555524
# Start of epoch 290 i 0
# step 0: mean loss = 0.3150289
# Start of epoch 291 i 0
# step 0: mean loss = 0.3144938
# Start of epoch 292 i 0
# step 0: mean loss = 0.3139444
# Start of epoch 293 i 0
# step 0: mean loss = 0.31345084
# Start of epoch 294 i 0
# step 0: mean loss = 0.3129861
# Start of epoch 295 i 0
# step 0: mean loss = 0.3125611
# Start of epoch 296 i 0
# step 0: mean loss = 0.31213048
# Start of epoch 297 i 0
# step 0: mean loss = 0.31166485
# Start of epoch 298 i 0
# step 0: mean loss = 0.31119388
# Start of epoch 299 i 0
# step 0: mean loss = 0.31072935
# Start of epoch 300 i 0
# step 0: mean loss = 0.3102593
# Start of epoch 301 i 0
# step 0: mean loss = 0.30979437
# Start of epoch 302 i 0
# step 0: mean loss = 0.3093519
# Start of epoch 303 i 0
# step 0: mean loss = 0.30890414
# Start of epoch 304 i 0
# step 0: mean loss = 0.30844992
# Start of epoch 305 i 0
# step 0: mean loss = 0.30795056
# Start of epoch 306 i 0
# step 0: mean loss = 0.30743167
# Start of epoch 307 i 0
# step 0: mean loss = 0.30692634
# Start of epoch 308 i 0
# step 0: mean loss = 0.30646038
# Start of epoch 309 i 0
# step 0: mean loss = 0.3060443
# Start of epoch 310 i 0
# step 0: mean loss = 0.30567998
# Start of epoch 311 i 0
# step 0: mean loss = 0.3052877
# Start of epoch 312 i 0
# step 0: mean loss = 0.3048807
# Start of epoch 313 i 0
# step 0: mean loss = 0.30442098
# Start of epoch 314 i 0
# step 0: mean loss = 0.30396584
# Start of epoch 315 i 0
# step 0: mean loss = 0.3034758
# Start of epoch 316 i 0
# step 0: mean loss = 0.3029797
# Start of epoch 317 i 0
# step 0: mean loss = 0.30248445
# Start of epoch 318 i 0
# step 0: mean loss = 0.3019995
# Start of epoch 319 i 0
# step 0: mean loss = 0.3015549
# Start of epoch 320 i 0
# step 0: mean loss = 0.30114546
# Start of epoch 321 i 0
# step 0: mean loss = 0.3007063
# Start of epoch 322 i 0
# step 0: mean loss = 0.30026835
# Start of epoch 323 i 0
# step 0: mean loss = 0.29983622
# Start of epoch 324 i 0
# step 0: mean loss = 0.29939735
# Start of epoch 325 i 0
# step 0: mean loss = 0.29895997
# Start of epoch 326 i 0
# step 0: mean loss = 0.29850262
# Start of epoch 327 i 0
# step 0: mean loss = 0.29802862
# Start of epoch 328 i 0
# step 0: mean loss = 0.29756632
# Start of epoch 329 i 0
# step 0: mean loss = 0.29715943
# Start of epoch 330 i 0
# step 0: mean loss = 0.296801
# Start of epoch 331 i 0
# step 0: mean loss = 0.2964525
# Start of epoch 332 i 0
# step 0: mean loss = 0.2961356
# Start of epoch 333 i 0
# step 0: mean loss = 0.2958004
# Start of epoch 334 i 0
# step 0: mean loss = 0.29543933
# Start of epoch 335 i 0
# step 0: mean loss = 0.2950023
# Start of epoch 336 i 0
# step 0: mean loss = 0.29455325
# Start of epoch 337 i 0
# step 0: mean loss = 0.2941422
# Start of epoch 338 i 0
# step 0: mean loss = 0.29369754
# Start of epoch 339 i 0
# step 0: mean loss = 0.29326504
# Start of epoch 340 i 0
# step 0: mean loss = 0.29283106
# Start of epoch 341 i 0
# step 0: mean loss = 0.29246068
# Start of epoch 342 i 0
# step 0: mean loss = 0.29205024
# Start of epoch 343 i 0
# step 0: mean loss = 0.29163077
# Start of epoch 344 i 0
# step 0: mean loss = 0.2912027
# Start of epoch 345 i 0
# step 0: mean loss = 0.2907866
# Start of epoch 346 i 0
# step 0: mean loss = 0.2903718
# Start of epoch 347 i 0
# step 0: mean loss = 0.289956
# Start of epoch 348 i 0
# step 0: mean loss = 0.28952885
# Start of epoch 349 i 0
# step 0: mean loss = 0.28909224
# Start of epoch 350 i 0
# step 0: mean loss = 0.2886752
# Start of epoch 351 i 0
# step 0: mean loss = 0.2882607
# Start of epoch 352 i 0
# step 0: mean loss = 0.28785855
# Start of epoch 353 i 0
# step 0: mean loss = 0.28750092
# Start of epoch 354 i 0
# step 0: mean loss = 0.287244
# Start of epoch 355 i 0
# step 0: mean loss = 0.28701702
# Start of epoch 356 i 0
# step 0: mean loss = 0.28665715
# Start of epoch 357 i 0
# step 0: mean loss = 0.2862557
# Start of epoch 358 i 0
# step 0: mean loss = 0.28583962
# Start of epoch 359 i 0
# step 0: mean loss = 0.2854032
# Start of epoch 360 i 0
# step 0: mean loss = 0.2849795
# Start of epoch 361 i 0
# step 0: mean loss = 0.28459325
# Start of epoch 362 i 0
# step 0: mean loss = 0.28423423
# Start of epoch 363 i 0
# step 0: mean loss = 0.28388378
# Start of epoch 364 i 0
# step 0: mean loss = 0.28353584
# Start of epoch 365 i 0
# step 0: mean loss = 0.28318265
# Start of epoch 366 i 0
# step 0: mean loss = 0.28284442
# Start of epoch 367 i 0
# step 0: mean loss = 0.28246355
# Start of epoch 368 i 0
# step 0: mean loss = 0.28208065
# Start of epoch 369 i 0
# step 0: mean loss = 0.28172922
# Start of epoch 370 i 0
# step 0: mean loss = 0.28139678
# Start of epoch 371 i 0
# step 0: mean loss = 0.28102344
# Start of epoch 372 i 0
# step 0: mean loss = 0.28061953
# Start of epoch 373 i 0
# step 0: mean loss = 0.28020823
# Start of epoch 374 i 0
# step 0: mean loss = 0.2797947
# Start of epoch 375 i 0
# step 0: mean loss = 0.2793745
# Start of epoch 376 i 0
# step 0: mean loss = 0.27897322
# Start of epoch 377 i 0
# step 0: mean loss = 0.27859545
# Start of epoch 378 i 0
# step 0: mean loss = 0.27821654
# Start of epoch 379 i 0
# step 0: mean loss = 0.2778309
# Start of epoch 380 i 0
# step 0: mean loss = 0.27744073
# Start of epoch 381 i 0
# step 0: mean loss = 0.27703884
# Start of epoch 382 i 0
# step 0: mean loss = 0.27666152
# Start of epoch 383 i 0
# step 0: mean loss = 0.27632296
# Start of epoch 384 i 0
# step 0: mean loss = 0.27597877
# Start of epoch 385 i 0
# step 0: mean loss = 0.27562487
# Start of epoch 386 i 0
# step 0: mean loss = 0.2753052
# Start of epoch 387 i 0
# step 0: mean loss = 0.27499744
# Start of epoch 388 i 0
# step 0: mean loss = 0.2746728
# Start of epoch 389 i 0
# step 0: mean loss = 0.274339
# Start of epoch 390 i 0
# step 0: mean loss = 0.27400482
# Start of epoch 391 i 0
# step 0: mean loss = 0.27364329
# Start of epoch 392 i 0
# step 0: mean loss = 0.27325258
# Start of epoch 393 i 0
# step 0: mean loss = 0.27283916
# Start of epoch 394 i 0
# step 0: mean loss = 0.27242038
# Start of epoch 395 i 0
# step 0: mean loss = 0.27201954
# Start of epoch 396 i 0
# step 0: mean loss = 0.27164942
# Start of epoch 397 i 0
# step 0: mean loss = 0.27128392
# Start of epoch 398 i 0
# step 0: mean loss = 0.2709189
# Start of epoch 399 i 0
# step 0: mean loss = 0.27057818
# Start of epoch 400 i 0
# step 0: mean loss = 0.27026838
# Start of epoch 401 i 0
# step 0: mean loss = 0.2700002
# Start of epoch 402 i 0
# step 0: mean loss = 0.26967457
# Start of epoch 403 i 0
# step 0: mean loss = 0.26932192
# Start of epoch 404 i 0
# step 0: mean loss = 0.26894715
# Start of epoch 405 i 0
# step 0: mean loss = 0.26855868
# Start of epoch 406 i 0
# step 0: mean loss = 0.26818576
# Start of epoch 407 i 0
# step 0: mean loss = 0.26784164
# Start of epoch 408 i 0
# step 0: mean loss = 0.26749852
# Start of epoch 409 i 0
# step 0: mean loss = 0.26715004
# Start of epoch 410 i 0
# step 0: mean loss = 0.26681072
# Start of epoch 411 i 0
# step 0: mean loss = 0.26646182
# Start of epoch 412 i 0
# step 0: mean loss = 0.26614305
# Start of epoch 413 i 0
# step 0: mean loss = 0.2658469
# Start of epoch 414 i 0
# step 0: mean loss = 0.26558602
# Start of epoch 415 i 0
# step 0: mean loss = 0.26531613
# Start of epoch 416 i 0
# step 0: mean loss = 0.26509792
# Start of epoch 417 i 0
# step 0: mean loss = 0.26494277
# Start of epoch 418 i 0
# step 0: mean loss = 0.2647779
# Start of epoch 419 i 0
# step 0: mean loss = 0.26449284
# Start of epoch 420 i 0
# step 0: mean loss = 0.26414657
# Start of epoch 421 i 0
# step 0: mean loss = 0.26375887
# Start of epoch 422 i 0
# step 0: mean loss = 0.2633563
# Start of epoch 423 i 0
# step 0: mean loss = 0.26294553
# Start of epoch 424 i 0
# step 0: mean loss = 0.26254573
# Start of epoch 425 i 0
# step 0: mean loss = 0.262164
# Start of epoch 426 i 0
# step 0: mean loss = 0.26179028
# Start of epoch 427 i 0
# step 0: mean loss = 0.2614197
# Start of epoch 428 i 0
# step 0: mean loss = 0.26108837
# Start of epoch 429 i 0
# step 0: mean loss = 0.26076123
# Start of epoch 430 i 0
# step 0: mean loss = 0.26045668
# Start of epoch 431 i 0
# step 0: mean loss = 0.2601566
# Start of epoch 432 i 0
# step 0: mean loss = 0.25990772
# Start of epoch 433 i 0
# step 0: mean loss = 0.2596826
# Start of epoch 434 i 0
# step 0: mean loss = 0.2594185
# Start of epoch 435 i 0
# step 0: mean loss = 0.25915474
# Start of epoch 436 i 0
# step 0: mean loss = 0.2589137
# Start of epoch 437 i 0
# step 0: mean loss = 0.25863948
# Start of epoch 438 i 0
# step 0: mean loss = 0.25833416
# Start of epoch 439 i 0
# step 0: mean loss = 0.25799382
# Start of epoch 440 i 0
# step 0: mean loss = 0.25767002
# Start of epoch 441 i 0
# step 0: mean loss = 0.25733253
# Start of epoch 442 i 0
# step 0: mean loss = 0.25699562
# Start of epoch 443 i 0
# step 0: mean loss = 0.25664777
# Start of epoch 444 i 0
# step 0: mean loss = 0.256304
# Start of epoch 445 i 0
# step 0: mean loss = 0.25594434
# Start of epoch 446 i 0
# step 0: mean loss = 0.2555916
# Start of epoch 447 i 0
# step 0: mean loss = 0.25525963
# Start of epoch 448 i 0
# step 0: mean loss = 0.25494707
# Start of epoch 449 i 0
# step 0: mean loss = 0.2546344
# Start of epoch 450 i 0
# step 0: mean loss = 0.25431812
# Start of epoch 451 i 0
# step 0: mean loss = 0.2540039
# Start of epoch 452 i 0
# step 0: mean loss = 0.25368714
# Start of epoch 453 i 0
# step 0: mean loss = 0.25339225
# Start of epoch 454 i 0
# step 0: mean loss = 0.2531225
# Start of epoch 455 i 0
# step 0: mean loss = 0.25285572
# Start of epoch 456 i 0
# step 0: mean loss = 0.2525738
# Start of epoch 457 i 0
# step 0: mean loss = 0.25227803
# Start of epoch 458 i 0
# step 0: mean loss = 0.25199246
# Start of epoch 459 i 0
# step 0: mean loss = 0.2517794
# Start of epoch 460 i 0
# step 0: mean loss = 0.25149706
# Start of epoch 461 i 0
# step 0: mean loss = 0.2511753
# Start of epoch 462 i 0
# step 0: mean loss = 0.25084466
# Start of epoch 463 i 0
# step 0: mean loss = 0.25050136
# Start of epoch 464 i 0
# step 0: mean loss = 0.25018996
# Start of epoch 465 i 0
# step 0: mean loss = 0.24991915
# Start of epoch 466 i 0
# step 0: mean loss = 0.24964488
# Start of epoch 467 i 0
# step 0: mean loss = 0.24935734
# Start of epoch 468 i 0
# step 0: mean loss = 0.24906625
# Start of epoch 469 i 0
# step 0: mean loss = 0.24879017
# Start of epoch 470 i 0
# step 0: mean loss = 0.24851273
# Start of epoch 471 i 0
# step 0: mean loss = 0.24824113
# Start of epoch 472 i 0
# step 0: mean loss = 0.24799426
# Start of epoch 473 i 0
# step 0: mean loss = 0.24770236
# Start of epoch 474 i 0
# step 0: mean loss = 0.24739797
# Start of epoch 475 i 0
# step 0: mean loss = 0.24709874
# Start of epoch 476 i 0
# step 0: mean loss = 0.24682185
# Start of epoch 477 i 0
# step 0: mean loss = 0.24650966
# Start of epoch 478 i 0
# step 0: mean loss = 0.2461949
# Start of epoch 479 i 0
# step 0: mean loss = 0.24591494
# Start of epoch 480 i 0
# step 0: mean loss = 0.24565072
# Start of epoch 481 i 0
# step 0: mean loss = 0.24542081
# Start of epoch 482 i 0
# step 0: mean loss = 0.24512027
# Start of epoch 483 i 0
# step 0: mean loss = 0.24479286
# Start of epoch 484 i 0
# step 0: mean loss = 0.24446468
# Start of epoch 485 i 0
# step 0: mean loss = 0.24414964
# Start of epoch 486 i 0
# step 0: mean loss = 0.2438561
# Start of epoch 487 i 0
# step 0: mean loss = 0.24354997
# Start of epoch 488 i 0
# step 0: mean loss = 0.24323934
# Start of epoch 489 i 0
# step 0: mean loss = 0.24293944
# Start of epoch 490 i 0
# step 0: mean loss = 0.24264753
# Start of epoch 491 i 0
# step 0: mean loss = 0.24235612
# Start of epoch 492 i 0
# step 0: mean loss = 0.24207707
# Start of epoch 493 i 0
# step 0: mean loss = 0.24180777
# Start of epoch 494 i 0
# step 0: mean loss = 0.2415366
# Start of epoch 495 i 0
# step 0: mean loss = 0.24127446
# Start of epoch 496 i 0
# step 0: mean loss = 0.24100222
# Start of epoch 497 i 0
# step 0: mean loss = 0.24073216
# Start of epoch 498 i 0
# step 0: mean loss = 0.24046661
# Start of epoch 499 i 0
# step 0: mean loss = 0.2402579
# Start of epoch 500 i 0
# step 0: mean loss = 0.24006592
# Start of epoch 501 i 0
# step 0: mean loss = 0.23993522
# Start of epoch 502 i 0
# step 0: mean loss = 0.239823
# Start of epoch 503 i 0
# step 0: mean loss = 0.23960632
# Start of epoch 504 i 0
# step 0: mean loss = 0.23933087
# Start of epoch 505 i 0
# step 0: mean loss = 0.2390404
# Start of epoch 506 i 0
# step 0: mean loss = 0.23874491
# Start of epoch 507 i 0
# step 0: mean loss = 0.23846535
# Start of epoch 508 i 0
# step 0: mean loss = 0.23816612
# Start of epoch 509 i 0
# step 0: mean loss = 0.23785098
# Start of epoch 510 i 0
# step 0: mean loss = 0.23753284
# Start of epoch 511 i 0
# step 0: mean loss = 0.23722395
# Start of epoch 512 i 0
# step 0: mean loss = 0.23693375
# Start of epoch 513 i 0
# step 0: mean loss = 0.23663652
# Start of epoch 514 i 0
# step 0: mean loss = 0.23635632
# Start of epoch 515 i 0
# step 0: mean loss = 0.23612149
# Start of epoch 516 i 0
# step 0: mean loss = 0.23592103
# Start of epoch 517 i 0
# step 0: mean loss = 0.23568697
# Start of epoch 518 i 0
# step 0: mean loss = 0.23544358
# Start of epoch 519 i 0
# step 0: mean loss = 0.23519026
# Start of epoch 520 i 0
# step 0: mean loss = 0.23492128
# Start of epoch 521 i 0
# step 0: mean loss = 0.23465319
# Start of epoch 522 i 0
# step 0: mean loss = 0.23437025
# Start of epoch 523 i 0
# step 0: mean loss = 0.23407313
# Start of epoch 524 i 0
# step 0: mean loss = 0.2337892
# Start of epoch 525 i 0
# step 0: mean loss = 0.23352483
# Start of epoch 526 i 0
# step 0: mean loss = 0.23325649
# Start of epoch 527 i 0
# step 0: mean loss = 0.23298763
# Start of epoch 528 i 0
# step 0: mean loss = 0.23271582
# Start of epoch 529 i 0
# step 0: mean loss = 0.23245497
# Start of epoch 530 i 0
# step 0: mean loss = 0.23220055
# Start of epoch 531 i 0
# step 0: mean loss = 0.23195082
# Start of epoch 532 i 0
# step 0: mean loss = 0.23170207
# Start of epoch 533 i 0
# step 0: mean loss = 0.23145436
# Start of epoch 534 i 0
# step 0: mean loss = 0.23119195
# Start of epoch 535 i 0
# step 0: mean loss = 0.23091488
# Start of epoch 536 i 0
# step 0: mean loss = 0.23062588
# Start of epoch 537 i 0
# step 0: mean loss = 0.2303363
# Start of epoch 538 i 0
# step 0: mean loss = 0.23005663
# Start of epoch 539 i 0
# step 0: mean loss = 0.22982298
# Start of epoch 540 i 0
# step 0: mean loss = 0.22958633
# Start of epoch 541 i 0
# step 0: mean loss = 0.22935276
# Start of epoch 542 i 0
# step 0: mean loss = 0.22915715
# Start of epoch 543 i 0
# step 0: mean loss = 0.22901857
# Start of epoch 544 i 0
# step 0: mean loss = 0.22889058
# Start of epoch 545 i 0
# step 0: mean loss = 0.22874492
# Start of epoch 546 i 0
# step 0: mean loss = 0.22857624
# Start of epoch 547 i 0
# step 0: mean loss = 0.22837703
# Start of epoch 548 i 0
# step 0: mean loss = 0.22815238
# Start of epoch 549 i 0
# step 0: mean loss = 0.2278799
# Start of epoch 550 i 0
# step 0: mean loss = 0.22763105
# Start of epoch 551 i 0
# step 0: mean loss = 0.2273733
# Start of epoch 552 i 0
# step 0: mean loss = 0.22709201
# Start of epoch 553 i 0
# step 0: mean loss = 0.22682153
# Start of epoch 554 i 0
# step 0: mean loss = 0.2265572
# Start of epoch 555 i 0
# step 0: mean loss = 0.22629325
# Start of epoch 556 i 0
# step 0: mean loss = 0.22606197
# Start of epoch 557 i 0
# step 0: mean loss = 0.22579953
# Start of epoch 558 i 0
# step 0: mean loss = 0.22554058
# Start of epoch 559 i 0
# step 0: mean loss = 0.22530864
# Start of epoch 560 i 0
# step 0: mean loss = 0.22506848
# Start of epoch 561 i 0
# step 0: mean loss = 0.2248158
# Start of epoch 562 i 0
# step 0: mean loss = 0.22459346
# Start of epoch 563 i 0
# step 0: mean loss = 0.22436824
# Start of epoch 564 i 0
# step 0: mean loss = 0.22416857
# Start of epoch 565 i 0
# step 0: mean loss = 0.22397771
# Start of epoch 566 i 0
# step 0: mean loss = 0.22374755
# Start of epoch 567 i 0
# step 0: mean loss = 0.22349003
# Start of epoch 568 i 0
# step 0: mean loss = 0.22322187
# Start of epoch 569 i 0
# step 0: mean loss = 0.22295006
# Start of epoch 570 i 0
# step 0: mean loss = 0.22267768
# Start of epoch 571 i 0
# step 0: mean loss = 0.22240168
# Start of epoch 572 i 0
# step 0: mean loss = 0.22213207
# Start of epoch 573 i 0
# step 0: mean loss = 0.22187255
# Start of epoch 574 i 0
# step 0: mean loss = 0.22161534
# Start of epoch 575 i 0
# step 0: mean loss = 0.22136773
# Start of epoch 576 i 0
# step 0: mean loss = 0.22113065
# Start of epoch 577 i 0
# step 0: mean loss = 0.22089833
# Start of epoch 578 i 0
# step 0: mean loss = 0.22068357
# Start of epoch 579 i 0
# step 0: mean loss = 0.22045131
# Start of epoch 580 i 0
# step 0: mean loss = 0.22022617
# Start of epoch 581 i 0
# step 0: mean loss = 0.2200028
# Start of epoch 582 i 0
# step 0: mean loss = 0.2197881
# Start of epoch 583 i 0
# step 0: mean loss = 0.21958427
# Start of epoch 584 i 0
# step 0: mean loss = 0.21938732
# Start of epoch 585 i 0
# step 0: mean loss = 0.21925305
# Start of epoch 586 i 0
# step 0: mean loss = 0.21908769
# Start of epoch 587 i 0
# step 0: mean loss = 0.21887302
# Start of epoch 588 i 0
# step 0: mean loss = 0.21864629
# Start of epoch 589 i 0
# step 0: mean loss = 0.21841462
# Start of epoch 590 i 0
# step 0: mean loss = 0.21817218
# Start of epoch 591 i 0
# step 0: mean loss = 0.21792492
# Start of epoch 592 i 0
# step 0: mean loss = 0.21767892
# Start of epoch 593 i 0
# step 0: mean loss = 0.21743168
# Start of epoch 594 i 0
# step 0: mean loss = 0.2171908
# Start of epoch 595 i 0
# step 0: mean loss = 0.21694964
# Start of epoch 596 i 0
# step 0: mean loss = 0.21670945
# Start of epoch 597 i 0
# step 0: mean loss = 0.21647179
# Start of epoch 598 i 0
# step 0: mean loss = 0.21624862
# Start of epoch 599 i 0
# step 0: mean loss = 0.21603025
# Start of epoch 600 i 0
# step 0: mean loss = 0.21582173
# Start of epoch 601 i 0
# step 0: mean loss = 0.21560927
# Start of epoch 602 i 0
# step 0: mean loss = 0.21539077
# Start of epoch 603 i 0
# step 0: mean loss = 0.21517411
# Start of epoch 604 i 0
# step 0: mean loss = 0.21496624
# Start of epoch 605 i 0
# step 0: mean loss = 0.21473746
# Start of epoch 606 i 0
# step 0: mean loss = 0.21450914
# Start of epoch 607 i 0
# step 0: mean loss = 0.21427965
# Start of epoch 608 i 0
# step 0: mean loss = 0.21412542
# Start of epoch 609 i 0
# step 0: mean loss = 0.2140019
# Start of epoch 610 i 0
# step 0: mean loss = 0.21391279
# Start of epoch 611 i 0
# step 0: mean loss = 0.21375956
# Start of epoch 612 i 0
# step 0: mean loss = 0.21355604
# Start of epoch 613 i 0
# step 0: mean loss = 0.2133339
# Start of epoch 614 i 0
# step 0: mean loss = 0.21309549
# Start of epoch 615 i 0
# step 0: mean loss = 0.21285415
# Start of epoch 616 i 0
# step 0: mean loss = 0.2126199
# Start of epoch 617 i 0
# step 0: mean loss = 0.2123733
# Start of epoch 618 i 0
# step 0: mean loss = 0.21213144
# Start of epoch 619 i 0
# step 0: mean loss = 0.21189813
# Start of epoch 620 i 0
# step 0: mean loss = 0.21166962
# Start of epoch 621 i 0
# step 0: mean loss = 0.2114356
# Start of epoch 622 i 0
# step 0: mean loss = 0.21120659
# Start of epoch 623 i 0
# step 0: mean loss = 0.21098933
# Start of epoch 624 i 0
# step 0: mean loss = 0.21077034
# Start of epoch 625 i 0
# step 0: mean loss = 0.21055026
# Start of epoch 626 i 0
# step 0: mean loss = 0.2103367
# Start of epoch 627 i 0
# step 0: mean loss = 0.21013786
# Start of epoch 628 i 0
# step 0: mean loss = 0.20992686
# Start of epoch 629 i 0
# step 0: mean loss = 0.20971376
# Start of epoch 630 i 0
# step 0: mean loss = 0.20949759
# Start of epoch 631 i 0
# step 0: mean loss = 0.20928255
# Start of epoch 632 i 0
# step 0: mean loss = 0.20906352
# Start of epoch 633 i 0
# step 0: mean loss = 0.20883779
# Start of epoch 634 i 0
# step 0: mean loss = 0.20860855
# Start of epoch 635 i 0
# step 0: mean loss = 0.20838304
# Start of epoch 636 i 0
# step 0: mean loss = 0.20815578
# Start of epoch 637 i 0
# step 0: mean loss = 0.20792747
# Start of epoch 638 i 0
# step 0: mean loss = 0.20770146
# Start of epoch 639 i 0
# step 0: mean loss = 0.20747845
# Start of epoch 640 i 0
# step 0: mean loss = 0.2072658
# Start of epoch 641 i 0
# step 0: mean loss = 0.20705695
# Start of epoch 642 i 0
# step 0: mean loss = 0.2068878
# Start of epoch 643 i 0
# step 0: mean loss = 0.20670074
# Start of epoch 644 i 0
# step 0: mean loss = 0.2065615
# Start of epoch 645 i 0
# step 0: mean loss = 0.20661296
# Start of epoch 646 i 0
# step 0: mean loss = 0.20668575
# Start of epoch 647 i 0
# step 0: mean loss = 0.20660245
# Start of epoch 648 i 0
# step 0: mean loss = 0.2064981
# Start of epoch 649 i 0
# step 0: mean loss = 0.20636185
# Start of epoch 650 i 0
# step 0: mean loss = 0.2061788
# Start of epoch 651 i 0
# step 0: mean loss = 0.20602144
# Start of epoch 652 i 0
# step 0: mean loss = 0.20583233
# Start of epoch 653 i 0
# step 0: mean loss = 0.2056315
# Start of epoch 654 i 0
# step 0: mean loss = 0.2054252
# Start of epoch 655 i 0
# step 0: mean loss = 0.20521426
# Start of epoch 656 i 0
# step 0: mean loss = 0.20499606
# Start of epoch 657 i 0
# step 0: mean loss = 0.20477669
# Start of epoch 658 i 0
# step 0: mean loss = 0.20455873
# Start of epoch 659 i 0
# step 0: mean loss = 0.20433868
# Start of epoch 660 i 0
# step 0: mean loss = 0.20412023
# Start of epoch 661 i 0
# step 0: mean loss = 0.20390497
# Start of epoch 662 i 0
# step 0: mean loss = 0.20370154
# Start of epoch 663 i 0
# step 0: mean loss = 0.20349918
# Start of epoch 664 i 0
# step 0: mean loss = 0.20330548
# Start of epoch 665 i 0
# step 0: mean loss = 0.20311773
# Start of epoch 666 i 0
# step 0: mean loss = 0.20291914
# Start of epoch 667 i 0
# step 0: mean loss = 0.20272695
# Start of epoch 668 i 0
# step 0: mean loss = 0.20253749
# Start of epoch 669 i 0
# step 0: mean loss = 0.20234235
# Start of epoch 670 i 0
# step 0: mean loss = 0.20215058
# Start of epoch 671 i 0
# step 0: mean loss = 0.2019727
# Start of epoch 672 i 0
# step 0: mean loss = 0.20184
# Start of epoch 673 i 0
# step 0: mean loss = 0.20168799
# Start of epoch 674 i 0
# step 0: mean loss = 0.20150526
# Start of epoch 675 i 0
# step 0: mean loss = 0.20131631
# Start of epoch 676 i 0
# step 0: mean loss = 0.20111412
# Start of epoch 677 i 0
# step 0: mean loss = 0.20091334
# Start of epoch 678 i 0
# step 0: mean loss = 0.20071371
# Start of epoch 679 i 0
# step 0: mean loss = 0.20051913
# Start of epoch 680 i 0
# step 0: mean loss = 0.20032817
# Start of epoch 681 i 0
# step 0: mean loss = 0.2001384
# Start of epoch 682 i 0
# step 0: mean loss = 0.19994779
# Start of epoch 683 i 0
# step 0: mean loss = 0.19976068
# Start of epoch 684 i 0
# step 0: mean loss = 0.19962265
# Start of epoch 685 i 0
# step 0: mean loss = 0.19950353
# Start of epoch 686 i 0
# step 0: mean loss = 0.19937491
# Start of epoch 687 i 0
# step 0: mean loss = 0.19923271
# Start of epoch 688 i 0
# step 0: mean loss = 0.19906038
# Start of epoch 689 i 0
# step 0: mean loss = 0.19888327
# Start of epoch 690 i 0
# step 0: mean loss = 0.1987107
# Start of epoch 691 i 0
# step 0: mean loss = 0.19852912
# Start of epoch 692 i 0
# step 0: mean loss = 0.19833651
# Start of epoch 693 i 0
# step 0: mean loss = 0.19813633
# Start of epoch 694 i 0
# step 0: mean loss = 0.19793217
# Start of epoch 695 i 0
# step 0: mean loss = 0.19773167
# Start of epoch 696 i 0
# step 0: mean loss = 0.19754544
# Start of epoch 697 i 0
# step 0: mean loss = 0.19736944
# Start of epoch 698 i 0
# step 0: mean loss = 0.19719364
# Start of epoch 699 i 0
# step 0: mean loss = 0.19701628
# Start of epoch 700 i 0
# step 0: mean loss = 0.19683914
# Start of epoch 701 i 0
# step 0: mean loss = 0.19666375
# Start of epoch 702 i 0
# step 0: mean loss = 0.1964894
# Start of epoch 703 i 0
# step 0: mean loss = 0.19631514
# Start of epoch 704 i 0
# step 0: mean loss = 0.19613254
# Start of epoch 705 i 0
# step 0: mean loss = 0.19595805
# Start of epoch 706 i 0
# step 0: mean loss = 0.19579294
# Start of epoch 707 i 0
# step 0: mean loss = 0.19563352
# Start of epoch 708 i 0
# step 0: mean loss = 0.19548124
# Start of epoch 709 i 0
# step 0: mean loss = 0.19532873
# Start of epoch 710 i 0
# step 0: mean loss = 0.195206
# Start of epoch 711 i 0
# step 0: mean loss = 0.1950582
# Start of epoch 712 i 0
# step 0: mean loss = 0.19488733
# Start of epoch 713 i 0
# step 0: mean loss = 0.19470598
# Start of epoch 714 i 0
# step 0: mean loss = 0.19451942
# Start of epoch 715 i 0
# step 0: mean loss = 0.19433625
# Start of epoch 716 i 0
# step 0: mean loss = 0.19416258
# Start of epoch 717 i 0
# step 0: mean loss = 0.19400416
# Start of epoch 718 i 0
# step 0: mean loss = 0.19386318
# Start of epoch 719 i 0
# step 0: mean loss = 0.1937657
# Start of epoch 720 i 0
# step 0: mean loss = 0.19363844
# Start of epoch 721 i 0
# step 0: mean loss = 0.19348666
# Start of epoch 722 i 0
# step 0: mean loss = 0.19332545
# Start of epoch 723 i 0
# step 0: mean loss = 0.19316077
# Start of epoch 724 i 0
# step 0: mean loss = 0.19298859
# Start of epoch 725 i 0
# step 0: mean loss = 0.19281805
# Start of epoch 726 i 0
# step 0: mean loss = 0.1926509
# Start of epoch 727 i 0
# step 0: mean loss = 0.1924854
# Start of epoch 728 i 0
# step 0: mean loss = 0.19231594
# Start of epoch 729 i 0
# step 0: mean loss = 0.1921477
# Start of epoch 730 i 0
# step 0: mean loss = 0.19197416
# Start of epoch 731 i 0
# step 0: mean loss = 0.19179797
# Start of epoch 732 i 0
# step 0: mean loss = 0.19163965
# Start of epoch 733 i 0
# step 0: mean loss = 0.19154051
# Start of epoch 734 i 0
# step 0: mean loss = 0.19149253
# Start of epoch 735 i 0
# step 0: mean loss = 0.19141747
# Start of epoch 736 i 0
# step 0: mean loss = 0.19131112
# Start of epoch 737 i 0
# step 0: mean loss = 0.19116011
# Start of epoch 738 i 0
# step 0: mean loss = 0.1909988
# Start of epoch 739 i 0
# step 0: mean loss = 0.19081724
# Start of epoch 740 i 0
# step 0: mean loss = 0.19062915
# Start of epoch 741 i 0
# step 0: mean loss = 0.19044079
# Start of epoch 742 i 0
# step 0: mean loss = 0.19025096
# Start of epoch 743 i 0
# step 0: mean loss = 0.19006881
# Start of epoch 744 i 0
# step 0: mean loss = 0.18990898
# Start of epoch 745 i 0
# step 0: mean loss = 0.18977587
# Start of epoch 746 i 0
# step 0: mean loss = 0.18962893
# Start of epoch 747 i 0
# step 0: mean loss = 0.18948418
# Start of epoch 748 i 0
# step 0: mean loss = 0.18934266
# Start of epoch 749 i 0
# step 0: mean loss = 0.18920052
# Start of epoch 750 i 0
# step 0: mean loss = 0.18905792
# Start of epoch 751 i 0
# step 0: mean loss = 0.18889534
# Start of epoch 752 i 0
# step 0: mean loss = 0.18872546
# Start of epoch 753 i 0
# step 0: mean loss = 0.18856606
# Start of epoch 754 i 0
# step 0: mean loss = 0.18840155
# Start of epoch 755 i 0
# step 0: mean loss = 0.18823029
# Start of epoch 756 i 0
# step 0: mean loss = 0.18805483
# Start of epoch 757 i 0
# step 0: mean loss = 0.18787831
# Start of epoch 758 i 0
# step 0: mean loss = 0.18770209
# Start of epoch 759 i 0
# step 0: mean loss = 0.1875361
# Start of epoch 760 i 0
# step 0: mean loss = 0.18738039
# Start of epoch 761 i 0
# step 0: mean loss = 0.18723136
# Start of epoch 762 i 0
# step 0: mean loss = 0.18707763
# Start of epoch 763 i 0
# step 0: mean loss = 0.1869199
# Start of epoch 764 i 0
# step 0: mean loss = 0.1867605
# Start of epoch 765 i 0
# step 0: mean loss = 0.18660556
# Start of epoch 766 i 0
# step 0: mean loss = 0.186448
# Start of epoch 767 i 0
# step 0: mean loss = 0.18629377
# Start of epoch 768 i 0
# step 0: mean loss = 0.1861405
# Start of epoch 769 i 0
# step 0: mean loss = 0.18598257
# Start of epoch 770 i 0
# step 0: mean loss = 0.18582043
# Start of epoch 771 i 0
# step 0: mean loss = 0.18565686
# Start of epoch 772 i 0
# step 0: mean loss = 0.18549438
# Start of epoch 773 i 0
# step 0: mean loss = 0.18533231
# Start of epoch 774 i 0
# step 0: mean loss = 0.18517455
# Start of epoch 775 i 0
# step 0: mean loss = 0.18501942
# Start of epoch 776 i 0
# step 0: mean loss = 0.18486851
# Start of epoch 777 i 0
# step 0: mean loss = 0.18471394
# Start of epoch 778 i 0
# step 0: mean loss = 0.18456733
# Start of epoch 779 i 0
# step 0: mean loss = 0.1844226
# Start of epoch 780 i 0
# step 0: mean loss = 0.18428299
# Start of epoch 781 i 0
# step 0: mean loss = 0.18414468
# Start of epoch 782 i 0
# step 0: mean loss = 0.18400654
# Start of epoch 783 i 0
# step 0: mean loss = 0.1838882
# Start of epoch 784 i 0
# step 0: mean loss = 0.18376534
# Start of epoch 785 i 0
# step 0: mean loss = 0.18363866
# Start of epoch 786 i 0
# step 0: mean loss = 0.18351702
# Start of epoch 787 i 0
# step 0: mean loss = 0.18339282
# Start of epoch 788 i 0
# step 0: mean loss = 0.18325964
# Start of epoch 789 i 0
# step 0: mean loss = 0.18313438
# Start of epoch 790 i 0
# step 0: mean loss = 0.18301521
# Start of epoch 791 i 0
# step 0: mean loss = 0.1828853
# Start of epoch 792 i 0
# step 0: mean loss = 0.18274154
# Start of epoch 793 i 0
# step 0: mean loss = 0.18258679
# Start of epoch 794 i 0
# step 0: mean loss = 0.18242103
# Start of epoch 795 i 0
# step 0: mean loss = 0.18225019
# Start of epoch 796 i 0
# step 0: mean loss = 0.18207762
# Start of epoch 797 i 0
# step 0: mean loss = 0.18191347
# Start of epoch 798 i 0
# step 0: mean loss = 0.18174858
# Start of epoch 799 i 0
# step 0: mean loss = 0.1815849
# Start of epoch 800 i 0
# step 0: mean loss = 0.18142293
# Start of epoch 801 i 0
# step 0: mean loss = 0.181261
# Start of epoch 802 i 0
# step 0: mean loss = 0.18109801
# Start of epoch 803 i 0
# step 0: mean loss = 0.1809449
# Start of epoch 804 i 0
# step 0: mean loss = 0.18081056
# Start of epoch 805 i 0
# step 0: mean loss = 0.18068239
# Start of epoch 806 i 0
# step 0: mean loss = 0.1805447
# Start of epoch 807 i 0
# step 0: mean loss = 0.18039764
# Start of epoch 808 i 0
# step 0: mean loss = 0.18025535
# Start of epoch 809 i 0
# step 0: mean loss = 0.18010642
# Start of epoch 810 i 0
# step 0: mean loss = 0.17995174
# Start of epoch 811 i 0
# step 0: mean loss = 0.17980054
# Start of epoch 812 i 0
# step 0: mean loss = 0.17966029
# Start of epoch 813 i 0
# step 0: mean loss = 0.17951363
# Start of epoch 814 i 0
# step 0: mean loss = 0.17936546
# Start of epoch 815 i 0
# step 0: mean loss = 0.17921995
# Start of epoch 816 i 0
# step 0: mean loss = 0.1790742
# Start of epoch 817 i 0
# step 0: mean loss = 0.17893222
# Start of epoch 818 i 0
# step 0: mean loss = 0.17879334
# Start of epoch 819 i 0
# step 0: mean loss = 0.17867379
# Start of epoch 820 i 0
# step 0: mean loss = 0.17856346
# Start of epoch 821 i 0
# step 0: mean loss = 0.17849691
# Start of epoch 822 i 0
# step 0: mean loss = 0.1784829
# Start of epoch 823 i 0
# step 0: mean loss = 0.17842205
# Start of epoch 824 i 0
# step 0: mean loss = 0.17831711
# Start of epoch 825 i 0
# step 0: mean loss = 0.17817989
# Start of epoch 826 i 0
# step 0: mean loss = 0.17803308
# Start of epoch 827 i 0
# step 0: mean loss = 0.177878
# Start of epoch 828 i 0
# step 0: mean loss = 0.17771922
# Start of epoch 829 i 0
# step 0: mean loss = 0.17756236
# Start of epoch 830 i 0
# step 0: mean loss = 0.17741144
# Start of epoch 831 i 0
# step 0: mean loss = 0.17725554
# Start of epoch 832 i 0
# step 0: mean loss = 0.17710903
# Start of epoch 833 i 0
# step 0: mean loss = 0.17696075
# Start of epoch 834 i 0
# step 0: mean loss = 0.17680724
# Start of epoch 835 i 0
# step 0: mean loss = 0.17665249
# Start of epoch 836 i 0
# step 0: mean loss = 0.17649782
# Start of epoch 837 i 0
# step 0: mean loss = 0.17635027
# Start of epoch 838 i 0
# step 0: mean loss = 0.17620708
# Start of epoch 839 i 0
# step 0: mean loss = 0.17606704
# Start of epoch 840 i 0
# step 0: mean loss = 0.17592831
# Start of epoch 841 i 0
# step 0: mean loss = 0.17579909
# Start of epoch 842 i 0
# step 0: mean loss = 0.17566633
# Start of epoch 843 i 0
# step 0: mean loss = 0.17552407
# Start of epoch 844 i 0
# step 0: mean loss = 0.17538305
# Start of epoch 845 i 0
# step 0: mean loss = 0.17525433
# Start of epoch 846 i 0
# step 0: mean loss = 0.175119
# Start of epoch 847 i 0
# step 0: mean loss = 0.17498437
# Start of epoch 848 i 0
# step 0: mean loss = 0.17484754
# Start of epoch 849 i 0
# step 0: mean loss = 0.17470695
# Start of epoch 850 i 0
# step 0: mean loss = 0.17456296
# Start of epoch 851 i 0
# step 0: mean loss = 0.17442104
# Start of epoch 852 i 0
# step 0: mean loss = 0.1742813
# Start of epoch 853 i 0
# step 0: mean loss = 0.17413504
# Start of epoch 854 i 0
# step 0: mean loss = 0.17398739
# Start of epoch 855 i 0
# step 0: mean loss = 0.1738413
# Start of epoch 856 i 0
# step 0: mean loss = 0.17369542
# Start of epoch 857 i 0
# step 0: mean loss = 0.17355275
# Start of epoch 858 i 0
# step 0: mean loss = 0.17341249
# Start of epoch 859 i 0
# step 0: mean loss = 0.17327262
# Start of epoch 860 i 0
# step 0: mean loss = 0.17314224
# Start of epoch 861 i 0
# step 0: mean loss = 0.17301486
# Start of epoch 862 i 0
# step 0: mean loss = 0.17290896
# Start of epoch 863 i 0
# step 0: mean loss = 0.17279977
# Start of epoch 864 i 0
# step 0: mean loss = 0.17267814
# Start of epoch 865 i 0
# step 0: mean loss = 0.17254628
# Start of epoch 866 i 0
# step 0: mean loss = 0.17242257
# Start of epoch 867 i 0
# step 0: mean loss = 0.1723456
# Start of epoch 868 i 0
# step 0: mean loss = 0.17227079
# Start of epoch 869 i 0
# step 0: mean loss = 0.17216444
# Start of epoch 870 i 0
# step 0: mean loss = 0.17203395
# Start of epoch 871 i 0
# step 0: mean loss = 0.17189722
# Start of epoch 872 i 0
# step 0: mean loss = 0.1717498
# Start of epoch 873 i 0
# step 0: mean loss = 0.17159775
# Start of epoch 874 i 0
# step 0: mean loss = 0.17144373
# Start of epoch 875 i 0
# step 0: mean loss = 0.17128937
# Start of epoch 876 i 0
# step 0: mean loss = 0.1711455
# Start of epoch 877 i 0
# step 0: mean loss = 0.17102014
# Start of epoch 878 i 0
# step 0: mean loss = 0.17091465
# Start of epoch 879 i 0
# step 0: mean loss = 0.1707994
# Start of epoch 880 i 0
# step 0: mean loss = 0.17067386
# Start of epoch 881 i 0
# step 0: mean loss = 0.17054302
# Start of epoch 882 i 0
# step 0: mean loss = 0.1704081
# Start of epoch 883 i 0
# step 0: mean loss = 0.17027393
# Start of epoch 884 i 0
# step 0: mean loss = 0.17015165
# Start of epoch 885 i 0
# step 0: mean loss = 0.17004536
# Start of epoch 886 i 0
# step 0: mean loss = 0.16991852
# Start of epoch 887 i 0
# step 0: mean loss = 0.1697882
# Start of epoch 888 i 0
# step 0: mean loss = 0.16966987
# Start of epoch 889 i 0
# step 0: mean loss = 0.16955568
# Start of epoch 890 i 0
# step 0: mean loss = 0.16943954
# Start of epoch 891 i 0
# step 0: mean loss = 0.16930467
# Start of epoch 892 i 0
# step 0: mean loss = 0.16916677
# Start of epoch 893 i 0
# step 0: mean loss = 0.16904035
# Start of epoch 894 i 0
# step 0: mean loss = 0.168927
# Start of epoch 895 i 0
# ...
# step 0: mean loss = 0.09100111
# Start of epoch 2211 i 0
# step 0: mean loss = 0.09097343
# Start of epoch 2212 i 0
# step 0: mean loss = 0.09094779
# Start of epoch 2213 i 0
# step 0: mean loss = 0.090923764
# Start of epoch 2214 i 0
# step 0: mean loss = 0.09090245
# Start of epoch 2215 i 0
# step 0: mean loss = 0.09088345
# Start of epoch 2216 i 0
# step 0: mean loss = 0.09086236
# Start of epoch 2217 i 0
# step 0: mean loss = 0.09084542
# Start of epoch 2218 i 0
# step 0: mean loss = 0.0908306
# Start of epoch 2219 i 0
# step 0: mean loss = 0.0908134
# Start of epoch 2220 i 0
# step 0: mean loss = 0.09078906
# Start of epoch 2221 i 0
# step 0: mean loss = 0.090761326
# Start of epoch 2222 i 0
# step 0: mean loss = 0.09073535
# Start of epoch 2223 i 0
# step 0: mean loss = 0.09070739
# Start of epoch 2224 i 0
# step 0: mean loss = 0.090676606
# Start of epoch 2225 i 0
# step 0: mean loss = 0.090645306
# Start of epoch 2226 i 0
# step 0: mean loss = 0.090613745
# Start of epoch 2227 i 0
# step 0: mean loss = 0.09058308
# Start of epoch 2228 i 0
# step 0: mean loss = 0.09055213
# Start of epoch 2229 i 0
# step 0: mean loss = 0.09052243
# Start of epoch 2230 i 0
# step 0: mean loss = 0.09049345
# Start of epoch 2231 i 0
# step 0: mean loss = 0.09046495
# Start of epoch 2232 i 0
# step 0: mean loss = 0.09043621
# Start of epoch 2233 i 0
# step 0: mean loss = 0.09040728
# Start of epoch 2234 i 0
# step 0: mean loss = 0.090378776
# Start of epoch 2235 i 0
# step 0: mean loss = 0.09034949
# Start of epoch 2236 i 0
# step 0: mean loss = 0.09031995
# Start of epoch 2237 i 0
# step 0: mean loss = 0.090290636
# Start of epoch 2238 i 0
# step 0: mean loss = 0.09026196
# Start of epoch 2239 i 0
# step 0: mean loss = 0.09023495
# Start of epoch 2240 i 0
# step 0: mean loss = 0.090206765
# Start of epoch 2241 i 0
# step 0: mean loss = 0.09018316
# Start of epoch 2242 i 0
# step 0: mean loss = 0.090166606
# Start of epoch 2243 i 0
# step 0: mean loss = 0.09015981
# Start of epoch 2244 i 0
# step 0: mean loss = 0.09017241
# Start of epoch 2245 i 0
# step 0: mean loss = 0.09017318
# Start of epoch 2246 i 0
# step 0: mean loss = 0.09017087
# Start of epoch 2247 i 0
# step 0: mean loss = 0.090156935
# Start of epoch 2248 i 0
# step 0: mean loss = 0.09013869
# Start of epoch 2249 i 0
# step 0: mean loss = 0.09012277
# Start of epoch 2250 i 0
# step 0: mean loss = 0.09009782
# Start of epoch 2251 i 0
# step 0: mean loss = 0.0900688
# Start of epoch 2252 i 0
# step 0: mean loss = 0.09003814
# Start of epoch 2253 i 0
# step 0: mean loss = 0.09000568
# Start of epoch 2254 i 0
# step 0: mean loss = 0.089973085
# Start of epoch 2255 i 0
# step 0: mean loss = 0.089949645
# Start of epoch 2256 i 0
# step 0: mean loss = 0.08991941
# Start of epoch 2257 i 0
# step 0: mean loss = 0.089889415
# Start of epoch 2258 i 0
# step 0: mean loss = 0.08986454
# Start of epoch 2259 i 0
# step 0: mean loss = 0.08983942
# Start of epoch 2260 i 0
# step 0: mean loss = 0.08980773
# Start of epoch 2261 i 0
# step 0: mean loss = 0.089779444
# Start of epoch 2262 i 0
# step 0: mean loss = 0.089748316
# Start of epoch 2263 i 0
# step 0: mean loss = 0.08971613
# Start of epoch 2264 i 0
# step 0: mean loss = 0.08968339
# Start of epoch 2265 i 0
# step 0: mean loss = 0.089651525
# Start of epoch 2266 i 0
# step 0: mean loss = 0.0896191
# Start of epoch 2267 i 0
# step 0: mean loss = 0.08958768
# Start of epoch 2268 i 0
# step 0: mean loss = 0.089555085
# Start of epoch 2269 i 0
# step 0: mean loss = 0.0895227
# Start of epoch 2270 i 0
# step 0: mean loss = 0.08949014
# Start of epoch 2271 i 0
# step 0: mean loss = 0.089458875
# Start of epoch 2272 i 0
# step 0: mean loss = 0.08942808
# Start of epoch 2273 i 0
# step 0: mean loss = 0.089396775
# Start of epoch 2274 i 0
# step 0: mean loss = 0.0893663
# Start of epoch 2275 i 0
# step 0: mean loss = 0.089335226
# Start of epoch 2276 i 0
# step 0: mean loss = 0.089304514
# Start of epoch 2277 i 0
# step 0: mean loss = 0.08927806
# Start of epoch 2278 i 0
# step 0: mean loss = 0.08925025
# Start of epoch 2279 i 0
# step 0: mean loss = 0.08922123
# Start of epoch 2280 i 0
# step 0: mean loss = 0.08918975
# Start of epoch 2281 i 0
# step 0: mean loss = 0.08915721
# Start of epoch 2282 i 0
# step 0: mean loss = 0.0891245
# Start of epoch 2283 i 0
# step 0: mean loss = 0.089091256
# Start of epoch 2284 i 0
# step 0: mean loss = 0.08905792
# Start of epoch 2285 i 0
# step 0: mean loss = 0.08902533
# Start of epoch 2286 i 0
# step 0: mean loss = 0.08899258
# Start of epoch 2287 i 0
# step 0: mean loss = 0.08896039
# Start of epoch 2288 i 0
# step 0: mean loss = 0.08892728
# Start of epoch 2289 i 0
# step 0: mean loss = 0.08889487
# Start of epoch 2290 i 0
# step 0: mean loss = 0.088862635
# Start of epoch 2291 i 0
# step 0: mean loss = 0.08883241
# Start of epoch 2292 i 0
# step 0: mean loss = 0.08880318
# Start of epoch 2293 i 0
# step 0: mean loss = 0.08877699
# Start of epoch 2294 i 0
# step 0: mean loss = 0.08876063
# Start of epoch 2295 i 0
# step 0: mean loss = 0.08875062
# Start of epoch 2296 i 0
# step 0: mean loss = 0.08874052
# Start of epoch 2297 i 0
# step 0: mean loss = 0.08873091
# Start of epoch 2298 i 0
# step 0: mean loss = 0.08871279
# Start of epoch 2299 i 0
# step 0: mean loss = 0.088691
# Start of epoch 2300 i 0
# step 0: mean loss = 0.088665195
# Start of epoch 2301 i 0
# step 0: mean loss = 0.08863751
# Start of epoch 2302 i 0
# step 0: mean loss = 0.088607535
# Start of epoch 2303 i 0
# step 0: mean loss = 0.08857665
# Start of epoch 2304 i 0
# step 0: mean loss = 0.08854474
# Start of epoch 2305 i 0
# step 0: mean loss = 0.08851274
# Start of epoch 2306 i 0
# step 0: mean loss = 0.08848061
# Start of epoch 2307 i 0
# step 0: mean loss = 0.08844904
# Start of epoch 2308 i 0
# step 0: mean loss = 0.08841779
# Start of epoch 2309 i 0
# step 0: mean loss = 0.08838634
# Start of epoch 2310 i 0
# step 0: mean loss = 0.08835427
# Start of epoch 2311 i 0
# step 0: mean loss = 0.08832158
# Start of epoch 2312 i 0
# step 0: mean loss = 0.08828883
# Start of epoch 2313 i 0
# step 0: mean loss = 0.08825624
# Start of epoch 2314 i 0
# step 0: mean loss = 0.08822376
# Start of epoch 2315 i 0
# step 0: mean loss = 0.08819154
# Start of epoch 2316 i 0
# step 0: mean loss = 0.08815933
# Start of epoch 2317 i 0
# step 0: mean loss = 0.088126674
# Start of epoch 2318 i 0
# step 0: mean loss = 0.08809424
# Start of epoch 2319 i 0
# step 0: mean loss = 0.08806259
# Start of epoch 2320 i 0
# step 0: mean loss = 0.088031106
# Start of epoch 2321 i 0
# step 0: mean loss = 0.088001
# Start of epoch 2322 i 0
# step 0: mean loss = 0.08797305
# Start of epoch 2323 i 0
# step 0: mean loss = 0.0879449
# Start of epoch 2324 i 0
# step 0: mean loss = 0.08791613
# Start of epoch 2325 i 0
# step 0: mean loss = 0.087887645
# Start of epoch 2326 i 0
# step 0: mean loss = 0.08786139
# Start of epoch 2327 i 0
# step 0: mean loss = 0.08783387
# Start of epoch 2328 i 0
# step 0: mean loss = 0.08780587
# Start of epoch 2329 i 0
# step 0: mean loss = 0.087776065
# Start of epoch 2330 i 0
# step 0: mean loss = 0.08774749
# Start of epoch 2331 i 0
# step 0: mean loss = 0.08773657
# Start of epoch 2332 i 0
# step 0: mean loss = 0.08771783
# Start of epoch 2333 i 0
# step 0: mean loss = 0.08769635
# Start of epoch 2334 i 0
# step 0: mean loss = 0.087674536
# Start of epoch 2335 i 0
# step 0: mean loss = 0.087646835
# Start of epoch 2336 i 0
# step 0: mean loss = 0.08762743
# Start of epoch 2337 i 0
# step 0: mean loss = 0.08760423
# Start of epoch 2338 i 0
# step 0: mean loss = 0.08758073
# Start of epoch 2339 i 0
# step 0: mean loss = 0.08755489
# Start of epoch 2340 i 0
# step 0: mean loss = 0.08752903
# Start of epoch 2341 i 0
# step 0: mean loss = 0.08750504
# Start of epoch 2342 i 0
# step 0: mean loss = 0.087478265
# Start of epoch 2343 i 0
# step 0: mean loss = 0.08745084
# Start of epoch 2344 i 0
# step 0: mean loss = 0.08742398
# Start of epoch 2345 i 0
# step 0: mean loss = 0.087397724
# Start of epoch 2346 i 0
# step 0: mean loss = 0.08736981
# Start of epoch 2347 i 0
# step 0: mean loss = 0.087340735
# Start of epoch 2348 i 0
# step 0: mean loss = 0.08731105
# Start of epoch 2349 i 0
# step 0: mean loss = 0.0872816
# Start of epoch 2350 i 0
# step 0: mean loss = 0.08725301
# Start of epoch 2351 i 0
# step 0: mean loss = 0.08722448
# Start of epoch 2352 i 0
# step 0: mean loss = 0.08719514
# Start of epoch 2353 i 0
# step 0: mean loss = 0.08716532
# Start of epoch 2354 i 0
# step 0: mean loss = 0.08713612
# Start of epoch 2355 i 0
# step 0: mean loss = 0.08710903
# Start of epoch 2356 i 0
# step 0: mean loss = 0.087088004
# Start of epoch 2357 i 0
# step 0: mean loss = 0.087062865
# Start of epoch 2358 i 0
# step 0: mean loss = 0.08703606
# Start of epoch 2359 i 0
# step 0: mean loss = 0.08700803
# Start of epoch 2360 i 0
# step 0: mean loss = 0.086979
# Start of epoch 2361 i 0
# step 0: mean loss = 0.08695188
# Start of epoch 2362 i 0
# step 0: mean loss = 0.08693448
# Start of epoch 2363 i 0
# step 0: mean loss = 0.08693221
# Start of epoch 2364 i 0
# step 0: mean loss = 0.0869198
# Start of epoch 2365 i 0
# step 0: mean loss = 0.08690071
# Start of epoch 2366 i 0
# step 0: mean loss = 0.08687656
# Start of epoch 2367 i 0
# step 0: mean loss = 0.086849056
# Start of epoch 2368 i 0
# step 0: mean loss = 0.08681981
# Start of epoch 2369 i 0
# step 0: mean loss = 0.08678946
# Start of epoch 2370 i 0
# step 0: mean loss = 0.08675863
# Start of epoch 2371 i 0
# step 0: mean loss = 0.086729586
# Start of epoch 2372 i 0
# step 0: mean loss = 0.08670199
# Start of epoch 2373 i 0
# step 0: mean loss = 0.08667567
# Start of epoch 2374 i 0
# step 0: mean loss = 0.08665312
# Start of epoch 2375 i 0
# step 0: mean loss = 0.08663145
# Start of epoch 2376 i 0
# step 0: mean loss = 0.0866078
# Start of epoch 2377 i 0
# step 0: mean loss = 0.08658171
# Start of epoch 2378 i 0
# step 0: mean loss = 0.08655637
# Start of epoch 2379 i 0
# step 0: mean loss = 0.08653061
# Start of epoch 2380 i 0
# step 0: mean loss = 0.0865015
# Start of epoch 2381 i 0
# step 0: mean loss = 0.08647113
# Start of epoch 2382 i 0
# step 0: mean loss = 0.08643948
# Start of epoch 2383 i 0
# step 0: mean loss = 0.086407766
# Start of epoch 2384 i 0
# step 0: mean loss = 0.08637617
# Start of epoch 2385 i 0
# step 0: mean loss = 0.086344905
# Start of epoch 2386 i 0
# step 0: mean loss = 0.08631442
# Start of epoch 2387 i 0
# step 0: mean loss = 0.08628429
# Start of epoch 2388 i 0
# step 0: mean loss = 0.08625468
# Start of epoch 2389 i 0
# step 0: mean loss = 0.08622528
# Start of epoch 2390 i 0
# step 0: mean loss = 0.08619649
# Start of epoch 2391 i 0
# step 0: mean loss = 0.086168565
# Start of epoch 2392 i 0
# step 0: mean loss = 0.08614031
# Start of epoch 2393 i 0
# step 0: mean loss = 0.08611122
# Start of epoch 2394 i 0
# step 0: mean loss = 0.08608205
# Start of epoch 2395 i 0
# step 0: mean loss = 0.086054295
# Start of epoch 2396 i 0
# step 0: mean loss = 0.086026475
# Start of epoch 2397 i 0
# step 0: mean loss = 0.08599802
# Start of epoch 2398 i 0
# step 0: mean loss = 0.085969225
# Start of epoch 2399 i 0
# step 0: mean loss = 0.08594056
# Start of epoch 2400 i 0
# step 0: mean loss = 0.08591156
# Start of epoch 2401 i 0
# step 0: mean loss = 0.0858826
# Start of epoch 2402 i 0
# step 0: mean loss = 0.08585428
# Start of epoch 2403 i 0
# step 0: mean loss = 0.085825466
# Start of epoch 2404 i 0
# step 0: mean loss = 0.08579668
# Start of epoch 2405 i 0
# step 0: mean loss = 0.08577008
# Start of epoch 2406 i 0
# step 0: mean loss = 0.08574549
# Start of epoch 2407 i 0
# step 0: mean loss = 0.08572297
# Start of epoch 2408 i 0
# step 0: mean loss = 0.08569871
# Start of epoch 2409 i 0
# step 0: mean loss = 0.08567723
# Start of epoch 2410 i 0
# step 0: mean loss = 0.085654385
# Start of epoch 2411 i 0
# step 0: mean loss = 0.085631646
# Start of epoch 2412 i 0
# step 0: mean loss = 0.085609734
# Start of epoch 2413 i 0
# step 0: mean loss = 0.08558588
# Start of epoch 2414 i 0
# step 0: mean loss = 0.08555908
# Start of epoch 2415 i 0
# step 0: mean loss = 0.08553084
# Start of epoch 2416 i 0
# step 0: mean loss = 0.08550166
# Start of epoch 2417 i 0
# step 0: mean loss = 0.08547071
# Start of epoch 2418 i 0
# step 0: mean loss = 0.085439265
# Start of epoch 2419 i 0
# step 0: mean loss = 0.08540754
# Start of epoch 2420 i 0
# step 0: mean loss = 0.085376434
# Start of epoch 2421 i 0
# step 0: mean loss = 0.08534535
# Start of epoch 2422 i 0
# step 0: mean loss = 0.085314915
# Start of epoch 2423 i 0
# step 0: mean loss = 0.08528515
# Start of epoch 2424 i 0
# step 0: mean loss = 0.08525682
# Start of epoch 2425 i 0
# step 0: mean loss = 0.085228354
# Start of epoch 2426 i 0
# step 0: mean loss = 0.08519993
# Start of epoch 2427 i 0
# step 0: mean loss = 0.08517077
# Start of epoch 2428 i 0
# step 0: mean loss = 0.085142605
# Start of epoch 2429 i 0
# step 0: mean loss = 0.08511484
# Start of epoch 2430 i 0
# step 0: mean loss = 0.08508709
# Start of epoch 2431 i 0
# step 0: mean loss = 0.085059114
# Start of epoch 2432 i 0
# step 0: mean loss = 0.08503044
# Start of epoch 2433 i 0
# step 0: mean loss = 0.08500174
# Start of epoch 2434 i 0
# step 0: mean loss = 0.08497311
# Start of epoch 2435 i 0
# step 0: mean loss = 0.0849459
# Start of epoch 2436 i 0
# step 0: mean loss = 0.08491872
# Start of epoch 2437 i 0
# step 0: mean loss = 0.0848917
# Start of epoch 2438 i 0
# step 0: mean loss = 0.084881276
# Start of epoch 2439 i 0
# step 0: mean loss = 0.08488724
# Start of epoch 2440 i 0
# step 0: mean loss = 0.08490565
# Start of epoch 2441 i 0
# step 0: mean loss = 0.08490875
# Start of epoch 2442 i 0
# step 0: mean loss = 0.08489817
# Start of epoch 2443 i 0
# step 0: mean loss = 0.08488089
# Start of epoch 2444 i 0
# step 0: mean loss = 0.08485741
# Start of epoch 2445 i 0
# step 0: mean loss = 0.084830835
# Start of epoch 2446 i 0
# step 0: mean loss = 0.08480133
# Start of epoch 2447 i 0
# step 0: mean loss = 0.08477082
# Start of epoch 2448 i 0
# step 0: mean loss = 0.08473977
# Start of epoch 2449 i 0
# step 0: mean loss = 0.08470827
# Start of epoch 2450 i 0
# step 0: mean loss = 0.08467657
# Start of epoch 2451 i 0
# step 0: mean loss = 0.08464479
# Start of epoch 2452 i 0
# step 0: mean loss = 0.08461301
# Start of epoch 2453 i 0
# step 0: mean loss = 0.08458143
# Start of epoch 2454 i 0
# step 0: mean loss = 0.08455016
# Start of epoch 2455 i 0
# step 0: mean loss = 0.08451934
# Start of epoch 2456 i 0
# step 0: mean loss = 0.084489696
# Start of epoch 2457 i 0
# step 0: mean loss = 0.0844602
# Start of epoch 2458 i 0
# step 0: mean loss = 0.08443164
# Start of epoch 2459 i 0
# step 0: mean loss = 0.08440364
# Start of epoch 2460 i 0
# step 0: mean loss = 0.08437877
# Start of epoch 2461 i 0
# step 0: mean loss = 0.08436886
# Start of epoch 2462 i 0
# step 0: mean loss = 0.084381185
# Start of epoch 2463 i 0
# step 0: mean loss = 0.084393434
# Start of epoch 2464 i 0
# step 0: mean loss = 0.08439366
# Start of epoch 2465 i 0
# step 0: mean loss = 0.08440151
# Start of epoch 2466 i 0
# step 0: mean loss = 0.08439322
# Start of epoch 2467 i 0
# step 0: mean loss = 0.084379084
# Start of epoch 2468 i 0
# step 0: mean loss = 0.08436414
# Start of epoch 2469 i 0
# step 0: mean loss = 0.08434495
# Start of epoch 2470 i 0
# step 0: mean loss = 0.084323846
# Start of epoch 2471 i 0
# step 0: mean loss = 0.08429861
# Start of epoch 2472 i 0
# step 0: mean loss = 0.084270924
# Start of epoch 2473 i 0
# step 0: mean loss = 0.08424212
# Start of epoch 2474 i 0
# step 0: mean loss = 0.08421274
# Start of epoch 2475 i 0
# step 0: mean loss = 0.08418302
# Start of epoch 2476 i 0
# step 0: mean loss = 0.08415331
# Start of epoch 2477 i 0
# step 0: mean loss = 0.084123716
# Start of epoch 2478 i 0
# step 0: mean loss = 0.084094614
# Start of epoch 2479 i 0
# step 0: mean loss = 0.08406561
# Start of epoch 2480 i 0
# step 0: mean loss = 0.08403709
# Start of epoch 2481 i 0
# step 0: mean loss = 0.084009126
# Start of epoch 2482 i 0
# step 0: mean loss = 0.083981976
# Start of epoch 2483 i 0
# step 0: mean loss = 0.08395408
# Start of epoch 2484 i 0
# step 0: mean loss = 0.08392553
# Start of epoch 2485 i 0
# step 0: mean loss = 0.08389685
# Start of epoch 2486 i 0
# step 0: mean loss = 0.083867766
# Start of epoch 2487 i 0
# step 0: mean loss = 0.08383866
# Start of epoch 2488 i 0
# step 0: mean loss = 0.08380962
# Start of epoch 2489 i 0
# step 0: mean loss = 0.083781086
# Start of epoch 2490 i 0
# step 0: mean loss = 0.0837523
# Start of epoch 2491 i 0
# step 0: mean loss = 0.083724745
# Start of epoch 2492 i 0
# step 0: mean loss = 0.08369825
# Start of epoch 2493 i 0
# step 0: mean loss = 0.08367153
# Start of epoch 2494 i 0
# step 0: mean loss = 0.08364374
# Start of epoch 2495 i 0
# step 0: mean loss = 0.08361644
# Start of epoch 2496 i 0
# step 0: mean loss = 0.08358965
# Start of epoch 2497 i 0
# step 0: mean loss = 0.08356302
# Start of epoch 2498 i 0
# step 0: mean loss = 0.08353709
# Start of epoch 2499 i 0
# step 0: mean loss = 0.08351075
# 0.1111111111111111 1

# %%
qy_mean_est = np.zeros((all_time,neuron_num))
for step, x_batch_train in enumerate(batched_dataset):
    qy_mean_est[Time*step:Time*(step+1),:] = vae(x_batch_train)
for i in range(neuron_num):
    plt.figure()
    plt.ylim(-2,20)
    plt.plot(y_data[:,i],"k",linewidth = 3)
    plt.plot(qy_mean_est[:,i],"r",linewidth = 1)
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
qz_mean_est = np.zeros((all_time,factor_dim))
for step, x_batch_train in enumerate(batched_dataset):
    qz_mean_est[Time*step:Time*(step+1),:] = vae.latent(x_batch_train)
wgt = np.linalg.lstsq(qz_mean_est-qz_mean_est.mean(), traj-traj.mean())[0] 
qz_mean_est = np.dot(qz_mean_est,wgt)
qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # Evaluate Quality of reconstruction

# %%
z_true_c = traj - traj.mean(axis=0)
z_true_norm = z_true_c/np.linalg.norm(z_true_c)
R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
fig = plt.figure(figsize=(12,12))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure()
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
