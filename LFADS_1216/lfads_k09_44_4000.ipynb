# %% [markdown]
# Our aim is to reproduce an example from the paper:
#
# [Inferring single-trial neural population dynamics using sequential auto-encoders](https://www.nature.com/articles/s41592-018-0109-9)
#
# We will generate trajectories from a latent Lorentz attractor and apply LFADS to recover the latent dynamic. Instead of using the original code (https://lfads.github.io/lfads-run-manager/) we will use tensorflow 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import scipy.io
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
import funs

# %% [markdown]
# # Sample from latent Lorenz attractor:

# %%
all_time =3000
Time = 10
neuron_num = 85
datax = scipy.io.loadmat("spike85_k09_6000.mat")
y_data = datax["spike85_k09_6000"][:,:all_time].T
traj = scipy.io.loadmat("trj85_k09_6000.mat")
traj = traj["trj85_k09_6000"][:,:all_time].T

# %%
factor_dim = 2

NRep=int(all_time/Time)
output = np.zeros((NRep,Time,neuron_num))
print(y_data.shape)
for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    
output = output.astype('float32')

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
# Out:
# (3000, 85)
# (10, 85)

# %%
#for i in range(neuron_num):
#    fig, ax = plt.subplots()
#    mappable = ax.scatter(traj[:,0], traj[:,1], c=y_data[:,i] ,cmap='coolwarm',vmin=0,vmax=8)
#    fig.colorbar(mappable)
#    plt.show()

# %%
plt.figure()
plt.imshow(output[0,:,:].T,aspect='auto')
plt.xlabel('time')
plt.ylabel('neuron')
plt.colorbar()
plt.show()

# %%
dataset = tf.data.Dataset.from_tensor_slices((output))
#print(dataset)
#dataset = dataset.shuffle(20, reshuffle_each_iteration=True)

# %% [markdown]
# # Autoencoder Model

# %%
tf.keras.backend.clear_session()

# %%
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
class Encoder(tf.keras.layers.Layer):
    """Maps Trajectory to a triplet (z_mean, z_log_var, z)."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)        
        self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(num_gru_unit,return_sequences=False), 
                                                       input_shape=(sequence_length, num_input_neuron))
        self.dense_mean = tf.keras.layers.Dense(latent_dim)
        self.dense_log_var = tf.keras.layers.Dense(latent_dim)
        self.sampling = Sampling()
        
    def call(self, inputs):
        x = self.bidir_gru(inputs)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

# %%
class Decoder(tf.keras.layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""
    def __init__(self,
                 latent_dim=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=2,
                 name='decoder',
                 **kwargs):
        self.sequence_length = sequence_length
        super(Decoder, self).__init__(name=name, **kwargs)
        self.recurrent_decoder = tf.keras.layers.GRU(latent_dim,return_sequences=True)#,use_bias=False)
        self.linear_bottleneck = tf.keras.layers.Dense(num_factor, activation=None)
        self.dense_output = tf.keras.layers.Dense(256, activation='relu')
        self.dense_output1 = tf.keras.layers.Dense(256, activation='relu')
        self.dense_output2 = tf.keras.layers.Dense(num_input_neuron, activation=None)
        self.latent_dim=latent_dim
        
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        null_input = tf.zeros([batch_size,self.sequence_length,self.latent_dim])
        decoder_output = self.recurrent_decoder(null_input, initial_state=inputs)
        x = self.linear_bottleneck(decoder_output)
        x2 = self.dense_output(x)
        x2 = self.dense_output1(x2)
        xo = self.dense_output2(x2)
        #xo = tf.exp(self.dense_output2(x2))
        return xo, x

# %%
class VariationalAutoEncoder(tf.keras.Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=2,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.encoder = Encoder(latent_dim=latent_dim,num_gru_unit=num_gru_unit,sequence_length=sequence_length,
                               num_input_neuron=num_input_neuron)
        self.decoder = Decoder(latent_dim=latent_dim, sequence_length=sequence_length,
                              num_input_neuron=num_input_neuron,num_factor=num_factor)
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)[0]
        # Add KL divergence regularization loss.
        kl_loss = - 0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        self.add_loss(kl_loss)
        return reconstructed
    def latent(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        latent = self.decoder(z)[1]
        return latent

# %%
BATCH_SIZE = 10
batched_dataset = dataset.batch(BATCH_SIZE)

# %%
vae = VariationalAutoEncoder(latent_dim=64,
                             num_gru_unit=64,
                             sequence_length=Time,
                             num_input_neuron=neuron_num,
                             num_factor=factor_dim)

# %% [markdown]
# # Train Model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-4,clipvalue=200)
mse_loss_fn = tf.keras.losses.MeanSquaredError()
loss_metric = tf.keras.metrics.Mean()

# %% [markdown]
# #### Linearly scheduling on the Kullback–Leibler divergence penalty:
#
# We use a linearly increasing schedule on the Kullback–Leibler divergence penalty (as suggested [here](https://arxiv.org/pdf/1511.06349.pdf)) so that the optimization does not quickly (and pathologically) set the Kullback–Leibler divergence to 0

# %%
KL_penalty = np.linspace(0,1,10)

# %%
epochs = 680

for i,kl_ in enumerate(KL_penalty):
    print(kl_,i)
    if i > 0:
        break
    # Iterate over epochs.
    for epoch in range(epochs):
        print('Start of epoch %d' % (epoch,),'i',i)

        # Iterate over the batches of the dataset.
        for step, x_batch_train in enumerate(batched_dataset):
            with tf.GradientTape() as tape:
                reconstructed = vae(x_batch_train)
                # Compute reconstruction loss
                loss = mse_loss_fn(x_batch_train, reconstructed)
                #print("loss",loss,"kl",sum(vae.losses))
                loss += kl_*sum(vae.losses)  # Add KLD regularization loss

            grads = tape.gradient(loss, vae.trainable_weights)
            optimizer.apply_gradients(zip(grads, vae.trainable_weights))
            loss_metric(loss)

            if step % 100 == 0:
                print('step %s: mean loss = %s' % (step, loss_metric.result().numpy()))
# Out:
# 0.0 0
# Start of epoch 0 i 0
# step 0: mean loss = 1.2855667
# Start of epoch 1 i 0
# step 0: mean loss = 1.0106899
# Start of epoch 2 i 0
# step 0: mean loss = 1.0042315
# Start of epoch 3 i 0
# step 0: mean loss = 0.9984793
# Start of epoch 4 i 0
# step 0: mean loss = 0.9934584
# Start of epoch 5 i 0
# step 0: mean loss = 0.98876536
# Start of epoch 6 i 0
# step 0: mean loss = 0.98445004
# Start of epoch 7 i 0
# step 0: mean loss = 0.98016596
# Start of epoch 8 i 0
# step 0: mean loss = 0.9758284
# Start of epoch 9 i 0
# step 0: mean loss = 0.9715896
# Start of epoch 10 i 0
# step 0: mean loss = 0.9675257
# Start of epoch 11 i 0
# step 0: mean loss = 0.9634948
# Start of epoch 12 i 0
# step 0: mean loss = 0.9600016
# Start of epoch 13 i 0
# step 0: mean loss = 0.9567415
# Start of epoch 14 i 0
# step 0: mean loss = 0.9537019
# Start of epoch 15 i 0
# step 0: mean loss = 0.9509453
# Start of epoch 16 i 0
# step 0: mean loss = 0.9481528
# Start of epoch 17 i 0
# step 0: mean loss = 0.9456107
# Start of epoch 18 i 0
# step 0: mean loss = 0.9431269
# Start of epoch 19 i 0
# step 0: mean loss = 0.94097096
# Start of epoch 20 i 0
# step 0: mean loss = 0.9387103
# Start of epoch 21 i 0
# step 0: mean loss = 0.9366102
# Start of epoch 22 i 0
# step 0: mean loss = 0.9346115
# Start of epoch 23 i 0
# step 0: mean loss = 0.93269676
# Start of epoch 24 i 0
# step 0: mean loss = 0.9308437
# Start of epoch 25 i 0
# step 0: mean loss = 0.92899793
# Start of epoch 26 i 0
# step 0: mean loss = 0.92729026
# Start of epoch 27 i 0
# step 0: mean loss = 0.9255907
# Start of epoch 28 i 0
# step 0: mean loss = 0.9241762
# Start of epoch 29 i 0
# step 0: mean loss = 0.92248815
# Start of epoch 30 i 0
# step 0: mean loss = 0.92087597
# Start of epoch 31 i 0
# step 0: mean loss = 0.91922295
# Start of epoch 32 i 0
# step 0: mean loss = 0.91765124
# Start of epoch 33 i 0
# step 0: mean loss = 0.91599023
# Start of epoch 34 i 0
# step 0: mean loss = 0.9143712
# Start of epoch 35 i 0
# step 0: mean loss = 0.91293013
# Start of epoch 36 i 0
# step 0: mean loss = 0.91144526
# Start of epoch 37 i 0
# step 0: mean loss = 0.91013825
# Start of epoch 38 i 0
# step 0: mean loss = 0.9087984
# Start of epoch 39 i 0
# step 0: mean loss = 0.90745765
# Start of epoch 40 i 0
# step 0: mean loss = 0.9061818
# Start of epoch 41 i 0
# step 0: mean loss = 0.9051134
# Start of epoch 42 i 0
# step 0: mean loss = 0.9039144
# Start of epoch 43 i 0
# step 0: mean loss = 0.90279764
# Start of epoch 44 i 0
# step 0: mean loss = 0.9018576
# Start of epoch 45 i 0
# step 0: mean loss = 0.9008794
# Start of epoch 46 i 0
# step 0: mean loss = 0.89999956
# Start of epoch 47 i 0
# step 0: mean loss = 0.89894515
# Start of epoch 48 i 0
# step 0: mean loss = 0.8979627
# Start of epoch 49 i 0
# step 0: mean loss = 0.89685017
# Start of epoch 50 i 0
# step 0: mean loss = 0.8957145
# Start of epoch 51 i 0
# step 0: mean loss = 0.89459413
# Start of epoch 52 i 0
# step 0: mean loss = 0.8934832
# Start of epoch 53 i 0
# step 0: mean loss = 0.89234084
# Start of epoch 54 i 0
# step 0: mean loss = 0.8912685
# Start of epoch 55 i 0
# step 0: mean loss = 0.8902494
# Start of epoch 56 i 0
# step 0: mean loss = 0.8892359
# Start of epoch 57 i 0
# step 0: mean loss = 0.888375
# Start of epoch 58 i 0
# step 0: mean loss = 0.8875266
# Start of epoch 59 i 0
# step 0: mean loss = 0.8866917
# Start of epoch 60 i 0
# step 0: mean loss = 0.88578576
# Start of epoch 61 i 0
# step 0: mean loss = 0.88494146
# Start of epoch 62 i 0
# step 0: mean loss = 0.8840216
# Start of epoch 63 i 0
# step 0: mean loss = 0.88313687
# Start of epoch 64 i 0
# step 0: mean loss = 0.8821677
# Start of epoch 65 i 0
# step 0: mean loss = 0.8812371
# Start of epoch 66 i 0
# step 0: mean loss = 0.88036704
# Start of epoch 67 i 0
# step 0: mean loss = 0.8794981
# Start of epoch 68 i 0
# step 0: mean loss = 0.878661
# Start of epoch 69 i 0
# step 0: mean loss = 0.8777692
# Start of epoch 70 i 0
# step 0: mean loss = 0.8768727
# Start of epoch 71 i 0
# step 0: mean loss = 0.87597823
# Start of epoch 72 i 0
# step 0: mean loss = 0.8751518
# Start of epoch 73 i 0
# step 0: mean loss = 0.8743204
# Start of epoch 74 i 0
# step 0: mean loss = 0.873551
# Start of epoch 75 i 0
# step 0: mean loss = 0.87274873
# Start of epoch 76 i 0
# step 0: mean loss = 0.8720143
# Start of epoch 77 i 0
# step 0: mean loss = 0.87124926
# Start of epoch 78 i 0
# step 0: mean loss = 0.8704826
# Start of epoch 79 i 0
# step 0: mean loss = 0.8696902
# Start of epoch 80 i 0
# step 0: mean loss = 0.8689774
# Start of epoch 81 i 0
# step 0: mean loss = 0.86827976
# Start of epoch 82 i 0
# step 0: mean loss = 0.86756396
# Start of epoch 83 i 0
# step 0: mean loss = 0.86681664
# Start of epoch 84 i 0
# step 0: mean loss = 0.8660849
# Start of epoch 85 i 0
# step 0: mean loss = 0.8653535
# Start of epoch 86 i 0
# step 0: mean loss = 0.864568
# Start of epoch 87 i 0
# step 0: mean loss = 0.86379683
# Start of epoch 88 i 0
# step 0: mean loss = 0.86302215
# Start of epoch 89 i 0
# step 0: mean loss = 0.86235076
# Start of epoch 90 i 0
# step 0: mean loss = 0.86165017
# Start of epoch 91 i 0
# step 0: mean loss = 0.86100906
# Start of epoch 92 i 0
# step 0: mean loss = 0.86033183
# Start of epoch 93 i 0
# step 0: mean loss = 0.8596738
# Start of epoch 94 i 0
# step 0: mean loss = 0.8589928
# Start of epoch 95 i 0
# step 0: mean loss = 0.85834116
# Start of epoch 96 i 0
# step 0: mean loss = 0.8576471
# Start of epoch 97 i 0
# step 0: mean loss = 0.8569779
# Start of epoch 98 i 0
# step 0: mean loss = 0.85628235
# Start of epoch 99 i 0
# step 0: mean loss = 0.8555955
# Start of epoch 100 i 0
# step 0: mean loss = 0.8549413
# Start of epoch 101 i 0
# step 0: mean loss = 0.85430807
# Start of epoch 102 i 0
# step 0: mean loss = 0.8536585
# Start of epoch 103 i 0
# step 0: mean loss = 0.85300857
# Start of epoch 104 i 0
# step 0: mean loss = 0.85240465
# Start of epoch 105 i 0
# step 0: mean loss = 0.8517913
# Start of epoch 106 i 0
# step 0: mean loss = 0.85117984
# Start of epoch 107 i 0
# step 0: mean loss = 0.8505212
# Start of epoch 108 i 0
# step 0: mean loss = 0.84990233
# Start of epoch 109 i 0
# step 0: mean loss = 0.8492783
# Start of epoch 110 i 0
# step 0: mean loss = 0.8486584
# Start of epoch 111 i 0
# step 0: mean loss = 0.8479988
# Start of epoch 112 i 0
# step 0: mean loss = 0.84736073
# Start of epoch 113 i 0
# step 0: mean loss = 0.84673315
# Start of epoch 114 i 0
# step 0: mean loss = 0.846119
# Start of epoch 115 i 0
# step 0: mean loss = 0.8455247
# Start of epoch 116 i 0
# step 0: mean loss = 0.84499454
# Start of epoch 117 i 0
# step 0: mean loss = 0.84449464
# Start of epoch 118 i 0
# step 0: mean loss = 0.8439426
# Start of epoch 119 i 0
# step 0: mean loss = 0.84337974
# Start of epoch 120 i 0
# step 0: mean loss = 0.8428116
# Start of epoch 121 i 0
# step 0: mean loss = 0.84225225
# Start of epoch 122 i 0
# step 0: mean loss = 0.8416481
# Start of epoch 123 i 0
# step 0: mean loss = 0.84106
# Start of epoch 124 i 0
# step 0: mean loss = 0.8404559
# Start of epoch 125 i 0
# step 0: mean loss = 0.83986366
# Start of epoch 126 i 0
# step 0: mean loss = 0.83926123
# Start of epoch 127 i 0
# step 0: mean loss = 0.83870673
# Start of epoch 128 i 0
# step 0: mean loss = 0.8381291
# Start of epoch 129 i 0
# step 0: mean loss = 0.83763343
# Start of epoch 130 i 0
# step 0: mean loss = 0.83711195
# Start of epoch 131 i 0
# step 0: mean loss = 0.83667445
# Start of epoch 132 i 0
# step 0: mean loss = 0.8361703
# Start of epoch 133 i 0
# step 0: mean loss = 0.83566344
# Start of epoch 134 i 0
# step 0: mean loss = 0.8351372
# Start of epoch 135 i 0
# step 0: mean loss = 0.8346187
# Start of epoch 136 i 0
# step 0: mean loss = 0.83407646
# Start of epoch 137 i 0
# step 0: mean loss = 0.8335894
# Start of epoch 138 i 0
# step 0: mean loss = 0.8331044
# Start of epoch 139 i 0
# step 0: mean loss = 0.8326033
# Start of epoch 140 i 0
# step 0: mean loss = 0.8320819
# Start of epoch 141 i 0
# step 0: mean loss = 0.8315732
# Start of epoch 142 i 0
# step 0: mean loss = 0.83106834
# Start of epoch 143 i 0
# step 0: mean loss = 0.83054024
# Start of epoch 144 i 0
# step 0: mean loss = 0.8300059
# Start of epoch 145 i 0
# step 0: mean loss = 0.82947445
# Start of epoch 146 i 0
# step 0: mean loss = 0.8289458
# Start of epoch 147 i 0
# step 0: mean loss = 0.8284143
# Start of epoch 148 i 0
# step 0: mean loss = 0.8278744
# Start of epoch 149 i 0
# step 0: mean loss = 0.8273518
# Start of epoch 150 i 0
# step 0: mean loss = 0.8268394
# Start of epoch 151 i 0
# step 0: mean loss = 0.82636833
# Start of epoch 152 i 0
# step 0: mean loss = 0.82589483
# Start of epoch 153 i 0
# step 0: mean loss = 0.82542443
# Start of epoch 154 i 0
# step 0: mean loss = 0.8249364
# Start of epoch 155 i 0
# step 0: mean loss = 0.8244962
# Start of epoch 156 i 0
# step 0: mean loss = 0.8240344
# Start of epoch 157 i 0
# step 0: mean loss = 0.8235895
# Start of epoch 158 i 0
# step 0: mean loss = 0.8231213
# Start of epoch 159 i 0
# step 0: mean loss = 0.8226453
# Start of epoch 160 i 0
# step 0: mean loss = 0.822156
# Start of epoch 161 i 0
# step 0: mean loss = 0.82165825
# Start of epoch 162 i 0
# step 0: mean loss = 0.82116574
# Start of epoch 163 i 0
# step 0: mean loss = 0.82067674
# Start of epoch 164 i 0
# step 0: mean loss = 0.82018673
# Start of epoch 165 i 0
# step 0: mean loss = 0.8197184
# Start of epoch 166 i 0
# step 0: mean loss = 0.8192606
# Start of epoch 167 i 0
# step 0: mean loss = 0.81883645
# Start of epoch 168 i 0
# step 0: mean loss = 0.818417
# Start of epoch 169 i 0
# step 0: mean loss = 0.81798214
# Start of epoch 170 i 0
# step 0: mean loss = 0.81753385
# Start of epoch 171 i 0
# step 0: mean loss = 0.81708896
# Start of epoch 172 i 0
# step 0: mean loss = 0.8166701
# Start of epoch 173 i 0
# step 0: mean loss = 0.81624484
# Start of epoch 174 i 0
# step 0: mean loss = 0.8157988
# Start of epoch 175 i 0
# step 0: mean loss = 0.815345
# Start of epoch 176 i 0
# step 0: mean loss = 0.8148993
# Start of epoch 177 i 0
# step 0: mean loss = 0.8144546
# Start of epoch 178 i 0
# step 0: mean loss = 0.8139859
# Start of epoch 179 i 0
# step 0: mean loss = 0.8135326
# Start of epoch 180 i 0
# step 0: mean loss = 0.81308955
# Start of epoch 181 i 0
# step 0: mean loss = 0.81263936
# Start of epoch 182 i 0
# step 0: mean loss = 0.81218064
# Start of epoch 183 i 0
# step 0: mean loss = 0.81172776
# Start of epoch 184 i 0
# step 0: mean loss = 0.8112856
# Start of epoch 185 i 0
# step 0: mean loss = 0.8108287
# Start of epoch 186 i 0
# step 0: mean loss = 0.8103642
# Start of epoch 187 i 0
# step 0: mean loss = 0.8099085
# Start of epoch 188 i 0
# step 0: mean loss = 0.80948204
# Start of epoch 189 i 0
# step 0: mean loss = 0.80907
# Start of epoch 190 i 0
# step 0: mean loss = 0.80865586
# Start of epoch 191 i 0
# step 0: mean loss = 0.8082474
# Start of epoch 192 i 0
# step 0: mean loss = 0.80787313
# Start of epoch 193 i 0
# step 0: mean loss = 0.8074781
# Start of epoch 194 i 0
# step 0: mean loss = 0.80706775
# Start of epoch 195 i 0
# step 0: mean loss = 0.8066613
# Start of epoch 196 i 0
# step 0: mean loss = 0.8062798
# Start of epoch 197 i 0
# step 0: mean loss = 0.8059299
# Start of epoch 198 i 0
# step 0: mean loss = 0.805573
# Start of epoch 199 i 0
# step 0: mean loss = 0.80522764
# Start of epoch 200 i 0
# step 0: mean loss = 0.8048648
# Start of epoch 201 i 0
# step 0: mean loss = 0.8044775
# Start of epoch 202 i 0
# step 0: mean loss = 0.8040646
# Start of epoch 203 i 0
# step 0: mean loss = 0.80364954
# Start of epoch 204 i 0
# step 0: mean loss = 0.8032399
# Start of epoch 205 i 0
# step 0: mean loss = 0.80288273
# Start of epoch 206 i 0
# step 0: mean loss = 0.8024924
# Start of epoch 207 i 0
# step 0: mean loss = 0.8021032
# Start of epoch 208 i 0
# step 0: mean loss = 0.80169845
# Start of epoch 209 i 0
# step 0: mean loss = 0.801332
# Start of epoch 210 i 0
# step 0: mean loss = 0.80095506
# Start of epoch 211 i 0
# step 0: mean loss = 0.80057573
# Start of epoch 212 i 0
# step 0: mean loss = 0.800186
# Start of epoch 213 i 0
# step 0: mean loss = 0.799827
# Start of epoch 214 i 0
# step 0: mean loss = 0.7994521
# Start of epoch 215 i 0
# step 0: mean loss = 0.79907644
# Start of epoch 216 i 0
# step 0: mean loss = 0.7986768
# Start of epoch 217 i 0
# step 0: mean loss = 0.79828787
# Start of epoch 218 i 0
# step 0: mean loss = 0.7978829
# Start of epoch 219 i 0
# step 0: mean loss = 0.7974762
# Start of epoch 220 i 0
# step 0: mean loss = 0.7970822
# Start of epoch 221 i 0
# step 0: mean loss = 0.79670566
# Start of epoch 222 i 0
# step 0: mean loss = 0.79633504
# Start of epoch 223 i 0
# step 0: mean loss = 0.79596865
# Start of epoch 224 i 0
# step 0: mean loss = 0.79560226
# Start of epoch 225 i 0
# step 0: mean loss = 0.79525334
# Start of epoch 226 i 0
# step 0: mean loss = 0.794915
# Start of epoch 227 i 0
# step 0: mean loss = 0.79460657
# Start of epoch 228 i 0
# step 0: mean loss = 0.794296
# Start of epoch 229 i 0
# step 0: mean loss = 0.79395074
# Start of epoch 230 i 0
# step 0: mean loss = 0.79360694
# Start of epoch 231 i 0
# step 0: mean loss = 0.79324704
# Start of epoch 232 i 0
# step 0: mean loss = 0.7928633
# Start of epoch 233 i 0
# step 0: mean loss = 0.79248416
# Start of epoch 234 i 0
# step 0: mean loss = 0.7921262
# Start of epoch 235 i 0
# step 0: mean loss = 0.79176116
# Start of epoch 236 i 0
# step 0: mean loss = 0.79138154
# Start of epoch 237 i 0
# step 0: mean loss = 0.790987
# Start of epoch 238 i 0
# step 0: mean loss = 0.7906136
# Start of epoch 239 i 0
# step 0: mean loss = 0.7902431
# Start of epoch 240 i 0
# step 0: mean loss = 0.7898832
# Start of epoch 241 i 0
# step 0: mean loss = 0.7895585
# Start of epoch 242 i 0
# step 0: mean loss = 0.78923106
# Start of epoch 243 i 0
# step 0: mean loss = 0.78893715
# Start of epoch 244 i 0
# step 0: mean loss = 0.78865093
# Start of epoch 245 i 0
# step 0: mean loss = 0.7883535
# Start of epoch 246 i 0
# step 0: mean loss = 0.7880542
# Start of epoch 247 i 0
# step 0: mean loss = 0.78774816
# Start of epoch 248 i 0
# step 0: mean loss = 0.7874578
# Start of epoch 249 i 0
# step 0: mean loss = 0.7871428
# Start of epoch 250 i 0
# step 0: mean loss = 0.78680754
# Start of epoch 251 i 0
# step 0: mean loss = 0.7864519
# Start of epoch 252 i 0
# step 0: mean loss = 0.7860941
# Start of epoch 253 i 0
# step 0: mean loss = 0.7857358
# Start of epoch 254 i 0
# step 0: mean loss = 0.7853972
# Start of epoch 255 i 0
# step 0: mean loss = 0.7850484
# Start of epoch 256 i 0
# step 0: mean loss = 0.7847094
# Start of epoch 257 i 0
# step 0: mean loss = 0.7843569
# Start of epoch 258 i 0
# step 0: mean loss = 0.78401357
# Start of epoch 259 i 0
# step 0: mean loss = 0.7836691
# Start of epoch 260 i 0
# step 0: mean loss = 0.7833423
# Start of epoch 261 i 0
# step 0: mean loss = 0.78300995
# Start of epoch 262 i 0
# step 0: mean loss = 0.78266525
# Start of epoch 263 i 0
# step 0: mean loss = 0.7823169
# Start of epoch 264 i 0
# step 0: mean loss = 0.78197134
# Start of epoch 265 i 0
# step 0: mean loss = 0.78162855
# Start of epoch 266 i 0
# step 0: mean loss = 0.781284
# Start of epoch 267 i 0
# step 0: mean loss = 0.7809473
# Start of epoch 268 i 0
# step 0: mean loss = 0.78060806
# Start of epoch 269 i 0
# step 0: mean loss = 0.7802709
# Start of epoch 270 i 0
# step 0: mean loss = 0.77995574
# Start of epoch 271 i 0
# step 0: mean loss = 0.7796479
# Start of epoch 272 i 0
# step 0: mean loss = 0.7793592
# Start of epoch 273 i 0
# step 0: mean loss = 0.77907616
# Start of epoch 274 i 0
# step 0: mean loss = 0.77881324
# Start of epoch 275 i 0
# step 0: mean loss = 0.7785378
# Start of epoch 276 i 0
# step 0: mean loss = 0.7782581
# Start of epoch 277 i 0
# step 0: mean loss = 0.7779476
# Start of epoch 278 i 0
# step 0: mean loss = 0.77767056
# Start of epoch 279 i 0
# step 0: mean loss = 0.7773852
# Start of epoch 280 i 0
# step 0: mean loss = 0.77710235
# Start of epoch 281 i 0
# step 0: mean loss = 0.77680296
# Start of epoch 282 i 0
# step 0: mean loss = 0.77649724
# Start of epoch 283 i 0
# step 0: mean loss = 0.7761881
# Start of epoch 284 i 0
# step 0: mean loss = 0.7758624
# Start of epoch 285 i 0
# step 0: mean loss = 0.775543
# Start of epoch 286 i 0
# step 0: mean loss = 0.7752267
# Start of epoch 287 i 0
# step 0: mean loss = 0.77491343
# Start of epoch 288 i 0
# step 0: mean loss = 0.77459186
# Start of epoch 289 i 0
# step 0: mean loss = 0.77429247
# Start of epoch 290 i 0
# step 0: mean loss = 0.7739854
# Start of epoch 291 i 0
# step 0: mean loss = 0.77369046
# Start of epoch 292 i 0
# step 0: mean loss = 0.7733936
# Start of epoch 293 i 0
# step 0: mean loss = 0.7731097
# Start of epoch 294 i 0
# step 0: mean loss = 0.7728091
# Start of epoch 295 i 0
# step 0: mean loss = 0.77252495
# Start of epoch 296 i 0
# step 0: mean loss = 0.77222687
# Start of epoch 297 i 0
# step 0: mean loss = 0.7719325
# Start of epoch 298 i 0
# step 0: mean loss = 0.771621
# Start of epoch 299 i 0
# step 0: mean loss = 0.77131456
# Start of epoch 300 i 0
# step 0: mean loss = 0.77101254
# Start of epoch 301 i 0
# step 0: mean loss = 0.7707074
# Start of epoch 302 i 0
# step 0: mean loss = 0.77040356
# Start of epoch 303 i 0
# step 0: mean loss = 0.7701028
# Start of epoch 304 i 0
# step 0: mean loss = 0.76980746
# Start of epoch 305 i 0
# step 0: mean loss = 0.76951855
# Start of epoch 306 i 0
# step 0: mean loss = 0.769234
# Start of epoch 307 i 0
# step 0: mean loss = 0.7689356
# Start of epoch 308 i 0
# step 0: mean loss = 0.76864487
# Start of epoch 309 i 0
# step 0: mean loss = 0.7683466
# Start of epoch 310 i 0
# step 0: mean loss = 0.76807237
# Start of epoch 311 i 0
# step 0: mean loss = 0.76779413
# Start of epoch 312 i 0
# step 0: mean loss = 0.76752394
# Start of epoch 313 i 0
# step 0: mean loss = 0.76727194
# Start of epoch 314 i 0
# step 0: mean loss = 0.7670313
# Start of epoch 315 i 0
# step 0: mean loss = 0.766776
# Start of epoch 316 i 0
# step 0: mean loss = 0.76650906
# Start of epoch 317 i 0
# step 0: mean loss = 0.76621413
# Start of epoch 318 i 0
# step 0: mean loss = 0.7659163
# Start of epoch 319 i 0
# step 0: mean loss = 0.76561314
# Start of epoch 320 i 0
# step 0: mean loss = 0.7653181
# Start of epoch 321 i 0
# step 0: mean loss = 0.7650174
# Start of epoch 322 i 0
# step 0: mean loss = 0.7647243
# Start of epoch 323 i 0
# step 0: mean loss = 0.76443714
# Start of epoch 324 i 0
# step 0: mean loss = 0.76415354
# Start of epoch 325 i 0
# step 0: mean loss = 0.7638718
# Start of epoch 326 i 0
# step 0: mean loss = 0.76360255
# Start of epoch 327 i 0
# step 0: mean loss = 0.7633365
# Start of epoch 328 i 0
# step 0: mean loss = 0.7630658
# Start of epoch 329 i 0
# step 0: mean loss = 0.7627916
# Start of epoch 330 i 0
# step 0: mean loss = 0.7625334
# Start of epoch 331 i 0
# step 0: mean loss = 0.7622787
# Start of epoch 332 i 0
# step 0: mean loss = 0.76201
# Start of epoch 333 i 0
# step 0: mean loss = 0.7617629
# Start of epoch 334 i 0
# step 0: mean loss = 0.7615141
# Start of epoch 335 i 0
# step 0: mean loss = 0.76126736
# Start of epoch 336 i 0
# step 0: mean loss = 0.76100945
# Start of epoch 337 i 0
# step 0: mean loss = 0.7607607
# Start of epoch 338 i 0
# step 0: mean loss = 0.7605061
# Start of epoch 339 i 0
# step 0: mean loss = 0.7602533
# Start of epoch 340 i 0
# step 0: mean loss = 0.7599772
# Start of epoch 341 i 0
# step 0: mean loss = 0.7597089
# Start of epoch 342 i 0
# step 0: mean loss = 0.75943786
# Start of epoch 343 i 0
# step 0: mean loss = 0.7591672
# Start of epoch 344 i 0
# step 0: mean loss = 0.7588849
# Start of epoch 345 i 0
# step 0: mean loss = 0.7586041
# Start of epoch 346 i 0
# step 0: mean loss = 0.7583212
# Start of epoch 347 i 0
# step 0: mean loss = 0.75804484
# Start of epoch 348 i 0
# step 0: mean loss = 0.75776744
# Start of epoch 349 i 0
# step 0: mean loss = 0.7574963
# Start of epoch 350 i 0
# step 0: mean loss = 0.75723535
# Start of epoch 351 i 0
# step 0: mean loss = 0.7569785
# Start of epoch 352 i 0
# step 0: mean loss = 0.7567298
# Start of epoch 353 i 0
# step 0: mean loss = 0.75647104
# Start of epoch 354 i 0
# step 0: mean loss = 0.7562181
# Start of epoch 355 i 0
# step 0: mean loss = 0.7559671
# Start of epoch 356 i 0
# step 0: mean loss = 0.755706
# Start of epoch 357 i 0
# step 0: mean loss = 0.7554483
# Start of epoch 358 i 0
# step 0: mean loss = 0.75520146
# Start of epoch 359 i 0
# step 0: mean loss = 0.75495595
# Start of epoch 360 i 0
# step 0: mean loss = 0.75470775
# Start of epoch 361 i 0
# step 0: mean loss = 0.75445086
# Start of epoch 362 i 0
# step 0: mean loss = 0.7541985
# Start of epoch 363 i 0
# step 0: mean loss = 0.7539699
# Start of epoch 364 i 0
# step 0: mean loss = 0.75372857
# Start of epoch 365 i 0
# step 0: mean loss = 0.75348836
# Start of epoch 366 i 0
# step 0: mean loss = 0.7532498
# Start of epoch 367 i 0
# step 0: mean loss = 0.7530162
# Start of epoch 368 i 0
# step 0: mean loss = 0.75278383
# Start of epoch 369 i 0
# step 0: mean loss = 0.7525525
# Start of epoch 370 i 0
# step 0: mean loss = 0.75231576
# Start of epoch 371 i 0
# step 0: mean loss = 0.7520658
# Start of epoch 372 i 0
# step 0: mean loss = 0.7518238
# Start of epoch 373 i 0
# step 0: mean loss = 0.75157434
# Start of epoch 374 i 0
# step 0: mean loss = 0.7513219
# Start of epoch 375 i 0
# step 0: mean loss = 0.75105935
# Start of epoch 376 i 0
# step 0: mean loss = 0.750803
# Start of epoch 377 i 0
# step 0: mean loss = 0.75054806
# Start of epoch 378 i 0
# step 0: mean loss = 0.75030345
# Start of epoch 379 i 0
# step 0: mean loss = 0.75006235
# Start of epoch 380 i 0
# step 0: mean loss = 0.7498364
# Start of epoch 381 i 0
# step 0: mean loss = 0.7496011
# Start of epoch 382 i 0
# step 0: mean loss = 0.74935573
# Start of epoch 383 i 0
# step 0: mean loss = 0.74910927
# Start of epoch 384 i 0
# step 0: mean loss = 0.748871
# Start of epoch 385 i 0
# step 0: mean loss = 0.74863327
# Start of epoch 386 i 0
# step 0: mean loss = 0.7483879
# Start of epoch 387 i 0
# step 0: mean loss = 0.7481461
# Start of epoch 388 i 0
# step 0: mean loss = 0.74790704
# Start of epoch 389 i 0
# step 0: mean loss = 0.74768555
# Start of epoch 390 i 0
# step 0: mean loss = 0.7474522
# Start of epoch 391 i 0
# step 0: mean loss = 0.7472157
# Start of epoch 392 i 0
# step 0: mean loss = 0.7469746
# Start of epoch 393 i 0
# step 0: mean loss = 0.74673945
# Start of epoch 394 i 0
# step 0: mean loss = 0.7465044
# Start of epoch 395 i 0
# step 0: mean loss = 0.7462788
# Start of epoch 396 i 0
# step 0: mean loss = 0.7460504
# Start of epoch 397 i 0
# step 0: mean loss = 0.74581385
# Start of epoch 398 i 0
# step 0: mean loss = 0.7455739
# Start of epoch 399 i 0
# step 0: mean loss = 0.74533784
# Start of epoch 400 i 0
# step 0: mean loss = 0.7451033
# Start of epoch 401 i 0
# step 0: mean loss = 0.7448623
# Start of epoch 402 i 0
# step 0: mean loss = 0.7446205
# Start of epoch 403 i 0
# step 0: mean loss = 0.7443845
# Start of epoch 404 i 0
# step 0: mean loss = 0.7441622
# Start of epoch 405 i 0
# step 0: mean loss = 0.7439344
# Start of epoch 406 i 0
# step 0: mean loss = 0.7437124
# Start of epoch 407 i 0
# step 0: mean loss = 0.7434894
# Start of epoch 408 i 0
# step 0: mean loss = 0.7432643
# Start of epoch 409 i 0
# step 0: mean loss = 0.7430637
# Start of epoch 410 i 0
# step 0: mean loss = 0.74286914
# Start of epoch 411 i 0
# step 0: mean loss = 0.7426743
# Start of epoch 412 i 0
# step 0: mean loss = 0.7424846
# Start of epoch 413 i 0
# step 0: mean loss = 0.74226403
# Start of epoch 414 i 0
# step 0: mean loss = 0.74202806
# Start of epoch 415 i 0
# step 0: mean loss = 0.74178517
# Start of epoch 416 i 0
# step 0: mean loss = 0.7415335
# Start of epoch 417 i 0
# step 0: mean loss = 0.74128515
# Start of epoch 418 i 0
# step 0: mean loss = 0.74103886
# Start of epoch 419 i 0
# step 0: mean loss = 0.74080133
# Start of epoch 420 i 0
# step 0: mean loss = 0.7405614
# Start of epoch 421 i 0
# step 0: mean loss = 0.7403323
# Start of epoch 422 i 0
# step 0: mean loss = 0.7400985
# Start of epoch 423 i 0
# step 0: mean loss = 0.73987865
# Start of epoch 424 i 0
# step 0: mean loss = 0.7396518
# Start of epoch 425 i 0
# step 0: mean loss = 0.7394353
# Start of epoch 426 i 0
# step 0: mean loss = 0.7392096
# Start of epoch 427 i 0
# step 0: mean loss = 0.7389896
# Start of epoch 428 i 0
# step 0: mean loss = 0.7387685
# Start of epoch 429 i 0
# step 0: mean loss = 0.73854595
# Start of epoch 430 i 0
# step 0: mean loss = 0.73831916
# Start of epoch 431 i 0
# step 0: mean loss = 0.73809797
# Start of epoch 432 i 0
# step 0: mean loss = 0.73787266
# Start of epoch 433 i 0
# step 0: mean loss = 0.73765457
# Start of epoch 434 i 0
# step 0: mean loss = 0.73744404
# Start of epoch 435 i 0
# step 0: mean loss = 0.737236
# Start of epoch 436 i 0
# step 0: mean loss = 0.73704016
# Start of epoch 437 i 0
# step 0: mean loss = 0.7368467
# Start of epoch 438 i 0
# step 0: mean loss = 0.7366537
# Start of epoch 439 i 0
# step 0: mean loss = 0.7364543
# Start of epoch 440 i 0
# step 0: mean loss = 0.73625284
# Start of epoch 441 i 0
# step 0: mean loss = 0.73605555
# Start of epoch 442 i 0
# step 0: mean loss = 0.7358437
# Start of epoch 443 i 0
# step 0: mean loss = 0.7356249
# Start of epoch 444 i 0
# step 0: mean loss = 0.7353985
# Start of epoch 445 i 0
# step 0: mean loss = 0.73517895
# Start of epoch 446 i 0
# step 0: mean loss = 0.7349564
# Start of epoch 447 i 0
# step 0: mean loss = 0.73473406
# Start of epoch 448 i 0
# step 0: mean loss = 0.7345078
# Start of epoch 449 i 0
# step 0: mean loss = 0.7342894
# Start of epoch 450 i 0
# step 0: mean loss = 0.7340724
# Start of epoch 451 i 0
# step 0: mean loss = 0.7338582
# Start of epoch 452 i 0
# step 0: mean loss = 0.73364925
# Start of epoch 453 i 0
# step 0: mean loss = 0.7334404
# Start of epoch 454 i 0
# step 0: mean loss = 0.7332392
# Start of epoch 455 i 0
# step 0: mean loss = 0.73303694
# Start of epoch 456 i 0
# step 0: mean loss = 0.7328321
# Start of epoch 457 i 0
# step 0: mean loss = 0.7326339
# Start of epoch 458 i 0
# step 0: mean loss = 0.7324454
# Start of epoch 459 i 0
# step 0: mean loss = 0.73226047
# Start of epoch 460 i 0
# step 0: mean loss = 0.7320687
# Start of epoch 461 i 0
# step 0: mean loss = 0.7318835
# Start of epoch 462 i 0
# step 0: mean loss = 0.731686
# Start of epoch 463 i 0
# step 0: mean loss = 0.7314875
# Start of epoch 464 i 0
# step 0: mean loss = 0.7312824
# Start of epoch 465 i 0
# step 0: mean loss = 0.7310807
# Start of epoch 466 i 0
# step 0: mean loss = 0.7308809
# Start of epoch 467 i 0
# step 0: mean loss = 0.7306807
# Start of epoch 468 i 0
# step 0: mean loss = 0.7304726
# Start of epoch 469 i 0
# step 0: mean loss = 0.7302669

# %%
BATCH_SIZE = 1
batched_dataset = dataset.batch(BATCH_SIZE)
qy_mean_est = np.zeros((all_time,neuron_num))
for step, x_batch_train in enumerate(batched_dataset):
    qy_mean_est[Time*step:Time*(step+1),:] = vae(x_batch_train)
for i in range(neuron_num):
    plt.figure()
    plt.ylim(-2,20)
    plt.plot(y_data[:,i],"k")
    plt.plot(qy_mean_est[:,i],"r")

# %%
qz_mean_est = np.zeros((all_time,factor_dim))
for step, x_batch_train in enumerate(batched_dataset):
    qz_mean_est[Time*step:Time*(step+1),:] = vae.latent(x_batch_train)
#wgt = np.linalg.lstsq(qz_mean_est-qz_mean_est.mean(), traj-traj.mean())[0] 
#qz_mean_est = np.dot(qz_mean_est,wgt)
#qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))

# %% [markdown]
# # Evaluate Quality of reconstruction

# %%
plt.plot(qz_mean_est[:,0],qz_mean_est[:,1])
qz_est_c = qz_mean_est - qz_mean_est.mean(axis=0)
qz_est_norm = qz_est_c/np.linalg.norm(qz_est_c)
qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))

z_true_c = traj - traj.mean(axis=0)
z_true_norm = z_true_c/np.linalg.norm(z_true_c)
R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
fig = plt.figure(figsize=(12,12))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure()
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
