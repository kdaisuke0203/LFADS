# %% [markdown]
# Our aim is to reproduce an example from the paper:
#
# [Inferring single-trial neural population dynamics using sequential auto-encoders](https://www.nature.com/articles/s41592-018-0109-9)
#
# We will generate trajectories from a latent Lorentz attractor and apply LFADS to recover the latent dynamic. Instead of using the original code (https://lfads.github.io/lfads-run-manager/) we will use tensorflow 2.

# %%
import numpy as np
import matplotlib.pyplot as plt
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import scipy.io
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
import funs

# %% [markdown]
# # Sample from latent Lorenz attractor:

# %%
Time = 15  # 50 worse
neuron_num = 30
datax = scipy.io.loadmat("spike30_sim_1500.mat")
y_data = datax["spike30_sim_1500"] 
traj = scipy.io.loadmat("trj30_sim_1500.mat")
traj = traj["trj30_sim_1500"]
print(traj.shape)
# Out:
# (1500, 2)

# %%
factor_dim = 10

NRep=int(1500/Time)
output = np.zeros((NRep,Time,neuron_num))

for i in range(NRep):
    output[i,:,:] = y_data[Time*i:Time*(i+1),:]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(traj[:,0],traj[:,1])
plt.figure(figsize=(4, 4))
ax1 = plt.subplot(311)
ax1.plot(traj[:, 0], lw=4, color='k')

ax2 = plt.subplot(312, sharex=ax1)
ax2.plot(traj[:, 1], lw=4, color='k')    
output = output.astype('float32')

# Z score output:
output=output.reshape(Time*NRep,neuron_num)
from scipy import stats
output = stats.zscore(output,axis=0)
output = output.reshape(NRep,Time,neuron_num)
print(output[0].shape)
# Out:
# (15, 30)

# %%
plt.figure()
plt.imshow(output[0,:,:].T,aspect='auto')
plt.xlabel('time')
plt.ylabel('neuron')
plt.colorbar()
plt.show()

# %%
dataset = tf.data.Dataset.from_tensor_slices((output))
#print(dataset)
#dataset = dataset.shuffle(20, reshuffle_each_iteration=True)

# %% [markdown]
# # Autoencoder Model

# %%
tf.keras.backend.clear_session()

# %%
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
class Encoder(tf.keras.layers.Layer):
    """Maps Trajectory to a triplet (z_mean, z_log_var, z)."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)        
        self.bidir_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(num_gru_unit,return_sequences=False), 
                                                       input_shape=(sequence_length, num_input_neuron))
        self.dense_mean = tf.keras.layers.Dense(latent_dim)
        self.dense_log_var = tf.keras.layers.Dense(latent_dim)
        self.sampling = Sampling()
        
    def call(self, inputs):
        x = self.bidir_gru(inputs)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

# %%
class Decoder(tf.keras.layers.Layer):
    """Converts z, the encoded digit vector, back into a readable digit."""
    def __init__(self,
                 latent_dim=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='decoder',
                 **kwargs):
        self.sequence_length = sequence_length
        super(Decoder, self).__init__(name=name, **kwargs)
        self.recurrent_decoder = tf.keras.layers.GRU(latent_dim,return_sequences=True)#,use_bias=False)
        self.linear_bottleneck = tf.keras.layers.Dense(num_factor, activation=None)
        self.dense_output = tf.keras.layers.Dense(256, activation='relu')
        self.dense_output2 = tf.keras.layers.Dense(num_input_neuron, activation=None)
        self.latent_dim=latent_dim
        
    def call(self, inputs):
        batch_size = tf.shape(inputs)[0]
        null_input = tf.zeros([batch_size,self.sequence_length,self.latent_dim])
        decoder_output = self.recurrent_decoder(null_input, initial_state=inputs)
        x = self.linear_bottleneck(decoder_output)
        x2 = self.dense_output(x)
        xo = self.dense_output2(x2)
        #xo = tf.exp(x2)
        return xo, x

# %%
class VariationalAutoEncoder(tf.keras.Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
    def __init__(self,
                 latent_dim=64,
                 num_gru_unit=64,
                 sequence_length=Time,
                 num_input_neuron=neuron_num,
                 num_factor=factor_dim,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.encoder = Encoder(latent_dim=latent_dim,num_gru_unit=num_gru_unit,sequence_length=sequence_length,
                               num_input_neuron=num_input_neuron)
        self.decoder = Decoder(latent_dim=latent_dim, sequence_length=sequence_length,
                              num_input_neuron=num_input_neuron,num_factor=num_factor)
    
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)[0]
        # Add KL divergence regularization loss.
        kl_loss = - 0.5 * tf.reduce_mean(z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
        self.add_loss(kl_loss)
        return reconstructed
    def latent(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        latent = self.decoder(z)[1]
        return latent

# %%
BATCH_SIZE = 1
batched_dataset = dataset.batch(BATCH_SIZE)

# %%
vae = VariationalAutoEncoder(latent_dim=64,
                             num_gru_unit=32,
                             sequence_length=Time,
                             num_input_neuron=neuron_num,
                             num_factor=factor_dim)

# %% [markdown]
# # Train Model

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=8e-4,clipvalue=200)
mse_loss_fn = tf.keras.losses.MeanSquaredError()
loss_metric = tf.keras.metrics.Mean()

# %% [markdown]
# #### Linearly scheduling on the Kullback–Leibler divergence penalty:
#
# We use a linearly increasing schedule on the Kullback–Leibler divergence penalty (as suggested [here](https://arxiv.org/pdf/1511.06349.pdf)) so that the optimization does not quickly (and pathologically) set the Kullback–Leibler divergence to 0

# %%
KL_penalty = np.linspace(0,1,10)

# %%
epochs = 2500

for i,kl_ in enumerate(KL_penalty):
    print(kl_,i)
    if i > 0:
        break
    # Iterate over epochs.
    for epoch in range(epochs):
        print('Start of epoch %d' % (epoch,),'i',i)

        # Iterate over the batches of the dataset.
        for step, x_batch_train in enumerate(batched_dataset):
            with tf.GradientTape() as tape:
                reconstructed = vae(x_batch_train)
                # Compute reconstruction loss
                loss = mse_loss_fn(x_batch_train, reconstructed)
                #print("loss",loss,"kl",sum(vae.losses))
                loss += kl_*sum(vae.losses)  # Add KLD regularization loss

            grads = tape.gradient(loss, vae.trainable_weights)
            optimizer.apply_gradients(zip(grads, vae.trainable_weights))
            loss_metric(loss)

            if step % 100 == 0:
                print('step %s: mean loss = %s' % (step, loss_metric.result().numpy()))
# Out:
# 0.0 0
# Start of epoch 0 i 0
# step 0: mean loss = 1.8539219
# Start of epoch 1 i 0
# step 0: mean loss = 1.0177159
# Start of epoch 2 i 0
# step 0: mean loss = 1.0089128
# Start of epoch 3 i 0
# step 0: mean loss = 0.9966023
# Start of epoch 4 i 0
# step 0: mean loss = 0.9786791
# Start of epoch 5 i 0
# step 0: mean loss = 0.9582929
# Start of epoch 6 i 0
# step 0: mean loss = 0.93645155
# Start of epoch 7 i 0
# step 0: mean loss = 0.9153922
# Start of epoch 8 i 0
# step 0: mean loss = 0.8980756
# Start of epoch 9 i 0
# step 0: mean loss = 0.87868524
# Start of epoch 10 i 0
# step 0: mean loss = 0.8613235
# Start of epoch 11 i 0
# step 0: mean loss = 0.8453128
# Start of epoch 12 i 0
# step 0: mean loss = 0.83216625
# Start of epoch 13 i 0
# step 0: mean loss = 0.81768566
# Start of epoch 14 i 0
# step 0: mean loss = 0.8041022
# Start of epoch 15 i 0
# step 0: mean loss = 0.79361767
# Start of epoch 16 i 0
# step 0: mean loss = 0.7840756
# Start of epoch 17 i 0
# step 0: mean loss = 0.77364886
# Start of epoch 18 i 0
# step 0: mean loss = 0.7642396
# Start of epoch 19 i 0
# step 0: mean loss = 0.7545291
# Start of epoch 20 i 0
# step 0: mean loss = 0.745562
# Start of epoch 21 i 0
# step 0: mean loss = 0.7376175
# Start of epoch 22 i 0
# step 0: mean loss = 0.7295954
# Start of epoch 23 i 0
# step 0: mean loss = 0.7225468
# Start of epoch 24 i 0
# step 0: mean loss = 0.71511894
# Start of epoch 25 i 0
# step 0: mean loss = 0.70752794
# Start of epoch 26 i 0
# step 0: mean loss = 0.6999784
# Start of epoch 27 i 0
# step 0: mean loss = 0.69360495
# Start of epoch 28 i 0
# step 0: mean loss = 0.6875334
# Start of epoch 29 i 0
# step 0: mean loss = 0.6814491
# Start of epoch 30 i 0
# step 0: mean loss = 0.67581546
# Start of epoch 31 i 0
# step 0: mean loss = 0.6697327
# Start of epoch 32 i 0
# step 0: mean loss = 0.664383
# Start of epoch 33 i 0
# step 0: mean loss = 0.6596297
# Start of epoch 34 i 0
# step 0: mean loss = 0.6543764
# Start of epoch 35 i 0
# step 0: mean loss = 0.6495495
# Start of epoch 36 i 0
# step 0: mean loss = 0.64485216
# Start of epoch 37 i 0
# step 0: mean loss = 0.64016247
# Start of epoch 38 i 0
# step 0: mean loss = 0.63518846
# Start of epoch 39 i 0
# step 0: mean loss = 0.63067657
# Start of epoch 40 i 0
# step 0: mean loss = 0.62687594
# Start of epoch 41 i 0
# step 0: mean loss = 0.6228188
# Start of epoch 42 i 0
# step 0: mean loss = 0.61878026
# Start of epoch 43 i 0
# step 0: mean loss = 0.61508495
# Start of epoch 44 i 0
# step 0: mean loss = 0.6116328
# Start of epoch 45 i 0
# step 0: mean loss = 0.60785824
# Start of epoch 46 i 0
# step 0: mean loss = 0.6039641
# Start of epoch 47 i 0
# step 0: mean loss = 0.60011256
# Start of epoch 48 i 0
# step 0: mean loss = 0.59619576
# Start of epoch 49 i 0
# step 0: mean loss = 0.5930347
# Start of epoch 50 i 0
# step 0: mean loss = 0.58931595
# Start of epoch 51 i 0
# step 0: mean loss = 0.5859308
# Start of epoch 52 i 0
# step 0: mean loss = 0.5833864
# Start of epoch 53 i 0
# step 0: mean loss = 0.58101183
# Start of epoch 54 i 0
# step 0: mean loss = 0.57807404
# Start of epoch 55 i 0
# step 0: mean loss = 0.57489246
# Start of epoch 56 i 0
# step 0: mean loss = 0.5719777
# Start of epoch 57 i 0
# step 0: mean loss = 0.56891596
# Start of epoch 58 i 0
# step 0: mean loss = 0.56578416
# Start of epoch 59 i 0
# step 0: mean loss = 0.56271815
# Start of epoch 60 i 0
# step 0: mean loss = 0.5600846
# Start of epoch 61 i 0
# step 0: mean loss = 0.5570923
# Start of epoch 62 i 0
# step 0: mean loss = 0.55443937
# Start of epoch 63 i 0
# step 0: mean loss = 0.5517647
# Start of epoch 64 i 0
# step 0: mean loss = 0.5496329
# Start of epoch 65 i 0
# step 0: mean loss = 0.547085
# Start of epoch 66 i 0
# step 0: mean loss = 0.544414
# Start of epoch 67 i 0
# step 0: mean loss = 0.54183036
# Start of epoch 68 i 0
# step 0: mean loss = 0.53988224
# Start of epoch 69 i 0
# step 0: mean loss = 0.5375599
# Start of epoch 70 i 0
# step 0: mean loss = 0.5352263
# Start of epoch 71 i 0
# step 0: mean loss = 0.5330399
# Start of epoch 72 i 0
# step 0: mean loss = 0.530873
# Start of epoch 73 i 0
# step 0: mean loss = 0.52897507
# Start of epoch 74 i 0
# step 0: mean loss = 0.5267875
# Start of epoch 75 i 0
# step 0: mean loss = 0.5245888
# Start of epoch 76 i 0
# step 0: mean loss = 0.52226204
# Start of epoch 77 i 0
# step 0: mean loss = 0.52043664
# Start of epoch 78 i 0
# step 0: mean loss = 0.51883477
# Start of epoch 79 i 0
# step 0: mean loss = 0.51689214
# Start of epoch 80 i 0
# step 0: mean loss = 0.5147723
# Start of epoch 81 i 0
# step 0: mean loss = 0.51259637
# Start of epoch 82 i 0
# step 0: mean loss = 0.5106258
# Start of epoch 83 i 0
# step 0: mean loss = 0.50870645
# Start of epoch 84 i 0
# step 0: mean loss = 0.5067583
# Start of epoch 85 i 0
# step 0: mean loss = 0.5054197
# Start of epoch 86 i 0
# step 0: mean loss = 0.50409895
# Start of epoch 87 i 0
# step 0: mean loss = 0.5023845
# Start of epoch 88 i 0
# step 0: mean loss = 0.50053906
# Start of epoch 89 i 0
# step 0: mean loss = 0.4986199
# Start of epoch 90 i 0
# step 0: mean loss = 0.4968199
# Start of epoch 91 i 0
# step 0: mean loss = 0.4950322
# Start of epoch 92 i 0
# step 0: mean loss = 0.49332613
# Start of epoch 93 i 0
# step 0: mean loss = 0.4919785
# Start of epoch 94 i 0
# step 0: mean loss = 0.49039507
# Start of epoch 95 i 0
# step 0: mean loss = 0.4887987
# Start of epoch 96 i 0
# step 0: mean loss = 0.48710206
# Start of epoch 97 i 0
# step 0: mean loss = 0.48554987
# Start of epoch 98 i 0
# step 0: mean loss = 0.48402244
# Start of epoch 99 i 0
# step 0: mean loss = 0.482355
# Start of epoch 100 i 0
# step 0: mean loss = 0.48090166
# Start of epoch 101 i 0
# step 0: mean loss = 0.47927982
# Start of epoch 102 i 0
# step 0: mean loss = 0.47764155
# Start of epoch 103 i 0
# step 0: mean loss = 0.47624496
# Start of epoch 104 i 0
# step 0: mean loss = 0.4747597
# Start of epoch 105 i 0
# step 0: mean loss = 0.47326827
# Start of epoch 106 i 0
# step 0: mean loss = 0.47203475
# Start of epoch 107 i 0
# step 0: mean loss = 0.47094
# Start of epoch 108 i 0
# step 0: mean loss = 0.46986294
# Start of epoch 109 i 0
# step 0: mean loss = 0.46874735
# Start of epoch 110 i 0
# step 0: mean loss = 0.4672101
# Start of epoch 111 i 0
# step 0: mean loss = 0.46578252
# Start of epoch 112 i 0
# step 0: mean loss = 0.464357
# Start of epoch 113 i 0
# step 0: mean loss = 0.4629665
# Start of epoch 114 i 0
# step 0: mean loss = 0.46156454
# Start of epoch 115 i 0
# step 0: mean loss = 0.4602532
# Start of epoch 116 i 0
# step 0: mean loss = 0.459138
# Start of epoch 117 i 0
# step 0: mean loss = 0.45788407
# Start of epoch 118 i 0
# step 0: mean loss = 0.45662898
# Start of epoch 119 i 0
# step 0: mean loss = 0.45528597
# Start of epoch 120 i 0
# step 0: mean loss = 0.45392475
# Start of epoch 121 i 0
# step 0: mean loss = 0.45252952
# Start of epoch 122 i 0
# step 0: mean loss = 0.45122826
# Start of epoch 123 i 0
# step 0: mean loss = 0.4502541
# Start of epoch 124 i 0
# step 0: mean loss = 0.44913903
# Start of epoch 125 i 0
# step 0: mean loss = 0.4481474
# Start of epoch 126 i 0
# step 0: mean loss = 0.44721803
# Start of epoch 127 i 0
# step 0: mean loss = 0.44608313
# Start of epoch 128 i 0
# step 0: mean loss = 0.44504336
# Start of epoch 129 i 0
# step 0: mean loss = 0.4440767
# Start of epoch 130 i 0
# step 0: mean loss = 0.44287682
# Start of epoch 131 i 0
# step 0: mean loss = 0.4416372
# Start of epoch 132 i 0
# step 0: mean loss = 0.44037005
# Start of epoch 133 i 0
# step 0: mean loss = 0.43918517
# Start of epoch 134 i 0
# step 0: mean loss = 0.43818226
# Start of epoch 135 i 0
# step 0: mean loss = 0.4372419
# Start of epoch 136 i 0
# step 0: mean loss = 0.43614942
# Start of epoch 137 i 0
# step 0: mean loss = 0.43500534
# Start of epoch 138 i 0
# step 0: mean loss = 0.43387124
# Start of epoch 139 i 0
# step 0: mean loss = 0.43281993
# Start of epoch 140 i 0
# step 0: mean loss = 0.43173134
# Start of epoch 141 i 0
# step 0: mean loss = 0.43074325
# Start of epoch 142 i 0
# step 0: mean loss = 0.4299398
# Start of epoch 143 i 0
# step 0: mean loss = 0.42898875
# Start of epoch 144 i 0
# step 0: mean loss = 0.42799306
# Start of epoch 145 i 0
# step 0: mean loss = 0.42693606
# Start of epoch 146 i 0
# step 0: mean loss = 0.4258669
# Start of epoch 147 i 0
# step 0: mean loss = 0.42483774
# Start of epoch 148 i 0
# step 0: mean loss = 0.42379862
# Start of epoch 149 i 0
# step 0: mean loss = 0.42281666
# Start of epoch 150 i 0
# step 0: mean loss = 0.42179543
# Start of epoch 151 i 0
# step 0: mean loss = 0.42081094
# Start of epoch 152 i 0
# step 0: mean loss = 0.4199904
# Start of epoch 153 i 0
# step 0: mean loss = 0.41909316
# Start of epoch 154 i 0
# step 0: mean loss = 0.41813457
# Start of epoch 155 i 0
# step 0: mean loss = 0.4172474
# Start of epoch 156 i 0
# step 0: mean loss = 0.41629416
# Start of epoch 157 i 0
# step 0: mean loss = 0.41549945
# Start of epoch 158 i 0
# step 0: mean loss = 0.41472346
# Start of epoch 159 i 0
# step 0: mean loss = 0.4137579
# Start of epoch 160 i 0
# step 0: mean loss = 0.4127695
# Start of epoch 161 i 0
# step 0: mean loss = 0.4118458
# Start of epoch 162 i 0
# step 0: mean loss = 0.41090268
# Start of epoch 163 i 0
# step 0: mean loss = 0.40998086
# Start of epoch 164 i 0
# step 0: mean loss = 0.40906343
# Start of epoch 165 i 0
# step 0: mean loss = 0.40815833
# Start of epoch 166 i 0
# step 0: mean loss = 0.40722618
# Start of epoch 167 i 0
# step 0: mean loss = 0.40631747
# Start of epoch 168 i 0
# step 0: mean loss = 0.40544814
# Start of epoch 169 i 0
# step 0: mean loss = 0.4046636
# Start of epoch 170 i 0
# step 0: mean loss = 0.40377757
# Start of epoch 171 i 0
# step 0: mean loss = 0.40283006
# Start of epoch 172 i 0
# step 0: mean loss = 0.40188527
# Start of epoch 173 i 0
# step 0: mean loss = 0.4011212
# Start of epoch 174 i 0
# step 0: mean loss = 0.40037736
# Start of epoch 175 i 0
# step 0: mean loss = 0.3996101
# Start of epoch 176 i 0
# step 0: mean loss = 0.39880627
# Start of epoch 177 i 0
# step 0: mean loss = 0.39793897
# Start of epoch 178 i 0
# step 0: mean loss = 0.3972262
# Start of epoch 179 i 0
# step 0: mean loss = 0.39648405
# Start of epoch 180 i 0
# step 0: mean loss = 0.39567128
# Start of epoch 181 i 0
# step 0: mean loss = 0.39481094
# Start of epoch 182 i 0
# step 0: mean loss = 0.3939686
# Start of epoch 183 i 0
# step 0: mean loss = 0.39318573
# Start of epoch 184 i 0
# step 0: mean loss = 0.39241663
# Start of epoch 185 i 0
# step 0: mean loss = 0.3916645
# Start of epoch 186 i 0
# step 0: mean loss = 0.39090815
# Start of epoch 187 i 0
# step 0: mean loss = 0.39011428
# Start of epoch 188 i 0
# step 0: mean loss = 0.3893235
# Start of epoch 189 i 0
# step 0: mean loss = 0.38856715
# Start of epoch 190 i 0
# step 0: mean loss = 0.38791758
# Start of epoch 191 i 0
# step 0: mean loss = 0.38721612
# Start of epoch 192 i 0
# step 0: mean loss = 0.3864598
# Start of epoch 193 i 0
# step 0: mean loss = 0.385769
# Start of epoch 194 i 0
# step 0: mean loss = 0.38504538
# Start of epoch 195 i 0
# step 0: mean loss = 0.38444367
# Start of epoch 196 i 0
# step 0: mean loss = 0.38393533
# Start of epoch 197 i 0
# step 0: mean loss = 0.38321757
# Start of epoch 198 i 0
# step 0: mean loss = 0.38247287
# Start of epoch 199 i 0
# step 0: mean loss = 0.38172743
# Start of epoch 200 i 0
# step 0: mean loss = 0.38095784
# Start of epoch 201 i 0
# step 0: mean loss = 0.38017318
# Start of epoch 202 i 0
# step 0: mean loss = 0.3794509
# Start of epoch 203 i 0
# step 0: mean loss = 0.3787348
# Start of epoch 204 i 0
# step 0: mean loss = 0.3779786
# Start of epoch 205 i 0
# step 0: mean loss = 0.37720856
# Start of epoch 206 i 0
# step 0: mean loss = 0.376472
# Start of epoch 207 i 0
# step 0: mean loss = 0.37583056
# Start of epoch 208 i 0
# step 0: mean loss = 0.37533173
# Start of epoch 209 i 0
# step 0: mean loss = 0.3747545
# Start of epoch 210 i 0
# step 0: mean loss = 0.3741088
# Start of epoch 211 i 0
# step 0: mean loss = 0.37353683
# Start of epoch 212 i 0
# step 0: mean loss = 0.3728348
# Start of epoch 213 i 0
# step 0: mean loss = 0.3721206
# Start of epoch 214 i 0
# step 0: mean loss = 0.37142077
# Start of epoch 215 i 0
# step 0: mean loss = 0.37073818
# Start of epoch 216 i 0
# step 0: mean loss = 0.3700022
# Start of epoch 217 i 0
# step 0: mean loss = 0.36926565
# Start of epoch 218 i 0
# step 0: mean loss = 0.3685478
# Start of epoch 219 i 0
# step 0: mean loss = 0.36787888
# Start of epoch 220 i 0
# step 0: mean loss = 0.36715692
# Start of epoch 221 i 0
# step 0: mean loss = 0.36642563
# Start of epoch 222 i 0
# step 0: mean loss = 0.3657753
# Start of epoch 223 i 0
# step 0: mean loss = 0.36525562
# Start of epoch 224 i 0
# step 0: mean loss = 0.36465877
# Start of epoch 225 i 0
# step 0: mean loss = 0.3641077
# Start of epoch 226 i 0
# step 0: mean loss = 0.36357808
# Start of epoch 227 i 0
# step 0: mean loss = 0.36295193
# Start of epoch 228 i 0
# step 0: mean loss = 0.36227402
# Start of epoch 229 i 0
# step 0: mean loss = 0.36160704
# Start of epoch 230 i 0
# step 0: mean loss = 0.3609601
# Start of epoch 231 i 0
# step 0: mean loss = 0.3603543
# Start of epoch 232 i 0
# step 0: mean loss = 0.35974455
# Start of epoch 233 i 0
# step 0: mean loss = 0.35914072
# Start of epoch 234 i 0
# step 0: mean loss = 0.35855585
# Start of epoch 235 i 0
# step 0: mean loss = 0.3579763
# Start of epoch 236 i 0
# step 0: mean loss = 0.35739878
# Start of epoch 237 i 0
# step 0: mean loss = 0.35679385
# Start of epoch 238 i 0
# step 0: mean loss = 0.35618162
# Start of epoch 239 i 0
# step 0: mean loss = 0.35561866
# Start of epoch 240 i 0
# step 0: mean loss = 0.3550868
# Start of epoch 241 i 0
# step 0: mean loss = 0.35452417
# Start of epoch 242 i 0
# step 0: mean loss = 0.35398296
# Start of epoch 243 i 0
# step 0: mean loss = 0.35341865
# Start of epoch 244 i 0
# step 0: mean loss = 0.35279173
# Start of epoch 245 i 0
# step 0: mean loss = 0.3521495
# Start of epoch 246 i 0
# step 0: mean loss = 0.35150632
# Start of epoch 247 i 0
# step 0: mean loss = 0.35088032
# Start of epoch 248 i 0
# step 0: mean loss = 0.3502941
# Start of epoch 249 i 0
# step 0: mean loss = 0.34967446
# Start of epoch 250 i 0
# step 0: mean loss = 0.3490575
# Start of epoch 251 i 0
# step 0: mean loss = 0.34845424
# Start of epoch 252 i 0
# step 0: mean loss = 0.34790826
# Start of epoch 253 i 0
# step 0: mean loss = 0.34741983
# Start of epoch 254 i 0
# step 0: mean loss = 0.34693867
# Start of epoch 255 i 0
# step 0: mean loss = 0.3464506
# Start of epoch 256 i 0
# step 0: mean loss = 0.34587565
# Start of epoch 257 i 0
# step 0: mean loss = 0.34530762
# Start of epoch 258 i 0
# step 0: mean loss = 0.34473664
# Start of epoch 259 i 0
# step 0: mean loss = 0.3441463
# Start of epoch 260 i 0
# step 0: mean loss = 0.34356835
# Start of epoch 261 i 0
# step 0: mean loss = 0.3430479
# Start of epoch 262 i 0
# step 0: mean loss = 0.34254074
# Start of epoch 263 i 0
# step 0: mean loss = 0.34199324
# Start of epoch 264 i 0
# step 0: mean loss = 0.34144098
# Start of epoch 265 i 0
# step 0: mean loss = 0.3409289
# Start of epoch 266 i 0
# step 0: mean loss = 0.34042448
# Start of epoch 267 i 0
# step 0: mean loss = 0.33985513
# Start of epoch 268 i 0
# step 0: mean loss = 0.33928484
# Start of epoch 269 i 0
# step 0: mean loss = 0.33875653
# Start of epoch 270 i 0
# step 0: mean loss = 0.33824426
# Start of epoch 271 i 0
# step 0: mean loss = 0.33768436
# Start of epoch 272 i 0
# step 0: mean loss = 0.33714768
# Start of epoch 273 i 0
# step 0: mean loss = 0.33667153
# Start of epoch 274 i 0
# step 0: mean loss = 0.33634156
# Start of epoch 275 i 0
# step 0: mean loss = 0.3359135
# Start of epoch 276 i 0
# step 0: mean loss = 0.33542782
# Start of epoch 277 i 0
# step 0: mean loss = 0.33492452
# Start of epoch 278 i 0
# step 0: mean loss = 0.33446997
# Start of epoch 279 i 0
# step 0: mean loss = 0.33394927
# Start of epoch 280 i 0
# step 0: mean loss = 0.3334202
# Start of epoch 281 i 0
# step 0: mean loss = 0.33289132
# Start of epoch 282 i 0
# step 0: mean loss = 0.3323753
# Start of epoch 283 i 0
# step 0: mean loss = 0.33186924
# Start of epoch 284 i 0
# step 0: mean loss = 0.33137769
# Start of epoch 285 i 0
# step 0: mean loss = 0.33095148
# Start of epoch 286 i 0
# step 0: mean loss = 0.33061078
# Start of epoch 287 i 0
# step 0: mean loss = 0.33013257
# Start of epoch 288 i 0
# step 0: mean loss = 0.32960698
# Start of epoch 289 i 0
# step 0: mean loss = 0.32905033
# Start of epoch 290 i 0
# step 0: mean loss = 0.3285003
# Start of epoch 291 i 0
# step 0: mean loss = 0.3279552
# Start of epoch 292 i 0
# step 0: mean loss = 0.32747453
# Start of epoch 293 i 0
# step 0: mean loss = 0.3270185
# Start of epoch 294 i 0
# step 0: mean loss = 0.32657212
# Start of epoch 295 i 0
# step 0: mean loss = 0.32622033
# Start of epoch 296 i 0
# step 0: mean loss = 0.32572502
# Start of epoch 297 i 0
# step 0: mean loss = 0.32521287
# Start of epoch 298 i 0
# step 0: mean loss = 0.3247152
# Start of epoch 299 i 0
# step 0: mean loss = 0.32424656
# Start of epoch 300 i 0
# step 0: mean loss = 0.3237816
# Start of epoch 301 i 0
# step 0: mean loss = 0.3233525
# Start of epoch 302 i 0
# step 0: mean loss = 0.32285845
# Start of epoch 303 i 0
# step 0: mean loss = 0.3223782
# Start of epoch 304 i 0
# step 0: mean loss = 0.3218764
# Start of epoch 305 i 0
# step 0: mean loss = 0.32141346
# Start of epoch 306 i 0
# step 0: mean loss = 0.3209934
# Start of epoch 307 i 0
# step 0: mean loss = 0.32056496
# Start of epoch 308 i 0
# step 0: mean loss = 0.32012168
# Start of epoch 309 i 0
# step 0: mean loss = 0.31968254
# Start of epoch 310 i 0
# step 0: mean loss = 0.31920347
# Start of epoch 311 i 0
# step 0: mean loss = 0.3187398
# Start of epoch 312 i 0
# step 0: mean loss = 0.31827825
# Start of epoch 313 i 0
# step 0: mean loss = 0.3178323
# Start of epoch 314 i 0
# step 0: mean loss = 0.3173916
# Start of epoch 315 i 0
# step 0: mean loss = 0.31699386
# Start of epoch 316 i 0
# step 0: mean loss = 0.31658086
# Start of epoch 317 i 0
# step 0: mean loss = 0.31619522
# Start of epoch 318 i 0
# step 0: mean loss = 0.31584346
# Start of epoch 319 i 0
# step 0: mean loss = 0.3154377
# Start of epoch 320 i 0
# step 0: mean loss = 0.31500202
# Start of epoch 321 i 0
# step 0: mean loss = 0.31456992
# Start of epoch 322 i 0
# step 0: mean loss = 0.31412607
# Start of epoch 323 i 0
# step 0: mean loss = 0.31369624
# Start of epoch 324 i 0
# step 0: mean loss = 0.31326932
# Start of epoch 325 i 0
# step 0: mean loss = 0.31284443
# Start of epoch 326 i 0
# step 0: mean loss = 0.31239775
# Start of epoch 327 i 0
# step 0: mean loss = 0.31195214
# Start of epoch 328 i 0
# step 0: mean loss = 0.3115102
# Start of epoch 329 i 0
# step 0: mean loss = 0.31109482
# Start of epoch 330 i 0
# step 0: mean loss = 0.3107173
# Start of epoch 331 i 0
# step 0: mean loss = 0.310323
# Start of epoch 332 i 0
# step 0: mean loss = 0.3099055
# Start of epoch 333 i 0
# step 0: mean loss = 0.30947682
# Start of epoch 334 i 0
# step 0: mean loss = 0.3090297
# Start of epoch 335 i 0
# step 0: mean loss = 0.30856067
# Start of epoch 336 i 0
# step 0: mean loss = 0.30810145
# Start of epoch 337 i 0
# step 0: mean loss = 0.30765128
# Start of epoch 338 i 0
# step 0: mean loss = 0.3072528
# Start of epoch 339 i 0
# step 0: mean loss = 0.30686265
# Start of epoch 340 i 0
# step 0: mean loss = 0.30643803
# Start of epoch 341 i 0
# step 0: mean loss = 0.30600402
# Start of epoch 342 i 0
# step 0: mean loss = 0.3055591
# Start of epoch 343 i 0
# step 0: mean loss = 0.3051236
# Start of epoch 344 i 0
# step 0: mean loss = 0.3046868
# Start of epoch 345 i 0
# step 0: mean loss = 0.30428234
# Start of epoch 346 i 0
# step 0: mean loss = 0.3039227
# Start of epoch 347 i 0
# step 0: mean loss = 0.30358157
# Start of epoch 348 i 0
# step 0: mean loss = 0.30322185
# Start of epoch 349 i 0
# step 0: mean loss = 0.3028424
# Start of epoch 350 i 0
# step 0: mean loss = 0.30243394
# Start of epoch 351 i 0
# step 0: mean loss = 0.30206156
# Start of epoch 352 i 0
# step 0: mean loss = 0.30169284
# Start of epoch 353 i 0
# step 0: mean loss = 0.30129662
# Start of epoch 354 i 0
# step 0: mean loss = 0.30091476
# Start of epoch 355 i 0
# step 0: mean loss = 0.30053493
# Start of epoch 356 i 0
# step 0: mean loss = 0.3001426
# Start of epoch 357 i 0
# step 0: mean loss = 0.29975733
# Start of epoch 358 i 0
# step 0: mean loss = 0.2993992
# Start of epoch 359 i 0
# step 0: mean loss = 0.29903057
# Start of epoch 360 i 0
# step 0: mean loss = 0.298657
# Start of epoch 361 i 0
# step 0: mean loss = 0.2983011
# Start of epoch 362 i 0
# step 0: mean loss = 0.29789954
# Start of epoch 363 i 0
# step 0: mean loss = 0.29747197
# Start of epoch 364 i 0
# step 0: mean loss = 0.29702297
# Start of epoch 365 i 0
# step 0: mean loss = 0.2965748
# Start of epoch 366 i 0
# step 0: mean loss = 0.29614756
# Start of epoch 367 i 0
# step 0: mean loss = 0.29572576
# Start of epoch 368 i 0
# step 0: mean loss = 0.29534602
# Start of epoch 369 i 0
# step 0: mean loss = 0.29500178
# Start of epoch 370 i 0
# step 0: mean loss = 0.29476413
# Start of epoch 371 i 0
# step 0: mean loss = 0.2944779
# Start of epoch 372 i 0
# step 0: mean loss = 0.29418007
# Start of epoch 373 i 0
# step 0: mean loss = 0.29381892
# Start of epoch 374 i 0
# step 0: mean loss = 0.29344818
# Start of epoch 375 i 0
# step 0: mean loss = 0.29307708
# Start of epoch 376 i 0
# step 0: mean loss = 0.29274642
# Start of epoch 377 i 0
# step 0: mean loss = 0.29243165
# Start of epoch 378 i 0
# step 0: mean loss = 0.2920896
# Start of epoch 379 i 0
# step 0: mean loss = 0.2917163
# Start of epoch 380 i 0
# step 0: mean loss = 0.29133406
# Start of epoch 381 i 0
# step 0: mean loss = 0.29095048
# Start of epoch 382 i 0
# step 0: mean loss = 0.2905633
# Start of epoch 383 i 0
# step 0: mean loss = 0.2901726
# Start of epoch 384 i 0
# step 0: mean loss = 0.28979078
# Start of epoch 385 i 0
# step 0: mean loss = 0.28940538
# Start of epoch 386 i 0
# step 0: mean loss = 0.2890388
# Start of epoch 387 i 0
# step 0: mean loss = 0.2886801
# Start of epoch 388 i 0
# step 0: mean loss = 0.28842905
# Start of epoch 389 i 0
# step 0: mean loss = 0.28816906
# Start of epoch 390 i 0
# step 0: mean loss = 0.28786004
# Start of epoch 391 i 0
# step 0: mean loss = 0.28750104
# Start of epoch 392 i 0
# step 0: mean loss = 0.2871445
# Start of epoch 393 i 0
# step 0: mean loss = 0.28679308
# Start of epoch 394 i 0
# step 0: mean loss = 0.28642407
# Start of epoch 395 i 0
# step 0: mean loss = 0.28603724
# Start of epoch 396 i 0
# step 0: mean loss = 0.28564328
# Start of epoch 397 i 0
# step 0: mean loss = 0.28525507
# Start of epoch 398 i 0
# step 0: mean loss = 0.28486606
# Start of epoch 399 i 0
# step 0: mean loss = 0.28447112
# Start of epoch 400 i 0
# step 0: mean loss = 0.28408247
# Start of epoch 401 i 0
# step 0: mean loss = 0.2837128
# Start of epoch 402 i 0
# step 0: mean loss = 0.28336594
# Start of epoch 403 i 0
# step 0: mean loss = 0.28303143
# Start of epoch 404 i 0
# step 0: mean loss = 0.28267458
# Start of epoch 405 i 0
# step 0: mean loss = 0.28233537
# Start of epoch 406 i 0
# step 0: mean loss = 0.28201318
# Start of epoch 407 i 0
# step 0: mean loss = 0.2816872
# Start of epoch 408 i 0
# step 0: mean loss = 0.28135946
# Start of epoch 409 i 0
# step 0: mean loss = 0.28099802
# Start of epoch 410 i 0
# step 0: mean loss = 0.28064153
# Start of epoch 411 i 0
# step 0: mean loss = 0.2802849
# Start of epoch 412 i 0
# step 0: mean loss = 0.27994767
# Start of epoch 413 i 0
# step 0: mean loss = 0.2796325
# Start of epoch 414 i 0
# step 0: mean loss = 0.27935845
# Start of epoch 415 i 0
# step 0: mean loss = 0.27905163
# Start of epoch 416 i 0
# step 0: mean loss = 0.27874142
# Start of epoch 417 i 0
# step 0: mean loss = 0.27841386
# Start of epoch 418 i 0
# step 0: mean loss = 0.27808246
# step 0: mean loss = 0.26199812
# Start of epoch 470 i 0
# step 0: mean loss = 0.26170462
# Start of epoch 471 i 0
# step 0: mean loss = 0.2614026
# Start of epoch 472 i 0
# step 0: mean loss = 0.2610905
# Start of epoch 473 i 0
# step 0: mean loss = 0.26076257
# Start of epoch 474 i 0
# step 0: mean loss = 0.26043987
# Start of epoch 475 i 0
# step 0: mean loss = 0.26011312
# Start of epoch 476 i 0
# step 0: mean loss = 0.25980213
# Start of epoch 477 i 0
# step 0: mean loss = 0.2594971
# Start of epoch 478 i 0
# step 0: mean loss = 0.25918314
# Start of epoch 479 i 0
# step 0: mean loss = 0.25888157
# Start of epoch 480 i 0
# step 0: mean loss = 0.25862023
# Start of epoch 481 i 0
# step 0: mean loss = 0.25837564
# Start of epoch 482 i 0
# step 0: mean loss = 0.2581339
# Start of epoch 483 i 0
# step 0: mean loss = 0.25785595
# Start of epoch 484 i 0
# step 0: mean loss = 0.2575719
# Start of epoch 485 i 0
# step 0: mean loss = 0.25730786
# Start of epoch 486 i 0
# step 0: mean loss = 0.25703886
# Start of epoch 487 i 0
# step 0: mean loss = 0.2567753
# Start of epoch 488 i 0
# step 0: mean loss = 0.25650284
# Start of epoch 489 i 0
# step 0: mean loss = 0.25623575
# Start of epoch 490 i 0
# step 0: mean loss = 0.2559315
# Start of epoch 491 i 0
# step 0: mean loss = 0.25562853
# Start of epoch 492 i 0
# step 0: mean loss = 0.25532773
# Start of epoch 493 i 0
# step 0: mean loss = 0.2550237
# Start of epoch 494 i 0
# step 0: mean loss = 0.25471833
# Start of epoch 495 i 0
# step 0: mean loss = 0.25441077
# Start of epoch 496 i 0
# step 0: mean loss = 0.2541118
# Start of epoch 497 i 0
# step 0: mean loss = 0.253835
# Start of epoch 498 i 0
# step 0: mean loss = 0.25358635
# Start of epoch 499 i 0
# step 0: mean loss = 0.25339514
# Start of epoch 500 i 0
# step 0: mean loss = 0.25321066
# Start of epoch 501 i 0
# step 0: mean loss = 0.25296694
# Start of epoch 502 i 0
# step 0: mean loss = 0.25281128
# Start of epoch 503 i 0
# step 0: mean loss = 0.25267333
# Start of epoch 504 i 0
# step 0: mean loss = 0.25248116
# Start of epoch 505 i 0
# step 0: mean loss = 0.25223786
# Start of epoch 506 i 0
# step 0: mean loss = 0.25197163
# Start of epoch 507 i 0
# step 0: mean loss = 0.2517526
# Start of epoch 508 i 0
# step 0: mean loss = 0.25152603
# Start of epoch 509 i 0
# step 0: mean loss = 0.25128034
# Start of epoch 510 i 0
# step 0: mean loss = 0.25102893
# Start of epoch 511 i 0
# step 0: mean loss = 0.25074646
# Start of epoch 512 i 0
# step 0: mean loss = 0.2504406
# Start of epoch 513 i 0
# step 0: mean loss = 0.25014487
# Start of epoch 514 i 0
# step 0: mean loss = 0.24984857
# Start of epoch 515 i 0
# step 0: mean loss = 0.24955232
# Start of epoch 516 i 0
# step 0: mean loss = 0.24925183
# Start of epoch 517 i 0
# step 0: mean loss = 0.24894342
# Start of epoch 518 i 0
# step 0: mean loss = 0.24863163
# Start of epoch 519 i 0
# step 0: mean loss = 0.24832249
# Start of epoch 621 i 0
# step 0: mean loss = 0.22533011
# Start of epoch 622 i 0
# step 0: mean loss = 0.22512309
# Start of epoch 623 i 0
# step 0: mean loss = 0.22492631
# Start of epoch 624 i 0
# step 0: mean loss = 0.22473274
# Start of epoch 625 i 0
# step 0: mean loss = 0.2245489
# Start of epoch 626 i 0
# step 0: mean loss = 0.2243548
# Start of epoch 627 i 0
# step 0: mean loss = 0.22416581
# Start of epoch 628 i 0
# step 0: mean loss = 0.223967
# Start of epoch 629 i 0
# step 0: mean loss = 0.223763
# Start of epoch 630 i 0
# step 0: mean loss = 0.22355336
# Start of epoch 631 i 0
# step 0: mean loss = 0.22334158
# Start of epoch 632 i 0
# step 0: mean loss = 0.22313039
# Start of epoch 633 i 0
# step 0: mean loss = 0.22293285
# Start of epoch 634 i 0
# step 0: mean loss = 0.222729
# Start of epoch 635 i 0
# step 0: mean loss = 0.22252192
# Start of epoch 636 i 0
# step 0: mean loss = 0.22231393
# Start of epoch 637 i 0
# step 0: mean loss = 0.2221025
# Start of epoch 638 i 0
# step 0: mean loss = 0.22189124
# Start of epoch 639 i 0
# step 0: mean loss = 0.22167766
# Start of epoch 640 i 0
# step 0: mean loss = 0.22146866
# Start of epoch 641 i 0
# step 0: mean loss = 0.22126593
# Start of epoch 642 i 0
# step 0: mean loss = 0.22106881
# Start of epoch 643 i 0
# step 0: mean loss = 0.22086863
# Start of epoch 644 i 0
# step 0: mean loss = 0.2206785
# Start of epoch 645 i 0
# step 0: mean loss = 0.22050042
# Start of epoch 646 i 0
# step 0: mean loss = 0.22035235
# Start of epoch 647 i 0
# step 0: mean loss = 0.2201827
# Start of epoch 648 i 0
# step 0: mean loss = 0.21999127
# Start of epoch 649 i 0
# step 0: mean loss = 0.21979424
# Start of epoch 650 i 0
# step 0: mean loss = 0.21959074
# Start of epoch 651 i 0
# step 0: mean loss = 0.2193828
# Start of epoch 652 i 0
# step 0: mean loss = 0.21917486
# Start of epoch 653 i 0
# step 0: mean loss = 0.21896653
# Start of epoch 654 i 0
# step 0: mean loss = 0.21875398
# Start of epoch 655 i 0
# step 0: mean loss = 0.21854602
# Start of epoch 656 i 0
# step 0: mean loss = 0.21835268
# Start of epoch 657 i 0
# step 0: mean loss = 0.21815348
# Start of epoch 658 i 0
# step 0: mean loss = 0.21795966
# Start of epoch 659 i 0
# step 0: mean loss = 0.21776848
# Start of epoch 660 i 0
# step 0: mean loss = 0.21758857
# Start of epoch 661 i 0
# step 0: mean loss = 0.21740565
# Start of epoch 662 i 0
# step 0: mean loss = 0.21720839
# Start of epoch 663 i 0
# step 0: mean loss = 0.21701367
# Start of epoch 664 i 0
# step 0: mean loss = 0.21681327
# Start of epoch 665 i 0
# step 0: mean loss = 0.21661407
# Start of epoch 666 i 0
# step 0: mean loss = 0.21641403
# Start of epoch 667 i 0
# step 0: mean loss = 0.21622463
# Start of epoch 668 i 0
# step 0: mean loss = 0.21604879
# Start of epoch 669 i 0
# step 0: mean loss = 0.21587895
# Start of epoch 670 i 0
# step 0: mean loss = 0.21570319
# Start of epoch 671 i 0
# step 0: mean loss = 0.21550308
# Start of epoch 672 i 0
# step 0: mean loss = 0.21529979
# Start of epoch 673 i 0
# step 0: mean loss = 0.215096
# Start of epoch 674 i 0
# step 0: mean loss = 0.21489243
# Start of epoch 675 i 0
# step 0: mean loss = 0.21468736
# Start of epoch 676 i 0
# step 0: mean loss = 0.21448006
# Start of epoch 677 i 0
# step 0: mean loss = 0.21427718
# Start of epoch 678 i 0
# step 0: mean loss = 0.21407561
# Start of epoch 679 i 0
# step 0: mean loss = 0.21388051
# Start of epoch 680 i 0
# step 0: mean loss = 0.2136995
# Start of epoch 681 i 0
# step 0: mean loss = 0.2135118
# Start of epoch 682 i 0
# step 0: mean loss = 0.21331845
# Start of epoch 683 i 0
# step 0: mean loss = 0.21313338
# Start of epoch 684 i 0
# step 0: mean loss = 0.21296075
# Start of epoch 685 i 0
# step 0: mean loss = 0.2128005
# Start of epoch 686 i 0
# step 0: mean loss = 0.21262573
# Start of epoch 687 i 0
# step 0: mean loss = 0.2124473
# Start of epoch 688 i 0
# step 0: mean loss = 0.21226801
# Start of epoch 689 i 0
# step 0: mean loss = 0.21208344
# Start of epoch 690 i 0
# step 0: mean loss = 0.21190462
# Start of epoch 691 i 0
# step 0: mean loss = 0.21172501
# Start of epoch 692 i 0
# step 0: mean loss = 0.21154542
# Start of epoch 693 i 0
# step 0: mean loss = 0.21138376
# Start of epoch 694 i 0
# step 0: mean loss = 0.21122576
# Start of epoch 695 i 0
# step 0: mean loss = 0.21104303
# Start of epoch 696 i 0
# step 0: mean loss = 0.21084017
# Start of epoch 697 i 0
# step 0: mean loss = 0.21063088
# Start of epoch 698 i 0
# step 0: mean loss = 0.21042806
# Start of epoch 699 i 0
# step 0: mean loss = 0.21023224
# Start of epoch 700 i 0
# step 0: mean loss = 0.21003573
# Start of epoch 701 i 0
# step 0: mean loss = 0.20983747
# Start of epoch 702 i 0
# step 0: mean loss = 0.20965114
# Start of epoch 703 i 0
# step 0: mean loss = 0.20946704
# Start of epoch 704 i 0
# step 0: mean loss = 0.20928133
# Start of epoch 705 i 0
# step 0: mean loss = 0.20909531
# Start of epoch 706 i 0
# step 0: mean loss = 0.20891106
# Start of epoch 707 i 0
# step 0: mean loss = 0.20873298
# Start of epoch 708 i 0
# step 0: mean loss = 0.20854963
# Start of epoch 709 i 0
# step 0: mean loss = 0.20836878
# Start of epoch 710 i 0
# step 0: mean loss = 0.20820051
# Start of epoch 711 i 0
# step 0: mean loss = 0.20803832
# Start of epoch 712 i 0
# step 0: mean loss = 0.2078674
# Start of epoch 713 i 0
# step 0: mean loss = 0.20770214
# Start of epoch 714 i 0
# step 0: mean loss = 0.20752671
# Start of epoch 715 i 0
# step 0: mean loss = 0.20734878
# Start of epoch 716 i 0
# step 0: mean loss = 0.2071877
# Start of epoch 717 i 0
# step 0: mean loss = 0.20701738
# Start of epoch 718 i 0
# step 0: mean loss = 0.20684248
# Start of epoch 719 i 0
# step 0: mean loss = 0.20666064
# Start of epoch 720 i 0
# step 0: mean loss = 0.20648432
# Start of epoch 721 i 0
# step 0: mean loss = 0.20629205
# Start of epoch 722 i 0
# step 0: mean loss = 0.20609508
# Start of epoch 723 i 0
# step 0: mean loss = 0.20589706
# Start of epoch 724 i 0
# step 0: mean loss = 0.20570292
# Start of epoch 725 i 0
# step 0: mean loss = 0.20551117
# Start of epoch 726 i 0
# step 0: mean loss = 0.20531856
# Start of epoch 727 i 0
# step 0: mean loss = 0.20512347
# Start of epoch 728 i 0
# step 0: mean loss = 0.2049374
# Start of epoch 729 i 0
# step 0: mean loss = 0.2047658
# Start of epoch 730 i 0
# step 0: mean loss = 0.20460428
# Start of epoch 731 i 0
# step 0: mean loss = 0.20444229
# Start of epoch 732 i 0
# step 0: mean loss = 0.20428887
# Start of epoch 733 i 0
# step 0: mean loss = 0.20415746
# Start of epoch 734 i 0
# step 0: mean loss = 0.20400223
# Start of epoch 735 i 0
# step 0: mean loss = 0.20383814
# Start of epoch 736 i 0
# step 0: mean loss = 0.20366967
# Start of epoch 737 i 0
# step 0: mean loss = 0.20349498
# Start of epoch 738 i 0
# step 0: mean loss = 0.20331083
# Start of epoch 739 i 0
# step 0: mean loss = 0.2031309
# Start of epoch 740 i 0
# step 0: mean loss = 0.2029503
# Start of epoch 741 i 0
# step 0: mean loss = 0.20276986
# Start of epoch 742 i 0
# step 0: mean loss = 0.20259862
# Start of epoch 743 i 0
# step 0: mean loss = 0.20242459
# Start of epoch 744 i 0
# step 0: mean loss = 0.20224479
# Start of epoch 745 i 0
# step 0: mean loss = 0.20206052
# Start of epoch 746 i 0
# step 0: mean loss = 0.20187972
# Start of epoch 747 i 0
# step 0: mean loss = 0.20169662
# Start of epoch 748 i 0
# step 0: mean loss = 0.20150754
# Start of epoch 749 i 0
# step 0: mean loss = 0.20131949
# Start of epoch 750 i 0
# step 0: mean loss = 0.20113415
# Start of epoch 751 i 0
# step 0: mean loss = 0.2009548
# Start of epoch 752 i 0
# step 0: mean loss = 0.20077227
# Start of epoch 753 i 0
# step 0: mean loss = 0.20059626
# Start of epoch 754 i 0
# step 0: mean loss = 0.20042618
# Start of epoch 755 i 0
# step 0: mean loss = 0.20025869
# Start of epoch 756 i 0
# step 0: mean loss = 0.20008767
# Start of epoch 757 i 0
# step 0: mean loss = 0.19992042
# Start of epoch 758 i 0
# step 0: mean loss = 0.19975771
# Start of epoch 759 i 0
# step 0: mean loss = 0.19959658
# Start of epoch 760 i 0
# step 0: mean loss = 0.19942662
# Start of epoch 761 i 0
# step 0: mean loss = 0.19925709
# Start of epoch 762 i 0
# step 0: mean loss = 0.1990939
# Start of epoch 763 i 0
# step 0: mean loss = 0.1989413
# Start of epoch 764 i 0
# step 0: mean loss = 0.19877927
# Start of epoch 765 i 0
# step 0: mean loss = 0.19861527
# Start of epoch 766 i 0
# step 0: mean loss = 0.19844882
# Start of epoch 767 i 0
# step 0: mean loss = 0.19828261
# Start of epoch 768 i 0
# step 0: mean loss = 0.19811071
# Start of epoch 769 i 0
# step 0: mean loss = 0.19794163
# Start of epoch 770 i 0
# step 0: mean loss = 0.19777589
# Start of epoch 771 i 0
# step 0: mean loss = 0.19761921
# Start of epoch 772 i 0
# Start of epoch 823 i 0
# step 0: mean loss = 0.18945257
# Start of epoch 824 i 0
# step 0: mean loss = 0.18928277
# Start of epoch 825 i 0
# step 0: mean loss = 0.1891122
# Start of epoch 826 i 0
# step 0: mean loss = 0.18894088
# Start of epoch 827 i 0
# step 0: mean loss = 0.18877217
# Start of epoch 828 i 0
# step 0: mean loss = 0.18860896
# Start of epoch 829 i 0
# step 0: mean loss = 0.18845631
# Start of epoch 830 i 0
# step 0: mean loss = 0.18830791
# Start of epoch 831 i 0
# step 0: mean loss = 0.1881582
# Start of epoch 832 i 0
# step 0: mean loss = 0.18801826
# Start of epoch 833 i 0
# step 0: mean loss = 0.18788396
# Start of epoch 834 i 0
# step 0: mean loss = 0.1877495
# Start of epoch 835 i 0
# step 0: mean loss = 0.1876073
# Start of epoch 836 i 0
# step 0: mean loss = 0.1874623
# Start of epoch 837 i 0
# step 0: mean loss = 0.18730906
# Start of epoch 838 i 0
# step 0: mean loss = 0.18715492
# Start of epoch 839 i 0
# step 0: mean loss = 0.18699819
# Start of epoch 840 i 0
# step 0: mean loss = 0.18683931
# Start of epoch 841 i 0
# step 0: mean loss = 0.18668227
# Start of epoch 842 i 0
# step 0: mean loss = 0.18652742
# Start of epoch 843 i 0
# step 0: mean loss = 0.18636984
# Start of epoch 844 i 0
# step 0: mean loss = 0.18621318
# Start of epoch 845 i 0
# step 0: mean loss = 0.18606374
# Start of epoch 846 i 0
# step 0: mean loss = 0.18591489
# Start of epoch 847 i 0
# step 0: mean loss = 0.1857628
# Start of epoch 848 i 0
# step 0: mean loss = 0.185611
# Start of epoch 849 i 0
# step 0: mean loss = 0.18546072
# Start of epoch 850 i 0
# step 0: mean loss = 0.18530925
# Start of epoch 851 i 0
# step 0: mean loss = 0.18515994
# Start of epoch 852 i 0
# step 0: mean loss = 0.18501343
# Start of epoch 853 i 0
# step 0: mean loss = 0.18486427
# Start of epoch 854 i 0
# step 0: mean loss = 0.18471871
# Start of epoch 855 i 0
# step 0: mean loss = 0.18458192
# Start of epoch 856 i 0
# step 0: mean loss = 0.18444337
# Start of epoch 857 i 0
# step 0: mean loss = 0.18430023
# Start of epoch 858 i 0
# step 0: mean loss = 0.184171
# Start of epoch 859 i 0
# step 0: mean loss = 0.18405014
# Start of epoch 860 i 0
# step 0: mean loss = 0.18392295
# Start of epoch 861 i 0
# step 0: mean loss = 0.183777
# Start of epoch 862 i 0
# step 0: mean loss = 0.18364355
# Start of epoch 863 i 0
# step 0: mean loss = 0.18353303
# Start of epoch 864 i 0
# step 0: mean loss = 0.18343608
# Start of epoch 865 i 0
# step 0: mean loss = 0.18338256
# Start of epoch 866 i 0
# step 0: mean loss = 0.18335724
# Start of epoch 867 i 0
# step 0: mean loss = 0.18325591
# Start of epoch 868 i 0
# step 0: mean loss = 0.18312597
# Start of epoch 869 i 0
# step 0: mean loss = 0.18298166
# Start of epoch 870 i 0
# step 0: mean loss = 0.18283178
# Start of epoch 871 i 0
# step 0: mean loss = 0.18268216
# Start of epoch 872 i 0
# step 0: mean loss = 0.18253255
# Start of epoch 873 i 0
# step 0: mean loss = 0.18239763
# Start of epoch 874 i 0
# step 0: mean loss = 0.18225259
# Start of epoch 875 i 0
# step 0: mean loss = 0.18210436
# Start of epoch 876 i 0
# step 0: mean loss = 0.18195382
# Start of epoch 877 i 0
# step 0: mean loss = 0.18180306
# Start of epoch 878 i 0
# step 0: mean loss = 0.18165106
# Start of epoch 879 i 0
# step 0: mean loss = 0.18150179
# Start of epoch 880 i 0
# step 0: mean loss = 0.1813528
# Start of epoch 881 i 0
# step 0: mean loss = 0.18120918
# Start of epoch 882 i 0
# step 0: mean loss = 0.18106835
# Start of epoch 883 i 0
# step 0: mean loss = 0.18093213
# Start of epoch 884 i 0
# step 0: mean loss = 0.18080132
# Start of epoch 885 i 0
# step 0: mean loss = 0.1806677
# Start of epoch 886 i 0
# step 0: mean loss = 0.18053834
# Start of epoch 887 i 0
# step 0: mean loss = 0.18040766
# Start of epoch 888 i 0
# step 0: mean loss = 0.18027118
# Start of epoch 889 i 0
# step 0: mean loss = 0.18013014
# Start of epoch 890 i 0
# step 0: mean loss = 0.17998649
# Start of epoch 891 i 0
# step 0: mean loss = 0.17984201
# Start of epoch 892 i 0
# step 0: mean loss = 0.17970173
# Start of epoch 893 i 0
# step 0: mean loss = 0.17956315
# Start of epoch 894 i 0
# step 0: mean loss = 0.17942649
# Start of epoch 895 i 0
# ...
# Start of epoch 1209 i 0
# step 0: mean loss = 0.14758183
# Start of epoch 1210 i 0
# step 0: mean loss = 0.14751126
# Start of epoch 1211 i 0
# step 0: mean loss = 0.14743604
# Start of epoch 1212 i 0
# step 0: mean loss = 0.14735469
# Start of epoch 1213 i 0
# step 0: mean loss = 0.14726777
# Start of epoch 1214 i 0
# step 0: mean loss = 0.14718455
# Start of epoch 1215 i 0
# step 0: mean loss = 0.14710613
# Start of epoch 1216 i 0
# step 0: mean loss = 0.14702724
# Start of epoch 1217 i 0
# step 0: mean loss = 0.14694872
# Start of epoch 1218 i 0
# step 0: mean loss = 0.14687672
# Start of epoch 1219 i 0
# step 0: mean loss = 0.14680015
# Start of epoch 1220 i 0
# step 0: mean loss = 0.14671834
# Start of epoch 1221 i 0
# step 0: mean loss = 0.14663526
# Start of epoch 1222 i 0
# step 0: mean loss = 0.14655584
# Start of epoch 1223 i 0
# step 0: mean loss = 0.14647865
# Start of epoch 1224 i 0
# step 0: mean loss = 0.14639951
# Start of epoch 1225 i 0
# step 0: mean loss = 0.1463136
# Start of epoch 1226 i 0
# step 0: mean loss = 0.1462273
# Start of epoch 1227 i 0
# step 0: mean loss = 0.14614448
# Start of epoch 1228 i 0
# step 0: mean loss = 0.14606673
# Start of epoch 1229 i 0
# step 0: mean loss = 0.1459858
# Start of epoch 1230 i 0
# step 0: mean loss = 0.14590286
# Start of epoch 1231 i 0
# step 0: mean loss = 0.14581607
# Start of epoch 1232 i 0
# step 0: mean loss = 0.1457259
# Start of epoch 1233 i 0
# step 0: mean loss = 0.14563538
# Start of epoch 1234 i 0
# step 0: mean loss = 0.14554326
# Start of epoch 1235 i 0
# step 0: mean loss = 0.14545156
# Start of epoch 1236 i 0
# Start of epoch 1481 i 0
# step 0: mean loss = 0.1291887
# Start of epoch 1482 i 0
# step 0: mean loss = 0.12912443
# Start of epoch 1483 i 0
# step 0: mean loss = 0.12906079
# Start of epoch 1484 i 0
# step 0: mean loss = 0.12899816
# Start of epoch 1485 i 0
# step 0: mean loss = 0.12894094
# Start of epoch 1486 i 0
# step 0: mean loss = 0.12888987
# Start of epoch 1487 i 0
# step 0: mean loss = 0.12886469
# Start of epoch 1488 i 0
# step 0: mean loss = 0.12885195
# Start of epoch 1489 i 0
# step 0: mean loss = 0.12884542
# Start of epoch 1490 i 0
# step 0: mean loss = 0.12885676
# Start of epoch 1491 i 0
# step 0: mean loss = 0.12883179
# Start of epoch 1492 i 0
# step 0: mean loss = 0.12879759
# Start of epoch 1493 i 0
# step 0: mean loss = 0.12877469
# Start of epoch 1494 i 0
# step 0: mean loss = 0.12874937
# Start of epoch 1495 i 0
# step 0: mean loss = 0.12870674
# Start of epoch 1496 i 0
# step 0: mean loss = 0.12866047
# Start of epoch 1497 i 0
# step 0: mean loss = 0.12861058
# Start of epoch 1498 i 0
# step 0: mean loss = 0.12855802
# Start of epoch 1499 i 0
# step 0: mean loss = 0.12850134
# 0.1111111111111111 1

# %%
qy_mean_est = np.zeros((1500,neuron_num))
for step, x_batch_train in enumerate(batched_dataset):
    qy_mean_est[Time*step:Time*(step+1),:] = vae(x_batch_train)
for i in range(30):
    plt.figure()
    plt.ylim(-2,20)
    plt.plot(y_data[:,i],"k",linewidth = 2)
    plt.plot(qy_mean_est[:,i],"r",linewidth = 1)
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
qz_mean_est = np.zeros((1500,factor_dim))
for step, x_batch_train in enumerate(batched_dataset):
    qz_mean_est[Time*step:Time*(step+1),:] = vae.latent(x_batch_train)
wgt = np.linalg.lstsq(qz_mean_est-qz_mean_est.mean(), traj-traj.mean())[0] 
qz_mean_est = np.dot(qz_mean_est,wgt)
qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))
# Out:
# C:\Users\kdais\Anaconda3\envs\py36tg20\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %% [markdown]
# # Evaluate Quality of reconstruction

# %%
#plt.plot(qz_mean_est[:,0],qz_mean_est[:,1])
#qz_est_c = qz_mean_est - qz_mean_est.mean(axis=0)
#qz_est_norm = qz_est_c/np.linalg.norm(qz_est_c)
#qz_est_norm = np.stack(qz_mean_est)/np.linalg.norm(np.stack(qz_mean_est))

z_true_c = traj - traj.mean(axis=0)
z_true_norm = z_true_c/np.linalg.norm(z_true_c)
R = funs.compute_optimal_rotation(np.stack(qz_est_norm), z_true_norm, scale=True)
qz_est_norm_R = np.stack(qz_est_norm).dot(R)

from scipy import signal
qz_est_norm_R[:,0] = signal.savgol_filter(qz_est_norm_R[:,0], 51, 5)
qz_est_norm_R[:,1] = signal.savgol_filter(qz_est_norm_R[:,1],51, 5)
fig = plt.figure(figsize=(12,12))
plt.subplot(211)
plt_post = plt.plot(qz_est_norm_R[:,0],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,0], 'k', linewidth = 3, label = '\"true\" mean')
plt.subplot(212)
plt_post = plt.plot(qz_est_norm_R[:,1],'r', linewidth = 3, label = 'posterior mean')
plt_true = plt.plot(z_true_norm[:,1], 'k', linewidth = 3, label = '\"true\" mean')

fig = plt.figure()
plt.plot(z_true_norm[:,0], z_true_norm[:,1], lw=2, color = 'k')
plt.plot(qz_est_norm_R[:,0], qz_est_norm_R[:,1], lw=2, color = 'r')
